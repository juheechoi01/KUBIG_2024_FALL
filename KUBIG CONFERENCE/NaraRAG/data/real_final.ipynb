# %% [markdown]
# ## OpenAI 임베딩 활용

# %%
# @title set API key
import os
import getpass
from pprint import pprint
import warnings

warnings.filterwarnings("ignore")

from IPython import get_ipython

if "google.colab" in str(get_ipython()):
    # Running in Google Colab. Please set the UPSTAGE_API_KEY in the Colab Secrets
    from google.colab import userdata
    os.environ["UPSTAGE_API_KEY"] = userdata.get("UPSTAGE_API_KEY")
else:
    # Running locally. Please set the UPSTAGE_API_KEY in the .env file
    from dotenv import load_dotenv

    load_dotenv()

if "UPSTAGE_API_KEY" not in os.environ:
    os.environ["UPSTAGE_API_KEY"] = getpass.getpass("Enter your Upstage API key: ")

# %%
#from langchain.storage import InMemoryStore
#from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.retrievers import ParentDocumentRetriever
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_upstage import UpstageEmbeddings
from langchain.embeddings import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain.storage._lc_store import create_kv_docstore
from langchain.storage.file_system import LocalFileStore


loader = CSVLoader(file_path='final_training.csv',
                   source_column='출처',
                   content_columns=['회의날짜', '국회_대', '회의명', '회수', '차수', '안건', '법안', '질문자_이름',
       '질문', '질문_키워드', '문맥', '답변자_이름', '답변', '답변_키워드'])

docs = loader.load()


# It should create documents smaller than the parent
child_splitter = RecursiveCharacterTextSplitter(chunk_size=400)

# The vectorstore to use to index the child chunks
vectorstore = Chroma(
    collection_name="split_parents", embedding_function=OpenAIEmbeddings(model="text-embedding-3-large"), 
    persist_directory='child_DB(Chroma, OpenAI)')

# The storage layer for the parent documents
fs = LocalFileStore('./parent_fs_chroma_OpenAI')
store = create_kv_docstore(fs)
big_chunk_retriever = ParentDocumentRetriever(
vectorstore=vectorstore,
docstore=store,
child_splitter=child_splitter)
# Out:
# /var/folders/g2/j70lmnjx7r338m_8lsfpyd440000gn/T/ipykernel_79343/497589892.py:27: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   collection_name="split_parents", embedding_function=OpenAIEmbeddings(model="text-embedding-3-large"),

# %%
docs
# Out:
# [Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046416&fileType=PDF', 'row': 0}, page_content='회의날짜: 2016년9월23일(금)\n질문자_이름: 전재수 의원\n질문: 미르재단 설립 허가 신청서는 어디서 접수되었으며, 그 처리과정에 대해 어떠한 절차가 따라졌는지 설명해 주실 수 있나요?\n질문_키워드: 미르재단,  설립,  허가,  대중문화산업과,  직원,  세종시,  청사,  근무\n답변자_이름: 조윤선 문화체육관광부 장관\n답변_키워드: 서울,  이메일,  접수,  서류,  직원,  출장\n국회_대: 20\n회의명: 국회본회의\n회수: 제346회\n차수: 제8차\n안건: 교육․사회․문화에 관한 질문\n법안: 없음'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=047966&fileType=PDF', 'row': 1}, page_content='회의날짜: 2018년2월07일(수)\n질문자_이름: 유은혜 의원\n질문: 추가 조사에서 교수의 직계가족을 대상으로 한정한 것에 따른 부정행위의 미비한 조사 우려가 제기되고 있습니다. 부총리를 단장으로 하는 대입공정성강화추진점검단에서 이 문제를 계속적으로 검토하고 고려할 계획이 있나요?\n질문_키워드: 추가,  조사,  대상,  직계가족,  친인척,  자녀,  공저자,  제외\n답변자_이름: 김상곤 교육부 부총리겸교육부장관\n답변_키워드: 직계자녀,  대입공정성강화추진점검단,  점검단,  조사\n국회_대: 20\n회의명: 국회본회의\n회수: 제356회\n차수: 제7차\n안건: 교육․사회․문화에 관한 질문(계속)\n법안: 없음'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=
 관한 질문\n법안: 없음'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=031123&fileType=PDF', 'row': 79}, page_content='회의날짜: 2003년6월05일(목)\n질문자_이름: 송석찬 의원\n질문: 미국이 다자회담을 주장하면서 전력을 대폭적으로 증강하는 이유는 무엇이라고 생각하십니까?\n질문_키워드: 요구,  다자회담,  전력,  증강,  평화적,  외교적,  해결,  원칙,  북한에서,  미국과,  자회담\n답변자_이름: 고건 국무총리\n답변_키워드: 전력증강,  북한,  문제,  다자대화,  설득,  러포트,  사령관,  근래,  얘기,  한반도\n국회_대: 16\n회의명: 국회본회의\n회수: 제240회\n차수: 제2차\n안건: 정치에관한질문\n법안: 정치에관한질문'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046180&fileType=PDF', 'row': 80}, page_content='회의날짜: 2016년7월04일(월)\n질문자_이름: 유성엽 의원\n질문: 환율 정책과 성장, 분배의 관계에서 어떤 정책적인 방향성을 고려하고 있으며, 성장과 분배를 조화롭게 이루어내기 위한 계획이 있는지 알려주십시오.\n질문_키워드: 것,  성장,  분배,  환율,  경제,  정책,  내,  점,  생각,  실패\n답변자_이름: 유일호 기획재정부 부총리겸기획재정부장관\n답변_키워드: 말씀,  것,  저희,  의원님,  경제,  정책,  우선순위,  중요,  데,  전적\n국회_대: 20\n회의명: 국회본회의\n회수: 제343회\n차수: 제6차\n안건: 경제에 관한 질문\n법안: 없음'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050202&fileType=PDF', 'row': 81}, page_content='회의날짜: 2020년9월17일(목)\n질문자_이름: 최형두 의원\n질문: 미애 장관의 아들 서 모 씨의 군 휴가 미복귀 의혹이 8개월째 지속되고 있는데, 수사가 제대로 진행되지 않는 이유는 무엇일까요? 답변 1: 추미애 장관의 아들 서 모 씨의 군 휴가 미복귀 의혹이 8개월째 지속되고 있는데, 수사가 제대로 진행되지 않는 이유는 명확히 밝혀지지 않았습니다. 그러나 형사소송법 257조에 따르면 수사는 3개월 이내에 완료되어 공소제기 여부를 결정해야 합니다. 따라서 8개월이 지나도록 수사가 진행되지 않는 상황은 문제점으로 여겨질 수 있습니다. 이러한 지연이 발생한 이유는 수사를 담당하는 서울동부지검의 내부적인 문제나 여러 요인의 복합적인 영향으로 추측될 수 있습니다. 질문 2: 검찰의 인사 결정은 대통령의 제청에 의해서 이루어지는데, 이러한 인사 결정은 종합적인 판단에 의해 이루어지는 것이지만, 최 의원님의 평가와 같이 인사 결과만 가지고 평가하는 것은 적절하지 않을 수도 있을까요? 답변 2: 검찰의 인사 결정은 대통령의 제청에 의해 이루어지며, 종합적인 판단에 따라 결정됩니다. 인사 결정은 다양한 요인과 사정을 고려하여 이루어지는 것이 일반적입니다. 따라서 인사 결과만 가지고 평가하는 것은 사실과 다른 분석일 수 있으며, 최 의원님께서 언급하신대로 인사 결과를 이용하여 오해를 일으키거나 과도한 평가를 하는 것은 적절하지 않을 수 있습니다. 대한민국의 모든 시민은 과오나 불법행위에 대해 책임을 져야 함은 당연한 것이며, 이는 법무부장관이나 총리, 국회의원 등 모든 인사에게 해당됩니다. 질문 3: 추미애 장관의 문제와 관련하여 현재 검찰에서 수사가 진행 중이지만, 진정한 국정 논의가 이루어져야 한다는 의견이 있습니다. 이에 대한 답변을 듣고 싶습니다. 답변 3: 현재 추미애 장관의 문제와 관련하여 검찰에서 수사가 진행 중이며, 이는 국정 논의와는 별개의 사안입니다. 그러나 
#  ...]

# %%
from tqdm.notebook import tqdm
#
def embedding(a,b,MAX_BATCH_SIZE=100):
    #
    for i in tqdm(range(a,b,MAX_BATCH_SIZE)):
        print(f"start : {i}")
        i_end = min(len(docs),i+MAX_BATCH_SIZE)
        print(f"end: {i_end}")
        batch = docs[i:i_end]
        try:
            big_chunk_retriever.add_documents(batch, ids=None)
        except ValueError as e:
            print(e)
            #ct = i_end // 2
            temp = batch
            #print(ct)
            big_chunk_retriever.add_documents(temp[:50], ids=None)
            big_chunk_retriever.add_documents(temp[50:], ids=None)
            continue

        print(f"Number of keys stored in the doctstore :{len(list(store.yield_keys()))}")

# %%
embedding(0, 5100)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# start : 0
# end: 100
# Number of keys stored in the doctstore :100
# start : 100
# end: 200
# Number of keys stored in the doctstore :200
# start : 200
# end: 300
# Number of keys stored in the doctstore :300
# start : 300
# end: 400
# Number of keys stored in the doctstore :400
# start : 400
# end: 500
# Number of keys stored in the doctstore :500
# start : 500
# end: 600
# Number of keys stored in the doctstore :600
# start : 600
# end: 700
# Number of keys stored in the doctstore :700
# start : 700
# end: 800
# Number of keys stored in the doctstore :800
# start : 800
# end: 900
# Number of keys stored in the doctstore :900
# start : 900
# end: 1000
# Number of keys stored in the doctstore :1000
# start : 1000
# end: 1100
# Number of keys stored in the doctstore :1100
# start : 1100
# end: 1200
# Number of keys stored in the doctstore :1200
# start : 1200
# end: 1300
# Number of keys stored in the doctstore :1300
# start : 1300
# end: 1400
# Number of keys stored in the doctstore :1400
# start : 1400
# end: 1500
# Number of keys stored in the doctstore :1500
# start : 1500
# end: 1600
# Number of keys stored in the doctstore :1600
# start : 1600
# end: 1700
# Number of keys stored in the doctstore :1700
# start : 1700
# end: 1800
# Number of keys stored in the doctstore :1800
# start : 1800
# end: 1900
# Number of keys stored in the doctstore :1900
# start : 1900
# end: 2000
# Number of keys stored in the doctstore :2000
# start : 2000
# end: 2100
# Number of keys stored in the doctstore :2100
# start : 2100
# end: 2200
# Number of keys stored in the doctstore :2200
# start : 2200
# end: 2300
# Number of keys stored in the doctstore :2300
# start : 2300
# end: 2400
# Number of keys stored in the doctstore :2400
# start : 2400
# end: 2500
# Number of keys stored in the doctstore :2500
# start : 2500
# end: 2600
# Number of keys stored in the doctstore :2600
# start : 2600
# end: 2700
# Number of keys stored in the doctstore :2700
# start : 2700
# end: 2800
# Number of keys stored in the doctstore :2800
# start : 2800
# end: 2900
# Number of keys stored in the doctstore :2900
# start : 2900
# end: 3000
# Number of keys stored in the doctstore :3000
# start : 3000
# end: 3100
# Number of keys stored in the doctstore :3100
# start : 3100
# end: 3200
# Number of keys stored in the doctstore :3200
# start : 3200
# end: 3300
# Number of keys stored in the doctstore :3300
# start : 3300
# end: 3400
# Number of keys stored in the doctstore :3400
# start : 3400
# end: 3500
# Number of keys stored in the doctstore :3500
# start : 3500
# end: 3600
# Number of keys stored in the doctstore :3600
# start : 3600
# end: 3700
# Number of keys stored in the doctstore :3700
# start : 3700
# end: 3800
# Number of keys stored in the doctstore :3800
# start : 3800
# end: 3900
# Number of keys stored in the doctstore :3900
# start : 3900
# end: 4000
# Number of keys stored in the doctstore :4000
# start : 4000
# end: 4100
# Number of keys stored in the doctstore :4100
# start : 4100
# end: 4200
# Number of keys stored in the doctstore :4200
# start : 4200
# end: 4300
# Number of keys stored in the doctstore :4300
# start : 4300
# end: 4400
# Number of keys stored in the doctstore :4400
# start : 4400
# end: 4500
# Number of keys stored in the doctstore :4500
# start : 4500
# end: 4600
# Number of keys stored in the doctstore :4600
# start : 4600
# end: 4700
# Number of keys stored in the doctstore :4700
# start : 4700
# end: 4800
# Number of keys stored in the doctstore :4800
# start : 4800
# end: 4900
# Number of keys stored in the doctstore :4900
# start : 4900
# end: 5000
# Number of keys stored in the doctstore :5000
# start : 5000
# end: 5100
# Number of keys stored in the doctstore :5100

# %%
embedding(5100, 35231)
# Out:
#   0%|          | 0/302 [00:00<?, ?it/s]
# start : 5100
# end: 5200
# Number of keys stored in the doctstore :5200
# start : 5200
# end: 5300
# Number of keys stored in the doctstore :5300
# start : 5300
# end: 5400
# Number of keys stored in the doctstore :5400
# start : 5400
# end: 5500
# Number of keys stored in the doctstore :5500
# start : 5500
# end: 5600
# Number of keys stored in the doctstore :5600
# start : 5600
# end: 5700
# Number of keys stored in the doctstore :5700
# start : 5700
# end: 5800
# Number of keys stored in the doctstore :5800
# start : 5800
# end: 5900
# Number of keys stored in the doctstore :5900
# start : 5900
# end: 6000
# Number of keys stored in the doctstore :6000
# start : 6000
# end: 6100
# Number of keys stored in the doctstore :6100
# start : 6100
# end: 6200
# Number of keys stored in the doctstore :6200
# start : 6200
# end: 6300
# Number of keys stored in the doctstore :6300
# start : 6300
# end: 6400
# Number of keys stored in the doctstore :6400
# start : 6400
# end: 6500
# Number of keys stored in the doctstore :6500
# start : 6500
# end: 6600
# Number of keys stored in the doctstore :6600
# start : 6600
# end: 6700
# Number of keys stored in the doctstore :6700
# start : 6700
# end: 6800
# Number of keys stored in the doctstore :6800
# start : 6800
# end: 6900
# Number of keys stored in the doctstore :6900
# start : 6900
# end: 7000
# Number of keys stored in the doctstore :7000
# start : 7000
# end: 7100
# Number of keys stored in the doctstore :7100
# start : 7100
# end: 7200
# Number of keys stored in the doctstore :7200
# start : 7200
# end: 7300
# Number of keys stored in the doctstore :7300
# start : 7300
# end: 7400
# Number of keys stored in the doctstore :7400
# start : 7400
# end: 7500
# Number of keys stored in the doctstore :7500
# start : 7500
# end: 7600
# Number of keys stored in the doctstore :7600
# start : 7600
# end: 7700
# Number of keys stored in the doctstore :7700
# start : 7700
# end: 7800
# Number of keys stored in the doctstore :7800
# start : 7800
# end: 7900
# Number of keys stored in the doctstore :7900
# start : 7900
# end: 8000
# Number of keys stored in the doctstore :8000
# start : 8000
# end: 8100
# Number of keys stored in the doctstore :8100
# start : 8100
# end: 8200
# Number of keys stored in the doctstore :8200
# start : 8200
# end: 8300
# Number of keys stored in the doctstore :8300
# start : 8300
# end: 8400
# Number of keys stored in the doctstore :8400
# start : 8400
# end: 8500
# Number of keys stored in the doctstore :8500
# start : 8500
# end: 8600
# Number of keys stored in the doctstore :8600
# start : 8600
# end: 8700
# Number of keys stored in the doctstore :8700
# start : 8700
# end: 8800
# Number of keys stored in the doctstore :8800
# start : 8800
# end: 8900
# Number of keys stored in the doctstore :8900
# start : 8900
# end: 9000
# Number of keys stored in the doctstore :9000
# start : 9000
# end: 9100
# Number of keys stored in the doctstore :9100
# start : 9100
# end: 9200
# Number of keys stored in the doctstore :9200
# start : 9200
# end: 9300
# Number of keys stored in the doctstore :9300
# start : 9300
# end: 9400
# Number of keys stored in the doctstore :9400
# start : 9400
# end: 9500
# Number of keys stored in the doctstore :9500
# start : 9500
# end: 9600
# Number of keys stored in the doctstore :9600
# start : 9600
# end: 9700
# Number of keys stored in the doctstore :9700
# start : 9700
# end: 9800
# Number of keys stored in the doctstore :9800
# start : 9800
# end: 9900
# Number of keys stored in the doctstore :9900
# start : 9900
# end: 10000
# Number of keys stored in the doctstore :10000
# start : 10000
# end: 10100
# Number of keys stored in the doctstore :10100
# start : 10100
# end: 10200
# Number of keys stored in the doctstore :10200
# start : 10200
# end: 10300
# Number of keys stored in the doctstore :10300
# start : 10300
# end: 10400
# Number of keys stored in the doctstore :10400
# start : 10400
# end: 10500
# Number of keys stored in the doctstore :10500
# start : 10500
# end: 10600
# Number of keys stored in the doctstore :10600
# start : 10600
# end: 10700
# Number of keys stored in the doctstore :10700
# start : 10700
# end: 10800
# Number of keys stored in the doctstore :10800
# start : 10800
# end: 10900
# Number of keys stored in the doctstore :10900
# start : 10900
# end: 11000
# Number of keys stored in the doctstore :11000
# start : 11000
# end: 11100
# Number of keys stored in the doctstore :11100
# start : 11100
# end: 11200
# Number of keys stored in the doctstore :11200
# start : 11200
# end: 11300
# Number of keys stored in the doctstore :11300
# start : 11300
# end: 11400
# Number of keys stored in the doctstore :11400
# start : 11400
# end: 11500
# Number of keys stored in the doctstore :11500
# start : 11500
# end: 11600
# Number of keys stored in the doctstore :11600
# start : 11600
# end: 11700
# Number of keys stored in the doctstore :11700
# start : 11700
# end: 11800
# Number of keys stored in the doctstore :11800
# start : 11800
# end: 11900
# Number of keys stored in the doctstore :11900
# start : 11900
# end: 12000
# Number of keys stored in the doctstore :12000
# start : 12000
# end: 12100
# Number of keys stored in the doctstore :12100
# start : 12100
# end: 12200
# Number of keys stored in the doctstore :12200
# start : 12200
# end: 12300
# Number of keys stored in the doctstore :12300
# start : 12300
# end: 12400
# Number of keys stored in the doctstore :12400
# start : 12400
# end: 12500
# Number of keys stored in the doctstore :12500
# start : 12500
# end: 12600
# Number of keys stored in the doctstore :12600
# start : 12600
# end: 12700
# Number of keys stored in the doctstore :12700
# start : 12700
# end: 12800
# Number of keys stored in the doctstore :12800
# start : 12800
# end: 12900
# Number of keys stored in the doctstore :12900
# start : 12900
# end: 13000
# Number of keys stored in the doctstore :13000
# start : 13000
# end: 13100
# Number of keys stored in the doctstore :13100
# start : 13100
# end: 13200
# Number of keys stored in the doctstore :13200
# start : 13200
# end: 13300
# Number of keys stored in the doctstore :13300
# start : 13300
# end: 13400
# Number of keys stored in the doctstore :13400
# start : 13400
# end: 13500
# Number of keys stored in the doctstore :13500
# start : 13500
# end: 13600
# Number of keys stored in the doctstore :13600
# start : 13600
# end: 13700
# Number of keys stored in the doctstore :13700
# start : 13700
# end: 13800
# Number of keys stored in the doctstore :13800
# start : 13800
# end: 13900
# Number of keys stored in the doctstore :13900
# start : 13900
# end: 14000
# Number of keys stored in the doctstore :14000
# start : 14000
# end: 14100
# Number of keys stored in the doctstore :14100
# start : 14100
# end: 14200
# Number of keys stored in the doctstore :14200
# start : 14200
# end: 14300
# Number of keys stored in the doctstore :14300
# start : 14300
# end: 14400
# Number of keys stored in the doctstore :14400
# start : 14400
# end: 14500
# Number of keys stored in the doctstore :14500
# start : 14500
# end: 14600
# Number of keys stored in the doctstore :14600
# start : 14600
# end: 14700
# Number of keys stored in the doctstore :14700
# start : 14700
# end: 14800
# Number of keys stored in the doctstore :14800
# start : 14800
# end: 14900
# Number of keys stored in the doctstore :14900
# start : 14900
# end: 15000
# Number of keys stored in the doctstore :15000
# start : 15000
# end: 15100
# Number of keys stored in the doctstore :15100
# start : 15100
# end: 15200
# Number of keys stored in the doctstore :15200
# start : 15200
# end: 15300
# Number of keys stored in the doctstore :15300
# start : 15300
# end: 15400
# Number of keys stored in the doctstore :15400
# start : 15400
# end: 15500
# Number of keys stored in the doctstore :15500
# start : 15500
# end: 15600
# Number of keys stored in the doctstore :15600
# start : 15600
# end: 15700
# Number of keys stored in the doctstore :15700
# start : 15700
# end: 15800
# Number of keys stored in the doctstore :15800
# start : 15800
# end: 15900
# Number of keys stored in the doctstore :15900
# start : 15900
# end: 16000
# Number of keys stored in the doctstore :16000
# start : 16000
# end: 16100
# Number of keys stored in the doctstore :16100
# start : 16100
# end: 16200
# Number of keys stored in the doctstore :16200
# start : 16200
# end: 16300
# Number of keys stored in the doctstore :16300
# start : 16300
# end: 16400
# Number of keys stored in the doctstore :16400
# start : 16400
# end: 16500
# Number of keys stored in the doctstore :16500
# start : 16500
# end: 16600
# Number of keys stored in the doctstore :16600
# start : 16600
# end: 16700
# Number of keys stored in the doctstore :16700
# start : 16700
# end: 16800
# Number of keys stored in the doctstore :16800
# start : 16800
# end: 16900
# Number of keys stored in the doctstore :16900
# start : 16900
# end: 17000
# Number of keys stored in the doctstore :17000
# start : 17000
# end: 17100
# Number of keys stored in the doctstore :17100
# start : 17100
# end: 17200
# Number of keys stored in the doctstore :17200
# start : 17200
# end: 17300
# Number of keys stored in the doctstore :17300
# start : 17300
# end: 17400
# Number of keys stored in the doctstore :17400
# start : 17400
# end: 17500
# Number of keys stored in the doctstore :17500
# start : 17500
# end: 17600
# Number of keys stored in the doctstore :17600
# start : 17600
# end: 17700
# Number of keys stored in the doctstore :17700
# start : 17700
# end: 17800
# Number of keys stored in the doctstore :17800
# start : 17800
# end: 17900
# Number of keys stored in the doctstore :17900
# start : 17900
# end: 18000
# Number of keys stored in the doctstore :18000
# start : 18000
# end: 18100
# Number of keys stored in the doctstore :18100
# start : 18100
# end: 18200
# Number of keys stored in the doctstore :18200
# start : 18200
# end: 18300
# Number of keys stored in the doctstore :18300
# start : 18300
# end: 18400
# Number of keys stored in the doctstore :18400
# start : 18400
# end: 18500
# Number of keys stored in the doctstore :18500
# start : 18500
# end: 18600
# Number of keys stored in the doctstore :18600
# start : 18600
# end: 18700
# Number of keys stored in the doctstore :18700
# start : 18700
# end: 18800
# Number of keys stored in the doctstore :18800
# start : 18800
# end: 18900
# Number of keys stored in the doctstore :18900
# start : 18900
# end: 19000
# Number of keys stored in the doctstore :19000
# start : 19000
# end: 19100
# Number of keys stored in the doctstore :19100
# start : 19100
# end: 19200
# Number of keys stored in the doctstore :19200
# start : 19200
# end: 19300
# Number of keys stored in the doctstore :19300
# start : 19300
# end: 19400
# Number of keys stored in the doctstore :19400
# start : 19400
# end: 19500
# Number of keys stored in the doctstore :19500
# start : 19500
# end: 19600
# Number of keys stored in the doctstore :19600
# start : 19600
# end: 19700
# Number of keys stored in the doctstore :19700
# start : 19700
# end: 19800
# Number of keys stored in the doctstore :19800
# start : 19800
# end: 19900
# Number of keys stored in the doctstore :19900
# start : 19900
# end: 20000
# Number of keys stored in the doctstore :20000
# start : 20000
# end: 20100
# Number of keys stored in the doctstore :20100
# start : 20100
# end: 20200
# Number of keys stored in the doctstore :20200
# start : 20200
# end: 20300
# Number of keys stored in the doctstore :20300
# start : 20300
# end: 20400
# Number of keys stored in the doctstore :20400
# start : 20400
# end: 20500
# Number of keys stored in the doctstore :20500
# start : 20500
# end: 20600
# Number of keys stored in the doctstore :20600
# start : 20600
# end: 20700
# Number of keys stored in the doctstore :20700
# start : 20700
# end: 20800
# Number of keys stored in the doctstore :20800
# start : 20800
# end: 20900
# Number of keys stored in the doctstore :20900
# start : 20900
# end: 21000
# Number of keys stored in the doctstore :21000
# start : 21000
# end: 21100
# Number of keys stored in the doctstore :21100
# start : 21100
# end: 21200
# Number of keys stored in the doctstore :21200
# start : 21200
# end: 21300
# Number of keys stored in the doctstore :21300
# start : 21300
# end: 21400
# Number of keys stored in the doctstore :21400
# start : 21400
# end: 21500
# Number of keys stored in the doctstore :21500
# start : 21500
# end: 21600
# Number of keys stored in the doctstore :21600
# start : 21600
# end: 21700
# Number of keys stored in the doctstore :21700
# start : 21700
# end: 21800
# Number of keys stored in the doctstore :21800
# start : 21800
# end: 21900
# Number of keys stored in the doctstore :21900
# start : 21900
# end: 22000
# Number of keys stored in the doctstore :22000
# start : 22000
# end: 22100
# Number of keys stored in the doctstore :22100
# start : 22100
# end: 22200
# Number of keys stored in the doctstore :22200
# start : 22200
# end: 22300
# Number of keys stored in the doctstore :22300
# start : 22300
# end: 22400
# Number of keys stored in the doctstore :22400
# start : 22400
# end: 22500
# Number of keys stored in the doctstore :22500
# start : 22500
# end: 22600
# Number of keys stored in the doctstore :22600
# start : 22600
# end: 22700
# Number of keys stored in the doctstore :22700
# start : 22700
# end: 22800
# Number of keys stored in the doctstore :22800
# start : 22800
# end: 22900
# Number of keys stored in the doctstore :22900
# start : 22900
# end: 23000
# Number of keys stored in the doctstore :23000
# start : 23000
# end: 23100
# Number of keys stored in the doctstore :23100
# start : 23100
# end: 23200
# Number of keys stored in the doctstore :23200
# start : 23200
# end: 23300
# Number of keys stored in the doctstore :23300
# start : 23300
# end: 23400
# Number of keys stored in the doctstore :23400
# start : 23400
# end: 23500
# Number of keys stored in the doctstore :23500
# start : 23500
# end: 23600
# Number of keys stored in the doctstore :23600
# start : 23600
# end: 23700
# Number of keys stored in the doctstore :23700
# start : 23700
# end: 23800
# Number of keys stored in the doctstore :23800
# start : 23800
# end: 23900
# Number of keys stored in the doctstore :23900
# start : 23900
# end: 24000
# Number of keys stored in the doctstore :24000
# start : 24000
# end: 24100
# Number of keys stored in the doctstore :24100
# start : 24100
# end: 24200
# Number of keys stored in the doctstore :24200
# start : 24200
# end: 24300
# Number of keys stored in the doctstore :24300
# start : 24300
# end: 24400
# Number of keys stored in the doctstore :24400
# start : 24400
# end: 24500
# Number of keys stored in the doctstore :24500
# start : 24500
# end: 24600
# Number of keys stored in the doctstore :24600
# start : 24600
# end: 24700
# Number of keys stored in the doctstore :24700
# start : 24700
# end: 24800
# Number of keys stored in the doctstore :24800
# start : 24800
# end: 24900
# Number of keys stored in the doctstore :24900
# start : 24900
# end: 25000
# Number of keys stored in the doctstore :25000
# start : 25000
# end: 25100
# Number of keys stored in the doctstore :25100
# start : 25100
# end: 25200
# Number of keys stored in the doctstore :25200
# start : 25200
# end: 25300
# Number of keys stored in the doctstore :25300
# start : 25300
# end: 25400
# Number of keys stored in the doctstore :25400
# start : 25400
# end: 25500
# Number of keys stored in the doctstore :25500
# start : 25500
# end: 25600
# Number of keys stored in the doctstore :25600
# start : 25600
# end: 25700
# Number of keys stored in the doctstore :25700
# start : 25700
# end: 25800
# Number of keys stored in the doctstore :25800
# start : 25800
# end: 25900
# Number of keys stored in the doctstore :25900
# start : 25900
# end: 26000
# Number of keys stored in the doctstore :26000
# start : 26000
# end: 26100
# Number of keys stored in the doctstore :26100
# start : 26100
# end: 26200
# Number of keys stored in the doctstore :26200
# start : 26200
# end: 26300
# Number of keys stored in the doctstore :26300
# start : 26300
# end: 26400
# Number of keys stored in the doctstore :26400
# start : 26400
# end: 26500
# Number of keys stored in the doctstore :26500
# start : 26500
# end: 26600
# Number of keys stored in the doctstore :26600
# start : 26600
# end: 26700
# Number of keys stored in the doctstore :26700
# start : 26700
# end: 26800
# Number of keys stored in the doctstore :26800
# start : 26800
# end: 26900
# Number of keys stored in the doctstore :26900
# start : 26900
# end: 27000
# Number of keys stored in the doctstore :27000
# start : 27000
# end: 27100
# Number of keys stored in the doctstore :27100
# start : 27100
# end: 27200
# Number of keys stored in the doctstore :27200
# start : 27200
# end: 27300
# Number of keys stored in the doctstore :27300
# start : 27300
# end: 27400
# Number of keys stored in the doctstore :27400
# start : 27400
# end: 27500
# Number of keys stored in the doctstore :27500
# start : 27500
# end: 27600
# Number of keys stored in the doctstore :27600
# start : 27600
# end: 27700
# Number of keys stored in the doctstore :27700
# start : 27700
# end: 27800
# Number of keys stored in the doctstore :27800
# start : 27800
# end: 27900
# Number of keys stored in the doctstore :27900
# start : 27900
# end: 28000
# Number of keys stored in the doctstore :28000
# start : 28000
# end: 28100
# Number of keys stored in the doctstore :28100
# start : 28100
# end: 28200
# Number of keys stored in the doctstore :28200
# start : 28200
# end: 28300
# Number of keys stored in the doctstore :28300
# start : 28300
# end: 28400
# Number of keys stored in the doctstore :28400
# start : 28400
# end: 28500
# Number of keys stored in the doctstore :28500
# start : 28500
# end: 28600
# Number of keys stored in the doctstore :28600
# start : 28600
# end: 28700
# Number of keys stored in the doctstore :28700
# start : 28700
# end: 28800
# Number of keys stored in the doctstore :28800
# start : 28800
# end: 28900
# Number of keys stored in the doctstore :28900
# start : 28900
# end: 29000
# Number of keys stored in the doctstore :29000
# start : 29000
# end: 29100
# Number of keys stored in the doctstore :29100
# start : 29100
# end: 29200
# Number of keys stored in the doctstore :29200
# start : 29200
# end: 29300
# Number of keys stored in the doctstore :29300
# start : 29300
# end: 29400
# Number of keys stored in the doctstore :29400
# start : 29400
# end: 29500
# Number of keys stored in the doctstore :29500
# start : 29500
# end: 29600
# Number of keys stored in the doctstore :29600
# start : 29600
# end: 29700
# Number of keys stored in the doctstore :29700
# start : 29700
# end: 29800
# Number of keys stored in the doctstore :29800
# start : 29800
# end: 29900
# Number of keys stored in the doctstore :29900
# start : 29900
# end: 30000
# Number of keys stored in the doctstore :30000
# start : 30000
# end: 30100
# Number of keys stored in the doctstore :30100
# start : 30100
# end: 30200
# Number of keys stored in the doctstore :30200
# start : 30200
# end: 30300
# Number of keys stored in the doctstore :30300
# start : 30300
# end: 30400
# Number of keys stored in the doctstore :30400
# start : 30400
# end: 30500
# Number of keys stored in the doctstore :30500
# start : 30500
# end: 30600
# Number of keys stored in the doctstore :30600
# start : 30600
# end: 30700
# Number of keys stored in the doctstore :30700
# start : 30700
# end: 30800
# Number of keys stored in the doctstore :30800
# start : 30800
# end: 30900
# Number of keys stored in the doctstore :30900
# start : 30900
# end: 31000
# Number of keys stored in the doctstore :31000
# start : 31000
# end: 31100
# Number of keys stored in the doctstore :31100
# start : 31100
# end: 31200
# Number of keys stored in the doctstore :31200
# start : 31200
# end: 31300
# Number of keys stored in the doctstore :31300
# start : 31300
# end: 31400
# Number of keys stored in the doctstore :31400
# start : 31400
# end: 31500
# Number of keys stored in the doctstore :31500
# start : 31500
# end: 31600
# Number of keys stored in the doctstore :31600
# start : 31600
# end: 31700
# Number of keys stored in the doctstore :31700
# start : 31700
# end: 31800
# Number of keys stored in the doctstore :31800
# start : 31800
# end: 31900
# Number of keys stored in the doctstore :31900
# start : 31900
# end: 32000
# Number of keys stored in the doctstore :32000
# start : 32000
# end: 32100
# Number of keys stored in the doctstore :32100
# start : 32100
# end: 32200
# Number of keys stored in the doctstore :32200
# start : 32200
# end: 32300
# Number of keys stored in the doctstore :32300
# start : 32300
# end: 32400
# Number of keys stored in the doctstore :32400
# start : 32400
# end: 32500
# Number of keys stored in the doctstore :32500
# start : 32500
# end: 32600
# Number of keys stored in the doctstore :32600
# start : 32600
# end: 32700
# Number of keys stored in the doctstore :32700
# start : 32700
# end: 32800
# Number of keys stored in the doctstore :32800
# start : 32800
# end: 32900
# Number of keys stored in the doctstore :32900
# start : 32900
# end: 33000
# Number of keys stored in the doctstore :33000
# start : 33000
# end: 33100
# Number of keys stored in the doctstore :33100
# start : 33100
# end: 33200
# Number of keys stored in the doctstore :33200
# start : 33200
# end: 33300
# Number of keys stored in the doctstore :33300
# start : 33300
# end: 33400
# Number of keys stored in the doctstore :33400
# start : 33400
# end: 33500
# Number of keys stored in the doctstore :33500
# start : 33500
# end: 33600
# Number of keys stored in the doctstore :33600
# start : 33600
# end: 33700
# Number of keys stored in the doctstore :33700
# start : 33700
# end: 33800
# Number of keys stored in the doctstore :33800
# start : 33800
# end: 33900
# Number of keys stored in the doctstore :33900
# start : 33900
# end: 34000
# Number of keys stored in the doctstore :34000
# start : 34000
# end: 34100
# Number of keys stored in the doctstore :34100
# start : 34100
# end: 34200
# Number of keys stored in the doctstore :34200
# start : 34200
# end: 34300
# Number of keys stored in the doctstore :34300
# start : 34300
# end: 34400
# Number of keys stored in the doctstore :34400
# start : 34400
# end: 34500
# Number of keys stored in the doctstore :34500
# start : 34500
# end: 34600
# Number of keys stored in the doctstore :34600
# start : 34600
# end: 34700
# Number of keys stored in the doctstore :34700
# start : 34700
# end: 34800
# Number of keys stored in the doctstore :34800
# start : 34800
# end: 34900
# Number of keys stored in the doctstore :34900
# start : 34900
# end: 35000
# Number of keys stored in the doctstore :35000
# start : 35000
# end: 35100
# Number of keys stored in the doctstore :35100
# start : 35100
# end: 35200
# Number of keys stored in the doctstore :35200
# start : 35200
# end: 35231
# Number of keys stored in the doctstore :35231

# %%
sub_docs = vectorstore.similarity_search("한덕수 총리가 무역적자에 관해 언급한 내용은 무엇인가요?")

print("글 길이: {}\n\n".format(len(sub_docs[0].page_content)))
print(sub_docs[0].page_content)

retrieved_docs = big_chunk_retriever.invoke("한덕수 총리가 무역적자에 관해 언급한 내용은 무엇인가요?")

print("글 길이: {}\n\n".format(len(retrieved_docs[0].page_content)))
print(retrieved_docs[0].page_content)
# Out:
# 글 길이: 356
#
#
# 회의날짜: 2022년7월26일(화)
# 국회_대: 21
# 회의명: 국회본회의
# 회수: 제398회
# 차수: 제6차
# 안건: 경제에 관한 질문
# 법안: 경제에 관한 질문
# 질문자_이름: 김경협  의원
# 질문: 무역적자가 28년 만에 발생한 이유는 무엇이라고 생각하십니까?
# 질문_키워드: 국제사회, 무역적자
# 문맥: '무역적자가 28년 만에 발생한 이유는 중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.'
# 답변자_이름: 한덕수 국무총리
# 글 길이: 528
#
#
# 회의날짜: 2022년7월26일(화)
# 국회_대: 21
# 회의명: 국회본회의
# 회수: 제398회
# 차수: 제6차
# 안건: 경제에 관한 질문
# 법안: 경제에 관한 질문
# 질문자_이름: 김경협  의원
# 질문: 무역적자가 28년 만에 발생한 이유는 무엇이라고 생각하십니까?
# 질문_키워드: 국제사회, 무역적자
# 문맥: '무역적자가 28년 만에 발생한 이유는 중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.'
# 답변자_이름: 한덕수 국무총리
# 답변: 중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.
# 답변_키워드: 중국, 원칙

# %%
sub_docs = vectorstore.similarity_search("오픈 프라이머리가 무엇인가요?")

print("글 길이: {}\n\n".format(len(sub_docs[0].page_content)))
print(sub_docs[0].page_content)

retrieved_docs = big_chunk_retriever.invoke("오픈 프라이머리가 무엇인가요?")

print("글 길이: {}\n\n".format(len(retrieved_docs[0].page_content)))
print(retrieved_docs[0].page_content)
# Out:
# 글 길이: 245
#
#
# 문맥: 의무공개매수제도는 특정 대주주에 대한 프리미엄만 부여되고, 일반 대주주에게 혜택이 가지 않아 M&A 저해와 문제 발생 우려로 인해 폐지되었습니다.
# 답변자_이름: 김주현 금융위원장
# 답변: 의무공개매수제도는 특정 대주주에 대한 프리미엄만 가고, 일반 대주주에게 혜택이 가지 않아 위기 상황에서 M&A를 저해하고 문제가 많다는 이유로 폐지되었습니다.
# 답변_키워드: 의무공개매수제도,  특정 대주주,  프리미엄,  일반 대주주,   M&A
# 글 길이: 422
#
#
# 회의날짜: 2022년10월6일(목)
# 국회_대: 21
# 회의명: 정무위원회
# 회수: 2022
# 차수: 2022년10월06일
# 안건: 감사개시
# 법안: 감사개시
# 질문자_이름: 강병원 위원
# 질문: 의무공개매수제도 폐지 이유는 무엇인가요?
# 질문_키워드: 경영권,  경영권 프리미엄,  선진국,  의무공개매수제도,  일반 투자자 보호
# 문맥: 의무공개매수제도는 특정 대주주에 대한 프리미엄만 부여되고, 일반 대주주에게 혜택이 가지 않아 M&A 저해와 문제 발생 우려로 인해 폐지되었습니다.
# 답변자_이름: 김주현 금융위원장
# 답변: 의무공개매수제도는 특정 대주주에 대한 프리미엄만 가고, 일반 대주주에게 혜택이 가지 않아 위기 상황에서 M&A를 저해하고 문제가 많다는 이유로 폐지되었습니다.
# 답변_키워드: 의무공개매수제도,  특정 대주주,  프리미엄,  일반 대주주,   M&A

# %%
from langchain.chains import RetrievalQAWithSourcesChain
from langchain_upstage import ChatUpstage
from langchain_community.chat_models import ChatOpenAI

llm = ChatOpenAI(model_name='gpt-4o', temperature=0)
qa_with_source = RetrievalQAWithSourcesChain.from_chain_type(llm=llm,
                                 chain_type="stuff",
                                 retriever=big_chunk_retriever, return_source_documents=True)

# %%
retrieved_docs
# Out:
# [Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=045004&fileType=PDF', 'row': 1957}, page_content='회의날짜: 2015년4월1일(수)\n국회_대: 19\n회의명: 정치개혁특별위원회\n회수: 제331회\n차수: 제2차\n안건: 현안보고- 중앙선거관리위원회\n법안: 없음\n질문자_이름: 박영선 위원\n질문: 선관위가 오픈 프라이머리의 종류를 고려하고 있을 때, 어떤 형태의 완전 국민경선을 고려하고 있나요?\n질문_키워드: 오픈, 프라이머리, 가능, 답변, 정당, 후보, 추천, 민주성\n문맥: 선관위는 완전 국민경선을 구상하고 있으며, 이는 일반적인 오픈 프라이머리의 한 형태로 당원뿐만 아니라 일반 국민 모두가 어떤 정당의 프라이머리에 자유롭게 참여할 수 있는 방식입니다. 이는 특정 정당의 당원들이 자신들의 정당에만 참여하는 것이 아닌, 당원과 비당원을 포함한 모든 국민이 자율적으로 참여할 수 있는 오픈 프라이머리입니다. 선관위가 고려하고 있는 시스템은 선거인명부를 관에서 직권으로 작성하는 방식을 포함하며, 이는 당원이 아닌 국민들까지도 모든 정당의 오픈 프라이머리에 참여할 수 있다는 점에서 완전 국민경선의 개념을 담고 있습니다. 이렇게 함으로써 정당 후보자 추천의 민주성을 강화하고자 하는 선관위의 의도가 반영된 것입니다.\n답변자_이름: 김용희 중앙선거관리위원회 사무총장\n답변: 선관위는 완전 국민경선을 구상하고 있으며, 이는 당원과 일반 국민 모두가 어느 정당의 오픈 프라이머리에 자유롭게 참여할 수 있는 형태로, 선거인명부를 관에서 직권으로 작성하는 방식을 고려하고 있습니다.\n답변_키워드: 오픈, 프라이머리, 참여, 형태, 당원, 정당, 일반'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=036077&fileType=PDF', 'row': 2728}, page_content='회의날짜: 2007年7月18日(水)\n국회_대: 17\n회의명: 정치관계법특별위원회\n회수: 제268회\n차수: 제4차\n안건: 공직선거법 개정안(완전국민참여 경선 제도 도입)에 관한 공청회\n법안: 없음\n질문자_이름: 장윤석 위원\n질문: 제안된 법률에 따른 오픈 프라이머리 시스템이 현실적으로 어떤 문제점을 가지고 있으며, 투표자의 자격과 전과 여부를 확인하기 위해 필요한 시스템을 구축하는 것은 어려울까요?\n질문_키워드: 당내경선,  오픈 프라이머리,  투표,  선거권,  당원\n문맥: 제안된 오픈 프라이머리 시스템은 현실적으로 수많은 문제점을 안고 있습니다. 관리상의 복잡성과 전체적인 선거법 체계와의 호환이 큰 도전 중 하나입니다. 현행 법률은 새로운 시스템의 구현에 있어 다양한 제약을 부과하며, 이를 해결하지 않으면 실행 자체가 어렵습니다. 더불어, 오픈 프라이머리 도입을 위해선 투표자의 자격 여부와 전과 여부 등을 확인할 수 있는 데이터베이스와 그를 실시간으로 조회할 수 있는 시스템의 구축이 필수적이지만, 이는 기술적, 법률적 난제를 수반합니다. 기술적 가능성에도 불구하고, 다른 당의 당원 명부, 경선 선거인 명부, 공무원 명단, 교사 명단 등 필요 자료의 확보에 대한 법적 근거와 절차가 마련되지 않았기 때문입니다. 즉, 새 시스템의 통합과 기존 법률의 변경 없이는 효과적인 검증이 어려워, 제약이 많은 기존 체계 안에서 불가능한 상황인 것입니다. 따라서 오픈 프라이머리 시스템이 현실에서 작동하려면 법률 개정 및 시스템 개발이 병행되어야 하는데, 이는 상당한 시간과 노력이 요구되는 복잡한 과정입니다.\n답변자_이름: 한승철 중앙선거관리위원회 법제기획관\n답변: 제안된 법률에 따른 오픈 프라이머리 시스템이 현실적으로 다수의 문제점을 가지고 있습니다. 첫째, 이러한 시스템의 운영은 관리상의 어려움을 초래할 수 있으며 전체적인 선거법 체계와 관련이 있습니다. 현재의 선거법 및 법률은 오픈 프라이머리의 운영을 효과적으로 제한하거나 다양한 제약을 가지고 있어서 새로운 시스템의 도입과 기존 법률 체계의 호환성 문제가 발생할 수 있습니다. 두 번째, 오픈 프라이머리 시스템에서 투표자의 자격 및 전과 여부를 확인하기 위해서는 다양한 데이터와 정보를 실시간으로 확인하고 관리해야 합니다. 이는 기술적으로 가능할 수 있지만, 다른 당의 당원 명부, 경선 선거인 명부, 공무원 명단, 교사 명단과 같은 자료의 확보와 처리가 어려울 수 있습니다. 따라서 오픈 프라이머리 시스템을 실현하기 위해서는 기존 법률 및 시스템과의 호환성을 고려하고, 효과적인 자격 및 전과 확인 시스템을 구축하는 데 상당한 어려움이 있을 것으로 보입니다.\n답변_키워드: 실시간 조회 시스템,  당원,  경선,  선거인,  선거법')]

# %%
big_chunk_retriever = ParentDocumentRetriever(
vectorstore=vectorstore,
docstore=store,
child_splitter=child_splitter,
search_kwargs={"k": 5})

# %%
sub_docs = vectorstore.similarity_search("오픈 프라이머리")

print("글 길이: {}\n\n".format(len(sub_docs[0].page_content)))
print(sub_docs[0].page_content)

retrieved_docs = big_chunk_retriever.invoke("오픈 프라이머리")

print("글 길이: {}\n\n".format(len(retrieved_docs[0].page_content)))
print(retrieved_docs[0].page_content)
# Out:
# 글 길이: 181
#
#
# 답변자_이름: 김용희 중앙선거관리위원회 사무총장
# 답변: 선관위는 완전 국민경선을 구상하고 있으며, 이는 당원과 일반 국민 모두가 어느 정당의 오픈 프라이머리에 자유롭게 참여할 수 있는 형태로, 선거인명부를 관에서 직권으로 작성하는 방식을 고려하고 있습니다.
# 답변_키워드: 오픈, 프라이머리, 참여, 형태, 당원, 정당, 일반
# 글 길이: 750
#
#
# 회의날짜: 2015년4월1일(수)
# 국회_대: 19
# 회의명: 정치개혁특별위원회
# 회수: 제331회
# 차수: 제2차
# 안건: 현안보고- 중앙선거관리위원회
# 법안: 없음
# 질문자_이름: 박영선 위원
# 질문: 선관위가 오픈 프라이머리의 종류를 고려하고 있을 때, 어떤 형태의 완전 국민경선을 고려하고 있나요?
# 질문_키워드: 오픈, 프라이머리, 가능, 답변, 정당, 후보, 추천, 민주성
# 문맥: 선관위는 완전 국민경선을 구상하고 있으며, 이는 일반적인 오픈 프라이머리의 한 형태로 당원뿐만 아니라 일반 국민 모두가 어떤 정당의 프라이머리에 자유롭게 참여할 수 있는 방식입니다. 이는 특정 정당의 당원들이 자신들의 정당에만 참여하는 것이 아닌, 당원과 비당원을 포함한 모든 국민이 자율적으로 참여할 수 있는 오픈 프라이머리입니다. 선관위가 고려하고 있는 시스템은 선거인명부를 관에서 직권으로 작성하는 방식을 포함하며, 이는 당원이 아닌 국민들까지도 모든 정당의 오픈 프라이머리에 참여할 수 있다는 점에서 완전 국민경선의 개념을 담고 있습니다. 이렇게 함으로써 정당 후보자 추천의 민주성을 강화하고자 하는 선관위의 의도가 반영된 것입니다.
# 답변자_이름: 김용희 중앙선거관리위원회 사무총장
# 답변: 선관위는 완전 국민경선을 구상하고 있으며, 이는 당원과 일반 국민 모두가 어느 정당의 오픈 프라이머리에 자유롭게 참여할 수 있는 형태로, 선거인명부를 관에서 직권으로 작성하는 방식을 고려하고 있습니다.
# 답변_키워드: 오픈, 프라이머리, 참여, 형태, 당원, 정당, 일반

# %%
retrieved_docs
# Out:
# [Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=045004&fileType=PDF', 'row': 1957}, page_content='회의날짜: 2015년4월1일(수)\n국회_대: 19\n회의명: 정치개혁특별위원회\n회수: 제331회\n차수: 제2차\n안건: 현안보고- 중앙선거관리위원회\n법안: 없음\n질문자_이름: 박영선 위원\n질문: 선관위가 오픈 프라이머리의 종류를 고려하고 있을 때, 어떤 형태의 완전 국민경선을 고려하고 있나요?\n질문_키워드: 오픈, 프라이머리, 가능, 답변, 정당, 후보, 추천, 민주성\n문맥: 선관위는 완전 국민경선을 구상하고 있으며, 이는 일반적인 오픈 프라이머리의 한 형태로 당원뿐만 아니라 일반 국민 모두가 어떤 정당의 프라이머리에 자유롭게 참여할 수 있는 방식입니다. 이는 특정 정당의 당원들이 자신들의 정당에만 참여하는 것이 아닌, 당원과 비당원을 포함한 모든 국민이 자율적으로 참여할 수 있는 오픈 프라이머리입니다. 선관위가 고려하고 있는 시스템은 선거인명부를 관에서 직권으로 작성하는 방식을 포함하며, 이는 당원이 아닌 국민들까지도 모든 정당의 오픈 프라이머리에 참여할 수 있다는 점에서 완전 국민경선의 개념을 담고 있습니다. 이렇게 함으로써 정당 후보자 추천의 민주성을 강화하고자 하는 선관위의 의도가 반영된 것입니다.\n답변자_이름: 김용희 중앙선거관리위원회 사무총장\n답변: 선관위는 완전 국민경선을 구상하고 있으며, 이는 당원과 일반 국민 모두가 어느 정당의 오픈 프라이머리에 자유롭게 참여할 수 있는 형태로, 선거인명부를 관에서 직권으로 작성하는 방식을 고려하고 있습니다.\n답변_키워드: 오픈, 프라이머리, 참여, 형태, 당원, 정당, 일반'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=036077&fileType=PDF', 'row': 2728}, page_content='회의날짜: 2007年7月18日(水)\n국회_대: 17\n회의명: 정치관계법특별위원회\n회수: 제268회\n차수: 제4차\n안건: 공직선거법 개정안(완전국민참여 경선 제도 도입)에 관한 공청회\n법안: 없음\n질문자_이름: 장윤석 위원\n질문: 제안된 법률에 따른 오픈 프라이머리 시스템이 현실적으로 어떤 문제점을 가지고 있으며, 투표자의 자격과 전과 여부를 확인하기 위해 필요한 시스템을 구축하는 것은 어려울까요?\n질문_키워드: 당내경선,  오픈 프라이머리,  투표,  선거권,  당원\n문맥: 제안된 오픈 프라이머리 시스템은 현실적으로 수많은 문제점을 안고 있습니다. 관리상의 복잡성과 전체적인 선거법 체계와의 호환이 큰 도전 중 하나입니다. 현행 법률은 새로운 시스템의 구현에 있어 다양한 제약을 부과하며, 이를 해결하지 않으면 실행 자체가 어렵습니다. 더불어, 오픈 프라이머리 도입을 위해선 투표자의 자격 여부와 전과 여부 등을 확인할 수 있는 데이터베이스와 그를 실시간으로 조회할 수 있는 시스템의 구축이 필수적이지만, 이는 기술적, 법률적 난제를 수반합니다. 기술적 가능성에도 불구하고, 다른 당의 당원 명부, 경선 선거인 명부, 공무원 명단, 교사 명단 등 필요 자료의 확보에 대한 법적 근거와 절차가 마련되지 않았기 때문입니다. 즉, 새 시스템의 통합과 기존 법률의 변경 없이는 효과적인 검증이 어려워, 제약이 많은 기존 체계 안에서 불가능한 상황인 것입니다. 따라서 오픈 프라이머리 시스템이 현실에서 작동하려면 법률 개정 및 시스템 개발이 병행되어야 하는데, 이는 상당한 시간과 노력이 요구되는 복잡한 과정입니다.\n답변자_이름: 한승철 중앙선거관리위원회 법제기획관\n답변: 제안된 법률에 따른 오픈 프라이머리 시스템이 현실적으로 다수의 문제점을 가지고 있습니다. 첫째, 이러한 시스템의 운영은 관리상의 어려움을 초래할 수 있으며 전체적인 선거법 체계와 관련이 있습니다. 현재의 선거법 및 법률은 오픈 프라이머리의 운영을 효과적으로 제한하거나 다양한 제약을 가지고 있어서 새로운 시스템의 도입과 기존 법률 체계의 호환성 문제가 발생할 수 있습니다. 두 번째, 오픈 프라이머리 시스템에서 투표자의 자격 및 전과 여부를 확인하기 위해서는 다양한 데이터와 정보를 실시간으로 확인하고 관리해야 합니다. 이는 기술적으로 가능할 수 있지만, 다른 당의 당원 명부, 경선 선거인 명부, 공무원 명단, 교사 명단과 같은 자료의 확보와 처리가 어려울 수 있습니다. 따라서 오픈 프라이머리 시스템을 실현하기 위해서는 기존 법률 및 시스템과의 호환성을 고려하고, 효과적인 자격 및 전과 확인 시스템을 구축하는 데 상당한 어려움이 있을 것으로 보입니다.\n답변_키워드: 실시간 조회 시스템,  당원,  경선,  선거인,  선거법'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=045059&fileType=PDF', 'row': 1530}, page_content='회의날짜: 2015년4월8일(수)\n국회_대: 19\n회의명: 정치개혁특별위원회\n회수: 제332회\n차수: 제3차\n안건: 정치자금법 개정에 관한 청원(진선미 의원의 소개로 제출)\n법안: 정치자금법 일부개정법률안\n질문자_이름: 박대동 위원\n질문: 오픈 프라이머리와 관련하여, 선관위에서 의견이 합치지 않을 경우 어떤 특별한 대안이 고려될 수 있을까요?\n질문_키워드: 프라이머리,  시행,  상대적,  부작용\n문맥: 오픈 프라이머리와 관련하여, 선거관리위원회(선관위)에서 의견 합치가 어려울 경우 고려될 수 있는 특별한 대안은 제도적 해결보다는 정당 간의 선택과 협의에 의존할 가능성이 높습니다. 특히 여야가 오픈 프라이머리를 같은 날 시행하는 방안에 동의하지 않는 상황에서 부작용을 줄이기 위해 정당들이 상호 협의를 통해 결정을 내리는 것이 중요하다고 할 수 있습니다. 어느 한 정당이 오픈 프라이머리를 시행하지 않기로 결정했을 경우, 표차가 근소하다면 역선택의 문제가 발생할 수 있는데, 이러한 역선택은 다른 정당에서도 오픈 프라이머리를 포기함으로써 방지하게 될 것입니다. 선관위는 이런 상황에서 각 정당이 문제를 해결하기 위한 선택을 하고 협의해 나가게 함으로써 각 정당이 역선택의 위험을 고려하여 스스로 오픈 프라이머리의 시행 여부를 결정하도록 유도하겠다는 입장을 밝히고 있습니다.\n답변자_이름: 김용희 중앙선거관리위원회 사무총장\n답변: 선관위에서 의견 합치기 어려운 경우, 정당은 오픈 프라이머리를 적용할지 여부를 상대 정당과 협의하고, 표차가 근소하다면 역선택 문제로부터 자유로울 수 있도록 합의에 도달할 수 있습니다.\n답변_키워드: 정당,  제도적')]

# %%
df.columns
# Out:
# Index(['출처', 'id', '회의날짜', '국회_대', '회의명', '회수', '차수', '안건', '법안', '질문자_이름',
#        '질문', '질문_키워드', '문맥', '답변자_이름', '답변', '답변_키워드'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_csv('final_training.csv', index_col=0)

df = df[['출처', 'id', '회의날짜', '질문자_이름',
       '질문', '질문_키워드', '답변자_이름', '문맥(context)', '실제 답변', '답변_키워드', '국회_대', '회의명', '회수', '차수', '안건', '법안']]
df.head()
# Out:
#                                                   출처     id           회의날짜  \
# 0  http://likms.assembly.go.kr/record/mhs-10-040-...  46416  2016년9월23일(금)
# 1  http://likms.assembly.go.kr/record/mhs-10-040-...  47966  2018년2월07일(수)
# 2  http://likms.assembly.go.kr/record/mhs-10-040-...  49896  2020년3월04일(수)
# 3  http://likms.assembly.go.kr/record/mhs-10-040-...  49412  2019년9월27일(금)
# 4  http://likms.assembly.go.kr/record/mhs-10-040-...  49012  2019년3월20일(수)
#
#     질문자_이름                                                 질문  \
# 0   전재수 의원  미르재단 설립 허가 신청서는 어디서 접수되었으며, 그 처리과정에 대해 어떠한 절차가...
# 1   유은혜 의원  추가 조사에서 교수의 직계가족을 대상으로 한정한 것에 따른 부정행위의 미비한 조사 ...
# 2  홍문표  의원  홍성군에서 발생하는 폐기물 처리장 건설 및 지역 주민 반대에 대한 대응은 어떻게 할...
# 3   민홍철 의원  왜 함박도와 관련된 지역에 대해 40년 동안 현장조사나 초소 설치와 같은 행위가 이...
# 4   윤상현 의원  핵무기 확산 가능성에 대비하여 어떠한 대응책과 국제사회와의 협조 방안을 고려하고 있나요?
#
#                                           질문_키워드             답변자_이름  \
# 0  미르재단,  설립,  허가,  대중문화산업과,  직원,  세종시,  청사,  근무     조윤선 문화체육관광부 장관
# 1      추가,  조사,  대상,  직계가족,  친인척,  자녀,  공저자,  제외  김상곤 교육부 부총리겸교육부장관
# 2                                      폐기물,  처리장         조명래 환경부 장관
# 3                                     함박도,  현장조사         정경두 국방부 장관
# 4                 핵무기,  확산,  가능성,  지구적,  재앙,  담보         정경두 국방부 장관
#
#                                          문맥(context)  \
# 0  미르재단 설립 허가 신청서의 접수와 처리과정은 문화체육관광부의 대중문화산업과에서 담...
# 1  추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입공정성...
# 2  지역 주민들의 반대에도 불구하고 홍성군 갈산면 오두리에 폐기물 처리장 건설 계획이 ...
# 3  함박도와 관련한 40년간의 현장조사 또는 초소 설치 등의 행위가 이루어지지 않은 이...
# 4  현대의 글로벌 안보 상황에서 핵무기의 확산은 심각한 위협으로 다가올 수 있습니다. ...
#
#                                                실제 답변  \
# 0  미르재단 설립 허가 신청은 대중문화산업과에서 접수되었고, 이메일을 통한 초기 신청 ...
# 1  네, 추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입...
# 2  현재 폐기물 정책 전반의 대전환을 고려하고, 발생지 처리 원칙을 포함한 폐기물 관리...
# 3  현장조사 및 행정조치 부재는 관할권 문제와 관련이 있습니다. 정전협정 시점부터 북한...
# 4   핵 확산을 단호하게 허용할 수 없다는 입장을 갖고 있으며, 해당 위협이 나타날 경...
#
#                                               답변_키워드  국회_대    회의명     회수   차수  \
# 0                       서울,  이메일,  접수,  서류,  직원,  출장    20  국회본회의  제346회  제8차
# 1                     직계자녀,  대입공정성강화추진점검단,  점검단,  조사    20  국회본회의  제356회  제7차
# 2                                    폐기물,  처리,  지역주민    20  국회본회의  제376회  제7차
# 3  관할권,  문제,  확인,  행정조치,  국방부,  잘못,  현장조사,  검증팀, ...    20  국회본회의  제371회  제3차
# 4                       핵,  확산,  단호,  허용,  국제사회,  공조    20  국회본회의  제367회  제6차
#
#                     안건  법안
# 0      교육․사회․문화에 관한 질문  없음
# 1  교육․사회․문화에 관한 질문(계속)  없음
# 2      교육․사회․문화에 관한 질문  없음
# 3      외교․통일․안보에 관한 질문  없음
# 4      외교․통일․안보에 관한 질문  없음

# %%
df.to_csv('final_training.csv')

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
loader = CSVLoader(file_path='final_training.csv',
                   source_column='출처',
                   content_columns=['회의날짜', '질문자_이름',
       '질문', '질문_키워드', '답변자_이름', '문맥(context)', '실제 답변', '답변_키워드', '국회_대', '회의명', '회수', '차수', '안건', '법안'])

docs = loader.load()

# %%
print(docs[0])
# Out:
# page_content='회의날짜: 2016년9월23일(금)
# 질문자_이름: 전재수 의원
# 질문: 미르재단 설립 허가 신청서는 어디서 접수되었으며, 그 처리과정에 대해 어떠한 절차가 따라졌는지 설명해 주실 수 있나요?
# 질문_키워드: 미르재단,  설립,  허가,  대중문화산업과,  직원,  세종시,  청사,  근무
# 답변자_이름: 조윤선 문화체육관광부 장관
# 문맥(context): 미르재단 설립 허가 신청서의 접수와 처리과정은 문화체육관광부의 대중문화산업과에서 담당되었으며, 이 과정은 전형적인 부처의 업무 프로세스를 따랐습니다. 초기에 신청서는 이메일로 접수되었고, 이후 서울에 출장 중이던 담당 직원이 실물 서류를 받아서 처리하게 되었습니다. 이 직원은 문체부 서울 사무실에서 법인 설립 허가서를 받아 그날 저녁 나루, 즉 문서 등록 시스템에 기안을 올렸습니다. 직후 해당 사무관과 과장이 세종시 문체부 본부에서 각각 결재를 진행했습니다. 이러한 신속한 결재 과정은 비일비재하게 야근을 하는 공무원들의 업무 패턴 중 하나로 볼 수 있으나, 이 경우 그 속도와 시간대가 일반적인 관행과 다소 차이가 있어 눈길을 끌었습니다.
# 실제 답변: 미르재단 설립 허가 신청은 대중문화산업과에서 접수되었고, 이메일을 통한 초기 신청 후 서울 출장 중인 직원이 직접 실질적인 서류를 서울에서 전달받은 것으로 알고 있습니다. 처리과정은 해당 부서의 업무 절차에 따라 진행되었습니다.
# 답변_키워드: 서울,  이메일,  접수,  서류,  직원,  출장
# 국회_대: 20
# 회의명: 국회본회의
# 회수: 제346회
# 차수: 제8차
# 안건: 교육․사회․문화에 관한 질문
# 법안: 없음' metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046416&fileType=PDF', 'row': 0}

# %% [markdown]
# ## 법안, 안건 변수 추가 전처리

# %%
import pandas as pd
df = pd.read_csv('final_training.csv', index_col=0)
df.head()
# Out:
#                                                   출처     id           회의날짜  \
# 0  http://likms.assembly.go.kr/record/mhs-10-040-...  46416  2016년9월23일(금)
# 1  http://likms.assembly.go.kr/record/mhs-10-040-...  47966  2018년2월07일(수)
# 2  http://likms.assembly.go.kr/record/mhs-10-040-...  49896  2020년3월04일(수)
# 3  http://likms.assembly.go.kr/record/mhs-10-040-...  49412  2019년9월27일(금)
# 4  http://likms.assembly.go.kr/record/mhs-10-040-...  49012  2019년3월20일(수)
#
#    국회_대    회의명     회수   차수                   안건  법안   질문자_이름  \
# 0    20  국회본회의  제346회  제8차      교육․사회․문화에 관한 질문  없음   전재수 의원
# 1    20  국회본회의  제356회  제7차  교육․사회․문화에 관한 질문(계속)  없음   유은혜 의원
# 2    20  국회본회의  제376회  제7차      교육․사회․문화에 관한 질문  없음  홍문표  의원
# 3    20  국회본회의  제371회  제3차      외교․통일․안보에 관한 질문  없음   민홍철 의원
# 4    20  국회본회의  제367회  제6차      외교․통일․안보에 관한 질문  없음   윤상현 의원
#
#                                                   질문  \
# 0  미르재단 설립 허가 신청서는 어디서 접수되었으며, 그 처리과정에 대해 어떠한 절차가...
# 1  추가 조사에서 교수의 직계가족을 대상으로 한정한 것에 따른 부정행위의 미비한 조사 ...
# 2  홍성군에서 발생하는 폐기물 처리장 건설 및 지역 주민 반대에 대한 대응은 어떻게 할...
# 3  왜 함박도와 관련된 지역에 대해 40년 동안 현장조사나 초소 설치와 같은 행위가 이...
# 4  핵무기 확산 가능성에 대비하여 어떠한 대응책과 국제사회와의 협조 방안을 고려하고 있나요?
#
#                                           질문_키워드  \
# 0  미르재단,  설립,  허가,  대중문화산업과,  직원,  세종시,  청사,  근무
# 1      추가,  조사,  대상,  직계가족,  친인척,  자녀,  공저자,  제외
# 2                                      폐기물,  처리장
# 3                                     함박도,  현장조사
# 4                 핵무기,  확산,  가능성,  지구적,  재앙,  담보
#
#                                                   문맥             답변자_이름  \
# 0  미르재단 설립 허가 신청서의 접수와 처리과정은 문화체육관광부의 대중문화산업과에서 담...     조윤선 문화체육관광부 장관
# 1  추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입공정성...  김상곤 교육부 부총리겸교육부장관
# 2  지역 주민들의 반대에도 불구하고 홍성군 갈산면 오두리에 폐기물 처리장 건설 계획이 ...         조명래 환경부 장관
# 3  함박도와 관련한 40년간의 현장조사 또는 초소 설치 등의 행위가 이루어지지 않은 이...         정경두 국방부 장관
# 4  현대의 글로벌 안보 상황에서 핵무기의 확산은 심각한 위협으로 다가올 수 있습니다. ...         정경두 국방부 장관
#
#                                                   답변  \
# 0  미르재단 설립 허가 신청은 대중문화산업과에서 접수되었고, 이메일을 통한 초기 신청 ...
# 1  네, 추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입...
# 2  현재 폐기물 정책 전반의 대전환을 고려하고, 발생지 처리 원칙을 포함한 폐기물 관리...
# 3  현장조사 및 행정조치 부재는 관할권 문제와 관련이 있습니다. 정전협정 시점부터 북한...
# 4   핵 확산을 단호하게 허용할 수 없다는 입장을 갖고 있으며, 해당 위협이 나타날 경...
#
#                                               답변_키워드
# 0                       서울,  이메일,  접수,  서류,  직원,  출장
# 1                     직계자녀,  대입공정성강화추진점검단,  점검단,  조사
# 2                                    폐기물,  처리,  지역주민
# 3  관할권,  문제,  확인,  행정조치,  국방부,  잘못,  현장조사,  검증팀, ...
# 4                       핵,  확산,  단호,  허용,  국제사회,  공조

# %%
law_length = df['법안'].apply(lambda x: len(x) if type(x)==str else 0)
agenda_length = df['안건'].apply(lambda x: len(x) if type(x)==str else 0)

# %%
law_only = pd.concat([df['법안'], pd.Series(law_length, name='length')], axis=1)
agenda_only = pd.concat([df['안건'], pd.Series(agenda_length, name='length')], axis=1)

# %%
len(law_only)
# Out:
# 35231

# %%
comma_check = law_only[law_only['법안'].apply(lambda x: ',' in str(x))]
comma_check.sort_values('length').iloc[100:150]
# Out:
#                                                     법안  length
# 30106           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 22031           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 28787           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 28892           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 22158           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 24654           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 24557           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 24461           화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 24684          한국마사회법 일부개정법률안, 전통 소싸움경기에 관한 법률 일부개정법률안      39
# 33169          한국마사회법 일부개정법률안, 전통 소싸움경기에 관한 법률 일부개정법률안      39
# 30187    소방시설공사업법 일부개정법률안,다중이용업소의 안전관리에 관한 특별법 일부개정법률안      45
# 23609  스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47
# 30648  스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47
# 22168  스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47
# 24888  스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47
# 28392  스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47
# 28294  스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47

# %%
def comma_split(x):
    if type(x) == str:
        return x.split(',')
    else:
        return None
law_only['list'] = law_only['법안'].apply(lambda x: comma_split(x))

# %%
law_only['list_length'] = law_only['list'].apply(lambda x: len(x) if type(x)==list else 0)

# %%
law_only.sort_values('list_length', ascending=False).iloc[50:160]
# Out:
#                                                       법안  length  \
# 24697  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 24810  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 34868  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 26611  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 30371  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# ...                                                  ...     ...
# 34567           감염병의 예방 및 관리에 관한 법률 일부개정법률안, 검역법 일부개정법률안      40
# 27343             화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 28294    스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47
# 30291                문재인 정부의 신고리 5, 6호기 공론화위원회 중단 촉구 결의안      35
# 22451                        지방자치법 일부개정법률안,지방자치법 전부개정법률안      27
#
#                                                     list  list_length
# 24697  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 24810  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 34868  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 26611  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 30371  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# ...                                                  ...          ...
# 34567        [감염병의 예방 및 관리에 관한 법률 일부개정법률안,  검역법 일부개정법률안]            2
# 27343          [화재예방,  소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안]            2
# 28294  [스토킹 피해자 보호 및 지원에 관한 법률안, 스토킹방지 및 피해자보호 등에 관한 ...            2
# 30291             [문재인 정부의 신고리 5,  6호기 공론화위원회 중단 촉구 결의안]            2
# 22451                     [지방자치법 일부개정법률안, 지방자치법 전부개정법률안]            2
#
# [110 rows x 4 columns]

# %%
def update_law(x):
    if isinstance(x['list'], list) and len(x['list']) >= 3:
        return x['list'][-1]
    return x['법안']

law_only['법안_new'] = law_only.apply(update_law, axis=1)

# %%
law_only.sort_values('list_length', ascending=False).iloc[50:160]
# Out:
#                                                       법안  length  \
# 24697  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 24810  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 34868  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 26611  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# 30371  최저임금법 일부개정법률안,산업재해보상보험법 일부개정법률안,고용정책 기본법 일부개정법...     341
# ...                                                  ...     ...
# 34567           감염병의 예방 및 관리에 관한 법률 일부개정법률안, 검역법 일부개정법률안      40
# 27343             화재예방, 소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안      38
# 28294    스토킹 피해자 보호 및 지원에 관한 법률안,스토킹방지 및 피해자보호 등에 관한 법률안      47
# 30291                문재인 정부의 신고리 5, 6호기 공론화위원회 중단 촉구 결의안      35
# 22451                        지방자치법 일부개정법률안,지방자치법 전부개정법률안      27
#
#                                                     list  list_length  \
# 24697  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 24810  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 34868  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 26611  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# 30371  [최저임금법 일부개정법률안, 산업재해보상보험법 일부개정법률안, 고용정책 기본법 일부...           15
# ...                                                  ...          ...
# 34567        [감염병의 예방 및 관리에 관한 법률 일부개정법률안,  검역법 일부개정법률안]            2
# 27343          [화재예방,  소방시설 설치․유지 및 안전관리에 관한 법률 일부개정법률안]            2
# 28294  [스토킹 피해자 보호 및 지원에 관한 법률안, 스토킹방지 및 피해자보호 등에 관한 ...            2
# 30291             [문재인 정부의 신고리 5,  6호기 공론화위원회 중단 촉구 결의안]            2
# 22451                     [지방자치법 일부개정법률안, 지방자치법 전부개정법률안]            2
#
#                                                 법안_new
# 24697                   사회적경제기업제품 구매촉진 및 판로지원에 관한 특별법안
# 24810                   사회적경제기업제품 구매촉진 및 판로지원에 관한 특별법안
# 34868                   사회적경제기업제품 구매촉진 및 판로지원에 관한 특별법안
# 26611                   사회적경제기업제품 구매촉진 및 판로지원에 관한 특별법안
# 30371                   사회적경제기업제품 구매촉진 및 판로지원에 관한 특별법안
# ...                                                ...
# 34567         감염병의 예방 및 관리에 관한 법률 일부개정법률안, 검역법 일부개정법률안
# 2529   미디어 신뢰도 개선 관련 「언론중재 및 피해구제 등에 관한 법률」 및 「정보통신망 ...          73
# 2564   미디어 신뢰도 개선 관련 「언론중재 및 피해구제 등에 관한 법률」 및 「정보통신망 ...          73
# 3086   미디어 신뢰도 개선 관련 「언론중재 및 피해구제 등에 관한 법률」 및 「정보통신망 ...          73
# 1960   미디어 신뢰도 개선 관련 「언론중재 및 피해구제 등에 관한 법률」 및 「정보통신망 ...          73
# 1667   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3120   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3153   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3606   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3636   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 2358   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 2862   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 2228   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 2709   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3862   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3727   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 1203   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 2826   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3260   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3699   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 3384   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 2259   미디어 생태계 개선 관련 「신문 등의 진흥에 관한 법률」 및 「정보통신망 이용촉진 ...          70
# 29430  개인형 이동수단의 관리 및 이용활성화에 관한 법률 및 개인형 이동수단의 관리 및 이...          68
# 26849  박근혜 정부의 최순실 등 민간인에 의한 국정농단 의혹 사건 규명을 위한 특별검사의 ...          65

# %%
law_only.to_excel('law_only.xlsx')

# %%
law_only['법안_new'] = law_only['법안_new'].apply(lambda x: x.strip() if type(x)==str else x)

# %%
df['법안'] = law_only['법안_new']

# %%
df
# Out:
#                                                       출처     id  \
# 0      http://likms.assembly.go.kr/record/mhs-10-040-...  46416
# 1      http://likms.assembly.go.kr/record/mhs-10-040-...  47966
# 2      http://likms.assembly.go.kr/record/mhs-10-040-...  49896
# 35231   임오경 위원  이행보증보험 제도에 대해서는 고려가 필요하지만, 코로나로 인한 손실에 더해 이행보증...
# 35232   신원식 위원  북한의 군사 전력 강화와 유도 기술 개발에 따라 대한민국은 방어 대비를 어떻게 강화...
#
#                                               질문_키워드  \
# 0      미르재단,  설립,  허가,  대중문화산업과,  직원,  세종시,  청사,  근무
# 1          추가,  조사,  대상,  직계가족,  친인척,  자녀,  공저자,  제외
# 2                                          폐기물,  처리장
# 3                                         함박도,  현장조사
# 4                     핵무기,  확산,  가능성,  지구적,  재앙,  담보
# ...                                              ...
# 35228                             신축적,  정책연구개발비,  삭감
# 35229                              안전보건교육, 수강, 경영책임자
# 35230                     반대,  생각,  저공해,  지원책들,  활성화
# 35231                      실내체육시설업, 연령․종목 제한, 이행보증보험
# 35232                유도, 북한, 방사포, 기능, 대구경, 기술, 업그레이드
#
#                                                       문맥             답변자_이름  \
# 0      미르재단 설립 허가 신청서의 접수와 처리과정은 문화체육관광부의 대중문화산업과에서 담...     조윤선 문화체육관광부 장관
# 1      추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입공정성...  김상곤 교육부 부총리겸교육부장관
# 2      지역 주민들의 반대에도 불구하고 홍성군 갈산면 오두리에 폐기물 처리장 건설 계획이 ...         조명래 환경부 장관
# 3      함박도와 관련한 40년간의 현장조사 또는 초소 설치 등의 행위가 이루어지지 않은 이...         정경두 국방부 장관
# 4      현대의 글로벌 안보 상황에서 핵무기의 확산은 심각한 위협으로 다가올 수 있습니다. ...         정경두 국방부 장관
# ...                                                  ...                ...
# 35228  중앙인사위원회의 자체 조정안을 보면, 정책연구개발비 분야 예산에서 2억 원이 삭감되...   김영호 중앙인사위원회 사무처장
# 35229  산업안전보건법상, 관리책임자는 건설업의 현장소장이나 제조업의 공장장 같은 각급 감독...       박화진 고용노동부 차관
# 35230  920억 원의 세금 감면은 경제적인 효과보다 부정적인 효과가 더 많이 나올 거라 생...     최상목 기획재정부 제1차관
# 35231  실내체육시설업에 대한 이용 연령과 종목 제한은 코로나19 팬데믹 기간 중 엄격한 규...   김정배 문화체육관광부 제2차관
# 35232  대한민국은 북한의 군사 기술 발전에 대비해 전략적으로 무기체계를 강화하고 발전시켜야...       서형진 방위사업청 차장
#
#                                                       답변  \
# 0      미르재단 설립 허가 신청은 대중문화산업과에서 접수되었고, 이메일을 통한 초기 신청 ...
# 1      네, 추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입...
# 2      현재 폐기물 정책 전반의 대전환을 고려하고, 발생지 처리 원칙을 포함한 폐기물 관리...
# 3      현장조사 및 행정조치 부재는 관할권 문제와 관련이 있습니다. 정전협정 시점부터 북한...
# 4       핵 확산을 단호하게 허용할 수 없다는 입장을 갖고 있으며, 해당 위협이 나타날 경...
# ...                                                  ...
# 35228  죄송합니다. 앞서 언급한 예산 삭감 사항은 정부의 지시에 따라 이루어졌으며, 추가 ...
# 35229  산업안전보건법에 따라 감독자뿐만 아니라 관리책임자에게도 안전보건교육 이행 의무가 있...
# 35230  920억 세감 추가는 경제적 효과가 제한적이며 이미 저공해로 분류된 경유차에 대한 ...
# 35231  이행보증보험 제도에 대해서는 고려가 필요하지만, 코로나로 인한 손실에 더해 이행보증...
# 35232  대한민국은 북한의 군사 기술 발전에 대비하기 위해 사단과 군단 간의 화력 차이를 고...
#
#                                                   답변_키워드
# 0                           서울,  이메일,  접수,  서류,  직원,  출장
# 1                         직계자녀,  대입공정성강화추진점검단,  점검단,  조사
# 2                                        폐기물,  처리,  지역주민
# 3      관할권,  문제,  확인,  행정조치,  국방부,  잘못,  현장조사,  검증팀, ...
# 4                           핵,  확산,  단호,  허용,  국제사회,  공조
# ...                                                  ...
# 35228                                            절감,  운영
# 35229                   산업안전보건법, 감독자, 안전보건교육, 관리책임자, 건설업
# 35230                                 발표,  노후,  경유차,  말소
# 35231                         코로나,  영업손실, 이행보증금 , 체육시설업자
# 35232                           화력, 사단급, 군단, 탐지, 자주포, 사단
#
# [35231 rows x 16 columns]

# %%
agenda_only.sort_values('length', ascending=False).head()
# Out:
#                                                       안건  length
# 4101   국제경기대회지원관련 법안(4건)에 대한 공청회o 국제경기대회 개최지원 등에 관한 특...     569
# 19852  2003년도기금운용계획안(계속)부별심사(경제부처)(계속)：국민경제자문회의‧재정경제부...     368
# 2586   2011대구세계육상선수권대회, 2014인천아시아경기대회 및 2015광주하계유니버시아...     315
# 23098  남북교류협력에관한법률중개정법률안에대한수정안(조웅규ㆍ이부영ㆍ원희룡ㆍ김상현ㆍ박종희ㆍ이상...     285
# 21048  군인사법 일부개정법률안(김명자 의원 대표발의)(김명자․강혜숙․구논회․권영길․김재경․...     263

# %%
agenda_only.loc[19852, '안건']
# Out:
# '2003년도기금운용계획안(계속)부별심사(경제부처)(계속)：국민경제자문회의‧재정경제부‧과학기술부‧농림부‧산업자원부‧정보통신부‧보건복지부‧환경부‧노동부‧건설교통부‧해양수산부‧기획예산처‧감사원‧공정거래위원회‧금융감독위원회‧국세청‧관세청‧조달청‧통계청‧기상청‧농촌진흥청‧산림청‧중소기업청‧특허청‧식품의약품안전청‧철도청부별심사(비경제부처)：대통령실‧대통령경호실‧국회‧대법원‧국가안전보장회의‧민주평화통일자문회의‧감사원‧헌법재판소‧중앙선거관리위원회‧국무총리실‧재정경제부‧교육인적자원부‧통일부‧외교통상부‧법무부‧국방부‧행정자치부‧문화관광부‧여성부‧기획예산처‧중앙인사위원회‧부패방지위원회‧방송위원회‧법제처‧국정홍보처‧국가보훈처‧병무청‧경찰청‧문화재청‧해양경찰청‧국가인권위원회'

# %%
df.loc[19852, ['질문','문맥','답변']]
# Out:
# 질문           러시아와의 협상에서 근본적인 타결이 이루어지지 않는 주요 이유는 무엇인가요?
# 문맥    협상 가운데에서 러시아와의 협상에서 근본적인 타결이 이루어지지 않는 주요 이유로는 ...
# 답변     러시아의 경제 어려움과 국제 채권국가들의 특별한 배려 때문에 타결이 어려운 상황입니다.
# Name: 19852, dtype: object

# %%
df.to_csv('final_training.csv')

# %% [markdown]
# ## 문서 splitter를 custom으로 설정하여 문서를 나누자
# - 회의 날짜 등 기본 설명(안건, 법안)
# - 질의 관련
# - 문맥 및 답변 관련

# %%
from langchain.text_splitter import TextSplitter
from langchain.schema import Document

class CustomColumnSplitter(TextSplitter):
    def string_to_dict(self, input_string):
        """
        Convert a given string with key-value pairs separated by newlines into a dictionary.
        """
        result_dict = {}
        for line in input_string.split("\n"):
            if ": " in line:  # Ensure valid key-value format
                key, value = line.split(": ", 1)  # Split only on the first occurrence of ": "
                result_dict[key.strip()] = value.strip()
        return result_dict

    def split_text(self, text):
        """
        text를 열 데이터로 분리하여 문서를 생성합니다.
        """
        # 텍스트를 딕셔너리로 변환 (CSV 행 형태로 가정)
        row_data = self.string_to_dict(text)  # 문자열을 딕셔너리로 변환 (Document에서 가져온 데이터)

        # 열 기준으로 나누기
        doc1 = {
            "회의날짜": row_data.get("회의날짜"),
            "국회_대": row_data.get("국회_대"),
            "회의명": row_data.get("회의명"),
            "회수": row_data.get("회수"),
            "차수": row_data.get("차수"),
            "안건": row_data.get("안건"),
            "법안": row_data.get("법안"),
        }
        doc2 = {
            "질문자_이름": row_data.get("질문자_이름"),
            "질문": row_data.get("질문"),
            "질문_키워드": row_data.get("질문_키워드"),
        }
        doc3 = {
            "답변자_이름": row_data.get("답변자_이름"),
            "문맥(context)": row_data.get("문맥(context)"),
            "실제 답변": row_data.get("실제 답변"),
            "답변_키워드": row_data.get("답변_키워드"),
        }

        # 반환할 문서 리스트
        return [doc1, doc2, doc3]

    def split_documents(self, documents):
        split_docs = []
        for document in documents:
            # 각 Document의 내용을 split_text로 처리
            sub_docs = self.split_text(document.page_content)
            for sub_doc in sub_docs:
                # 새롭게 분리된 데이터를 Document 객체로 변환
                split_docs.append(
                    Document(
                        page_content=str(sub_doc),  # 문자열로 변환
                        metadata=document.metadata,  # 기존 문서의 메타데이터 유지
                    )
                )
        return split_docs


# Splitter 적용
splitter = CustomColumnSplitter()
split_documents = []

for doc in docs:
    split_documents.extend([
        Document(page_content=str(part)) for part in splitter.split_text(doc.page_content)
    ])

# 결과 출력
for idx, doc in enumerate(split_documents, 1):
    print(f"Document {idx}:")
    print(doc.page_content)
    print(doc.metadata)
    if idx == 5:
        break
# Out:
# Document 1:
# {'회의날짜': '2016년9월23일(금)', '국회_대': '20', '회의명': '국회본회의', '회수': '제346회', '차수': '제8차', '안건': '교육․사회․문화에 관한 질문', '법안': '없음'}
# {}
# Document 2:
# {'질문자_이름': '전재수 의원', '질문': '미르재단 설립 허가 신청서는 어디서 접수되었으며, 그 처리과정에 대해 어떠한 절차가 따라졌는지 설명해 주실 수 있나요?', '질문_키워드': '미르재단,  설립,  허가,  대중문화산업과,  직원,  세종시,  청사,  근무'}
# {}
# Document 3:
# {'답변자_이름': '조윤선 문화체육관광부 장관', '문맥(context)': '미르재단 설립 허가 신청서의 접수와 처리과정은 문화체육관광부의 대중문화산업과에서 담당되었으며, 이 과정은 전형적인 부처의 업무 프로세스를 따랐습니다. 초기에 신청서는 이메일로 접수되었고, 이후 서울에 출장 중이던 담당 직원이 실물 서류를 받아서 처리하게 되었습니다. 이 직원은 문체부 서울 사무실에서 법인 설립 허가서를 받아 그날 저녁 나루, 즉 문서 등록 시스템에 기안을 올렸습니다. 직후 해당 사무관과 과장이 세종시 문체부 본부에서 각각 결재를 진행했습니다. 이러한 신속한 결재 과정은 비일비재하게 야근을 하는 공무원들의 업무 패턴 중 하나로 볼 수 있으나, 이 경우 그 속도와 시간대가 일반적인 관행과 다소 차이가 있어 눈길을 끌었습니다.', '실제 답변': '미르재단 설립 허가 신청은 대중문화산업과에서 접수되었고, 이메일을 통한 초기 신청 후 서울 출장 중인 직원이 직접 실질적인 서류를 서울에서 전달받은 것으로 알고 있습니다. 처리과정은 해당 부서의 업무 절차에 따라 진행되었습니다.', '답변_키워드': '서울,  이메일,  접수,  서류,  직원,  출장'}
# {}
# Document 4:
# {'회의날짜': '2018년2월07일(수)', '국회_대': '20', '회의명': '국회본회의', '회수': '제356회', '차수': '제7차', '안건': '교육․사회․문화에 관한 질문(계속)', '법안': '없음'}
# {}
# Document 5:
# {'질문자_이름': '유은혜 의원', '질문': '추가 조사에서 교수의 직계가족을 대상으로 한정한 것에 따른 부정행위의 미비한 조사 우려가 제기되고 있습니다. 부총리를 단장으로 하는 대입공정성강화추진점검단에서 이 문제를 계속적으로 검토하고 고려할 계획이 있나요?', '질문_키워드': '추가,  조사,  대상,  직계가족,  친인척,  자녀,  공저자,  제외'}
# {}

# %%
splitter.split_documents(docs)
# Out:
# [Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046416&fileType=PDF', 'row': 0}, page_content="{'회의날짜': '2016년9월23일(금)', '국회_대': '20', '회의명': '국회본회의', '회수': '제346회', '차수': '제8차', '안건': '교육․사회․문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046416&fileType=PDF', 'row': 0}, page_content="{'질문자_이름': '전재수 의원', '질문': '미르재단 설립 허가 신청서는 어디서 접수되었으며, 그 처리과정에 대해 어떠한 절차가 따라졌는지 설명해 주실 수 있나요?', '질문_키워드': '미르재단,  설립,  허가,  대중문화산업과,  직원,  세종시,  청사,  근무'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046416&fileType=PDF', 'row': 0}, page_content="{'답변자_이름': '조윤선 문화체육관광부 장관', '문맥': '미르재단 설립 허가 신청서의 접수와 처리과정은 문화체육관광부의 대중문화산업과에서 담당되었으며, 이 과정은 전형적인 부처의 업무 프로세스를 따랐습니다. 초기에 신청서는 이메일로 접수되었고, 이후 서울에 출장 중이던 담당 직원이 실물 서류를 받아서 처리하게 되었습니다. 이 직원은 문체부 서울 사무실에서 법인 설립 허가서를 받아 그날 저녁 나루, 즉 문서 등록 시스템에 기안을 올렸습니다. 직후 해당 사무관과 과장이 세종시 문체부 본부에서 각각 결재를 진행했습니다. 이러한 신속한 결재 과정은 비일비재하게 야근을 하는 공무원들의 업무 패턴 중 하나로 볼 수 있으나, 이 경우 그 속도와 시간대가 일반적인 관행과 다소 차이가 있어 눈길을 끌었습니다.', '답변': '미르재단 설립 허가 신청은 대중문화산업과에서 접수되었고, 이메일을 통한 초기 신청 후 서울 출장 중인 직원이 직접 실질적인 서류를 서울에서 전달받은 것으로 알고 있습니다. 처리과정은 해당 부서의 업무 절차에 따라 진행되었습니다.', '답변_키워드': '서울,  이메일,  접수,  서류,  직원,  출장'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=047966&fileType=PDF', 'row': 1}, page_content="{'회의날짜': '2018년2월07일(수)', '국회_대': '20', '회의명': '국회본회의', '회수': '제356회', '차수': '제7차', '안건': '교육․사회․문화에 관한 질문(계속)', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=047966&fileType=PDF', 'row': 1}, page_content="{'질문자_이름': '유은혜 의원', '질문': '추가 조사에서 교수의 직계가족을 대상으로 한정한 것에 따른 부정행위의 미비한 조사 우려가 제기되고 있습니다. 부총리를 단장으로 하는 대입공정성강화추진점검단에서 이 문제를 계속적으로 검토하고 고려할 계획이 있나요?', '질문_키워드': '추가,  조사,  대상,  직계가족,  친인척,  자녀,  공저자,  제외'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=047966&fileType=PDF', 'row': 1}, page_content="{'답변자_이름': '김상곤 교육부 부총리겸교육부장관', '문맥': '추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입공정성강화추진점검단에서는 계속해서 이 문제를 검토하고 고려하여 부정행위에 대한 효과적인 대응을 추진할 예정입니다.', '답변': '네, 추가 조사에서 직계자녀를 우선 대상으로 삼았지만, 부총리를 단장으로 하는 대입공정성강화추진점검단에서는 계속해서 이 문제를 검토하고 고려하여 부정행위에 대한 효과적인 대응을 추진할 예정입니다.', '답변_키워드': '직계자녀,  대입공정성강화추진점검단,  점검단,  조사'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049896&fileType=PDF', 'row': 2}, page_content="{'회의날짜': '2020년3월04일(수)', '국회_대': '20', '회의명': '국회본회의', '회수': '제376회', '차수': '제7차', '안건': '교육․사회․문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049896&fileType=PDF', 'row': 2}, page_content="{'질문자_이름': '홍문표  의원', '질문': '홍성군에서 발생하는 폐기물 처리장 건설 및 지역 주민 반대에 대한 대응은 어떻게 할 계획인가요?', '질문_키워드': '폐기물,  처리장'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049896&fileType=PDF', 'row': 2}, page_content="{'답변자_이름': '조명래 환경부 장관', '문맥': '지역 주민들의 반대에도 불구하고 홍성군 갈산면 오두리에 폐기물 처리장 건설 계획이 진행되고 있습니다. 조명래 환경부장관은 이와 관련하여 총체적인 폐기물 정책의 대전환이 필요하다는 입장을 밝혔습니다. 지역에서 발생하는 폐기물을 지역에서 처리하는 원칙을 법제화하는 방안을 마련할 계획이며, 이는 정부에서 아직 확립하지 못한 원칙입니다. 현재 갈산면 폐기물처리장과 관련해서는 사업자가 평가 초안을 준비 중이고, 평가서가 접수되면 정부는 지역주민들의 의견을 면밀히 검토할 것임을 약속했습니다. 이는 1만 2000명의 홍성군민이 서명한 반대 의견을 신중히 고려하는 것으로, 행정 절차가 문제가 없다 할지라도, 실제 현장에서의 반대가 심각할 때는 해당 사항에 대해 재고해야 한다는 원칙을 제시하였습니다. 정부는 이러한 문제에 대해 관계부처가 한 번 더 깊이 알아보고 적절한 조치를 취하기를 바라고 있습니다.', '답변': '현재 폐기물 정책 전반의 대전환을 고려하고, 발생지 처리 원칙을 포함한 폐기물 관리를 법제화할 계획이 있으며, 갈산면 폐기물처리장 평가서 접수 시 지역 주민의 영향을 면밀히 검토하고 협의 의견을 내도록 할 것입니다.', '답변_키워드': '폐기물,  처리,  지역주민'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049412&fileType=PDF', 'row': 3}, page_content="{'회의날짜': '2019년9월27일(금)', '국회_대': '20', '회의명': '국회본회의', '회수': '제371회', '차수': '제3차', '안건': '외교․통일․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049412&fileType=PDF', 'row': 3}, page_content="{'질문자_이름': '민홍철 의원', '질문': '왜 함박도와 관련된 지역에 대해 40년 동안 현장조사나 초소 설치와 같은 행위가 이루어지지 않았는지 군이나 행정부 등이 노력하지 않았던 이유가 무엇인가요?', '질문_키워드': '함박도,  현장조사'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049412&fileType=PDF', 'row': 3}, page_content="{'답변자_이름': '정경두 국방부 장관', '문맥': '함박도와 관련한 40년간의 현장조사 또는 초소 설치 등의 행위가 이루어지지 않은 이유는 복잡한 관할권 문제와 밀접한 관련이 있습니다. 초기 정전협정 시 모든 자료가 북한의 관할로 명시되었음에도 불구하고 행정적인 조치는 그와 달리 이루어졌으며, 이로 인해 현재 국방부와 다른 관련 부처 및 지자체는 민관 합동 검증팀을 구성하여 이러한 행정 조치의 오류들과 그 원인이 무엇인지에 대한 조사를 진행하고 있습니다. 이 과정에서 발견된 사실들을 국민들에게 명확히 설명하고, 앞으로의 후속 조치를 적절히 취해 나갈 것입니다. 또한, 이 문제와 관계없이 군사적 대비태세는 항상 면밀히 확인되고 있으며, 시설공사 초창기부터 지금에 이르기까지 어떠한 군사적 동향도 파악하면서 완벽하게 준비하고 유지하고 있다는 사실을 분명히 했습니다.', '답변': '현장조사 및 행정조치 부재는 관할권 문제와 관련이 있습니다. 정전협정 시점부터 북한의 관할권으로 확인되었으나, 국방부 및 기타 관련 기관들은 민관 합동 검증팀을 통해 이를 면밀히 조사하고 관련 행정조치의 오류를 규명하고 있습니다. 군사적 대비태세는 항상 확인되고 완벽하게 유지되어 있습니다.', '답변_키워드': '관할권,  문제,  확인,  행정조치,  국방부,  잘못,  현장조사,  검증팀,  시설공사'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049012&fileType=PDF', 'row': 4}, page_content="{'회의날짜': '2019년3월20일(수)', '국회_대': '20', '회의명': '국회본회의', '회수': '제367회', '차수': '제6차', '안건': '외교․통일․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049012&fileType=PDF', 'row': 4}, page_content="{'질문자_이름': '윤상현 의원', '질문': '핵무기 확산 가능성에 대비하여 어떠한 대응책과 국제사회와의 협조 방안을 고려하고 있나요?', '질문_키워드': '핵무기,  확산,  가능성,  지구적,  재앙,  담보'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049012&fileType=PDF', 'row': 4}, page_content="{'답변자_이름': '정경두 국방부 장관', '문맥': '현대의 글로벌 안보 상황에서 핵무기의 확산은 심각한 위협으로 다가올 수 있습니다. 따라서 우리는 핵 확산에 대비하여 국제사회와의 협조를 통해 효과적으로 대응할 계획입니다. 이러한 대응책은 저희의 단호한 입장과 함께 국제사회와의 협조를 통해 실현될 것이며, 우리는 전방위 안보 대비태세를 강화하여 과거보다 더욱 효과적으로 대응할 수 있도록 모든 역량을 집중시키겠습니다.', '답변': '핵 확산을 단호하게 허용할 수 없다는 입장을 갖고 있으며, 해당 위협이 나타날 경우 국제사회와 협조하여 효과적으로 막을 계획입니다.', '답변_키워드': '핵,  확산,  단호,  허용,  국제사회,  공조'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=028876&fileType=PDF', 'row': 5}, page_content="{'회의날짜': '2001년2월15일(목)', '국회_대': '16', '회의명': '국회본회의', '회수': '제218회', '차수': '제5차', '안건': '사회‧문화에관한질문(계속)', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=028876&fileType=PDF', 'row': 5}, page_content="{'질문자_이름': '김용균 의원', '질문': '국민의 정부에서 국가보안법이 악용되었나요?', '질문_키워드': '국민, 정부, 국가보안법, 악용'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=028876&fileType=PDF', 'row': 5}, page_content="{'답변자_이름': '이한동 국무총리', '문맥': '총리의 답변을 바탕으로 말씀 드리겠습니다. 총리는 국가보안법이 오래 전 권위주의 시대에 자의적 해석으로 인해 문제될 수 있었을 것이라고 언급하면서도, 현재는 그런 일이 없다고 생각한다고 말씀하셨습니다. 이에 따라 국민의 정부에서는 국가보안법의 악용이 없었을 것으로 판단하고 있습니다.', '답변': '국민의 정부에서는 국가보안법이 오래 전의 권위주의 시대에는 자의적 해석이 문제가 되었을 수 있지만 현재는 그런 일이 없었을 것으로 생각합니다.', '답변_키워드': '국가보안법, 권위주의시대, 자의적, 인권'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023610&fileType=PDF', 'row': 6}, page_content="{'회의날짜': '1997년2월26일(수)', '국회_대': '15', '회의명': '국회본회의', '회수': '제183회', '차수': '제8차', '안건': '경제에 관한 질문(계속)', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023610&fileType=PDF', 'row': 6}, page_content="{'질문자_이름': '박광태 의원', '질문': '특별검사제 도입에 대한 입장을 설명해 주시겠습니까?', '질문_키워드': '특별검사제'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023610&fileType=PDF', 'row': 6}, page_content="{'답변자_이름': '이수성 국무총리', '문맥': '특별검사제에 대한 여러분의 우려와 의견에 대해 깊이 고민하였으며, 정부로서는 특별검사제 도입을 신중히 검토하였지만, 현재로서는 이를 도입할 계획이 없음을 명백히 밝힙니다. 우리는 검찰이 준사법기관으로서의 충분한 자격과 능력을 갖추고 있으며, 나아가 공정하고 열심히 수사를 진행하고 있다고 믿고 있습니다. 검찰이 수사하는 동안 누구의 압력에도 흔들리지 않고, 오로지 사실에 근거하여 열심히 임하고 있음이 검찰로부터 전달받은 바입니다. 또한 정부는 검찰과 경찰의 수사가 국민의 신뢰를 얻을 수 있도록 지속적으로 격려하고 지원하며, 국민들이 만족할 수 있는 결과가 도출될 수 있도록 지도하는 역할을 다하고 있습니다. 그러나 이러한 노력에도 불구하고, 국민에게 신뢰를 받지 못한다면, 이는 실로 불행한 일임을 저 역시 잘 알고 있으며, 이에 대해 정부는 현재와 같은 정상적인 수사 절차를 지키면서도 국민들의 믿음을 얻기 위한 추가적인 방안을 모색해 나갈 것입니다.', '답변': '특별검사제 도입에 대해서 정부는 타당하지 않다고 판단하고 검찰의 열심한 수사를 지지하고 있으며 국민의 신뢰를 얻을 수 있도록 지도와 지원을 제공하고 있다.', '답변_키워드': '특별검사제'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023604&fileType=PDF', 'row': 7}, page_content="{'회의날짜': '1996년10월30일(수)', '국회_대': '15', '회의명': '국회본회의', '회수': '제181회', '차수': '제12차', '안건': '경제에 관한 질문(계속)', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023604&fileType=PDF', 'row': 7}, page_content="{'질문자_이름': '이응선 의원', '질문': '정보통신 및 소프트웨어 산업을 육성하기 위한 대책과 정보통신산업의 규제 완화 계획은 어떠한가?', '질문_키워드': '정보통신산업,  규제'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023604&fileType=PDF', 'row': 7}, page_content="{'답변자_이름': '강봉균 정보통신부 장관', '문맥': '정부는 정보통신 및 소프트웨어 산업을 전략 산업으로 육성할 계획을 가지고 있으며, 이를 위해 규제 완화와 함께 산업 활성화를 위한 제도적 지원을 강화하고 있다. 정보통신부는 통신사업과 관련된 기본법 및 사업법을 대폭 개정해 경쟁을 제약하는 규제를 줄이고, 공공기관의 정보화 관련 예산 중 일정 비율을 소프트웨어 구입비로 편성하여 소프트웨어 산업의 수요를 안정적으로 확보한다는 방침이다. 또한 창업 지원을 위해 창업보육센터를 설립하고 재정 및 기술 지원을 확대하며, 정보통신 관련 전문인력 양성을 위한 전문 대학원 설립 및 대학 연구비 지원을 계획하고 있다. 이 외에도 해외 시장 진출을 위한 협력 방안 마련도 중요한 과제로 보고 있다. 정부는 관련 내용을 정보통신산업육성종합대책의 형태로 다음 달 중에 종합적으로 발표할 예정이며, 관련 내용은 향후 상임위원회 보고를 통해 상세히 안내될 것이다.', '답변': '정부는 정보통신 및 소프트웨어 산업 육성을 위해 규제 완화, 수요 확보, 창업 지원, 전문인력 양성 등 다양한 조치를 취하고 있으며, 상장위원회를 통해 관련 내용을 상세히 보고할 예정이다.', '답변_키워드': '정보통신산업,  규제'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050202&fileType=PDF', 'row': 8}, page_content="{'회의날짜': '2020년9월17일(목)', '국회_대': '21', '회의명': '국회본회의', '회수': '제382회', '차수': '제7차', '안건': '교육·사회·문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050202&fileType=PDF', 'row': 8}, page_content="{'질문자_이름': '오영환 의원', '질문': '장관님께서는 최근의 대형 재난 상황을 마주하며 대응에 있어서 개선해야 할 점이 있다고 생각하십니까?', '질문_키워드': '예방,  재난․재해,  민생․사회 문제,  법무부장관,  국가 차원의 대응,  국회예산정책처,  행정안전부장관,  개선'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050202&fileType=PDF', 'row': 8}, page_content='{\'답변자_이름\': \'진영 행정안전부 장관\', \'문맥\': "제가 작성한 답변은 다음과 같습니다.\'제가 느낀 점은, 현재의 재난관리 체계에서는 여러 대형 재난 상황에 충분한 대비와 대응을 하지 못했다는 점입니다. 특히 최근 발생한 대형 화재, 집중호우, 감염병과 같은 재난에서는 대응이 미흡하여 많은 희생자와 피해가 발생하였습니다. 이를 통해 우리는 여전히 대응 능력이 부족하다는 사실을 인식하고, 이번 기회를 통해 자연재해 대응을 위한 대비책과 대응 능력을 더욱 향상시켜야 한다는 것을 명백하게 깨닫게 되었습니다.\'", \'답변\': \'예, 저희는 이번에 대형 화재, 집중호우, 감염병과 같은 국가적 재난 상황에서 충분히 대응하지 못했기 때문에 많은 희생자와 피해가 발생하였습니다. 집중호우로 인한 사망자 46명과 실종자 3명과 같은 인명 피해가 발생한 것은 매우 안타까운 일입니다. 이를 통해 저희는 아직도 대응 능력이 미흡하다는 것을 깨달았고, 이번 기회를 통해 자연재해 대응을 위한 대비책과 대응 능력을 한층 향상시켜야 한다는 것을 뼈저리게 느끼고 있습니다.\', \'답변_키워드\': \'대응능력,  기회,  미흡,  대비책\'}'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049415&fileType=PDF', 'row': 9}, page_content="{'회의날짜': '2019년9월30일(월)', '국회_대': '20', '회의명': '국회본회의', '회수': '제371회', '차수': '제4차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049415&fileType=PDF', 'row': 9}, page_content="{'질문자_이름': '윤한홍 위원', '질문': '조국 사태로 인한 청년들의 상실감과 절망에 대해 대통령이 사과하는 것은 어려우시더라도, 적어도 책임 있는 입장인 총리로서 청년들에게 위로의 말씀을 전하시고자 합니다. 어떻게 생각하시며, 이에 대한 대책이나 고민이 있는지 알려주십시오.', '질문_키워드': '학교, 장학금, 취직, 세펙, 조국 사태, 허탈감, 대통령, 사과'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049415&fileType=PDF', 'row': 9}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '총리께서는 청년들의 노력과 상실감, 절망에 대한 아픈 실망을 공감하고 있으며, 사회의 구조 개선을 통해 공정성을 높이고자 최선을 다할 것이라고 밝혔습니다. 또한, 청년들의 노력이 공정한 결과를 가져올 수 있도록 노력하고 있음을 강조하였습니다.', '답변': '청년들의 상실감과 절망에 대한 아픈 실망을 공감하고, 사회의 구조 개선을 통해 공정성을 높이는 데 최선을 다하겠습니다. 청년들의 노력이 공정한 결과를 가져올 수 있도록 노력하고 있습니다.', '답변_키워드': '도입, 제도, 자식들, 기회, 선의, 예결위, 악용, 공정성'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049020&fileType=PDF', 'row': 10}, page_content="{'회의날짜': '2019년3월21일(목)', '국회_대': '20', '회의명': '국회본회의', '회수': '제367회', '차수': '제7차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049020&fileType=PDF', 'row': 10}, page_content="{'질문자_이름': '송언석 의원', '질문': '최근 취업자 증가와 경기 동행지수 하락, 소득 양극화 등 경제 지표의 악화가 우려되고 있습니다. 총리님은 이러한 경제적 도전에 대해 어떻게 대응할 계획이 있으며, 특히 최저임금 인상이 경제에 미치는 영향에 대한 검토를 진행 중인지 궁금합니다.', '질문_키워드': '소득,  정부,  양극화,  빈익빈,  부익부,  계층'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049020&fileType=PDF', 'row': 10}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '총리님은 현재 경제적 도전에 대해 인식하고 있으며, 고령화 등 여러 요인으로 인한 소득 양극화 문제도 인정하고 있습니다. 또한, 최저임금 인상이 일부 계층에 부정적인 영향을 미치는 점을 인지하고 있습니다. 현재 정부는 이러한 도전에 대한 대응책을 모색하고 있으며, 특히 임시직 고용 감소와 같은 부정적인 현상에 대한 대응을 강조하고 있습니다.', '답변': '최근의 경제적 도전에 대해 인식하고 있으며, 고령화 등 여러 요인으로 인한 소득 양극화 문제도 인정합니다. 최저임금 인상이 일부 계층에 부정적인 영향을 미치는 점은 인지하고 있습니다. 현재 정부는 이러한 도전에 대한 대응책을 모색하고 있으며, 특히 임시직 고용 감소와 같은 부정적인 현상에 대한 대응을 강조하고 있습니다.', '답변_키워드': '고용,  임시직,  수용,  최하위,  소득계층'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023695&fileType=PDF', 'row': 11}, page_content="{'회의날짜': '1999년7월06일(화)', '국회_대': '15', '회의명': '국회본회의', '회수': '제205회', '차수': '제5차', '안건': '경제에 관한 질문(계속)', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023695&fileType=PDF', 'row': 11}, page_content="{'질문자_이름': '천정배 의원', '질문': '현재의 금융 안정 및 기업 구조조정 대책에 대해 어떠한 추가 조치가 필요하다고 보십니까?', '질문_키워드': '구조조정,  조치'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=023695&fileType=PDF', 'row': 11}, page_content="{'답변자_이름': '남궁석 정보통신부 장관', '문맥': '천정배 의원님의 발언은 한국에서 1997년 말부터 시작된 IMF 경제위기 이후의 상황을 반영한 것으로 보입니다. 당시 천 의원은 새정치국민회의 소속으로 활동하며 경제 구조조정과 각종 개혁 조치에 대한 의지를 강조하였습니다. 천 의원의 발언은 다음의 요점을 담고 있습니다. 1. IMF 위기 당시 김대중 대통령과 국민의 정부의 강력한 경제 개혁이 위기를 조기에 극복하는 데 크게 기여했지만, 근본적인 문제를 해결하지 않고는 위기가 재발할 수 있다는 우려를 표명했습니다. 2. 천 의원은 재벌개혁을 비롯한 경제구조의 지속적인 개혁 필요성을 강조하며, 이러한 개혁 없이는 경제가 다시 위기에 처할 수 있음을 지적했습니다. 3. 투명성 있는 기업경영을 요구하며 회계감사의 독립성 확립, 분식회계와 부실감사에 대한 책임추궁 강화, 손해회수 의무화 등을 강조하였습니다. 4. 재벌의 지배구조 문제에 대한 개선, 소수주주의 권익 보호 및 대주주의 책임 강화에 대한 필요성을 언급하였습니다. 5. 재벌들의 경제력 집중을 문제 삼으며, 공정한 시장질서를 위한 제도적 개선이 필요하다고 주장했습니다. 6. 천 의원은 부실기업에 대한 워크아웃 시스템의 개선과 효율적인 퇴출기업에 대한 인센티브 제공에 대한 필요성을 피력하였습니다. 7. 금융부문의 구조 조정 및 건전성 감독에 대한 강화, 공적자금의 건전한 활용을 촉구했습니다. 8. 중소기업 및 벤처기업에 대한 지원책을 강제력 있게 추진하며 관련 정책의 개선점을 제시하였습니다. 9. 실업과 서민경제에 대한 안정 대책의 필요성을 강조하며, 경제 정책 전반의 조정을 요구하였습니다. 이러한 내용은 당시 대한민국의 경제 상황에 대해 중요한 이슈들을 다루면서 국가적 차원의 심도 있는 대응방안을 모색하고 있음을 보여줍니다. 인공 지능 기술의 발전에 따라 미래에는 이러한 경제 문제에 대한 예측, 분석, 해결 방안 모색에 인공 지능이 중요한 역할을 할 수 있습니다. 데이터 분석을 통해 경제 패턴을 식별하고 위기 상황을 예방하며, 경제 정책의 효과를 시뮬레이션하는 데 인공 지능이 활용될 수 있을 것입니다.', '답변': '현재는 벤처기업 육성을 위해 투자 중심의 지원이 필요하며, 금융기관의 부실채권 증가에 대비하여 엄격한 재정지원 원칙을 수립해야 합니다.', '답변_키워드': '벤처기업,  투자,  창업'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051989&fileType=PDF', 'row': 12}, page_content="{'회의날짜': '2022년7월26일(화)', '국회_대': '21', '회의명': '국회본회의', '회수': '제398회', '차수': '제6차', '안건': '경제에 관한 질문', '법안': '경제에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051989&fileType=PDF', 'row': 12}, page_content="{'질문자_이름': '김경협  의원', '질문': '무역적자가 28년 만에 발생한 이유는 무엇이라고 생각하십니까?', '질문_키워드': '국제사회, 무역적자'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051989&fileType=PDF', 'row': 12}, page_content='{\'답변자_이름\': \'한덕수 국무총리\', \'문맥\': "\'무역적자가 28년 만에 발생한 이유는 중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.\'", \'답변\': \'중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.\', \'답변_키워드\': \'중국, 원칙\'}'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051293&fileType=PDF', 'row': 13}, page_content="{'회의날짜': '2021년9월16일(목)', '국회_대': '21', '회의명': '국회본회의', '회수': '제391회', '차수': '제7차', '안건': '교육․사회․문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051293&fileType=PDF', 'row': 13}, page_content="{'질문자_이름': '유상범 의원', '질문': '조성은 제보자가 과거에 브랜드뉴파티 창당과 관련해 논란이 있었고, 제보자의 과거 이력에 의심이 제기되고 있습니다. 이러한 제보자의 신뢰성 문제가 현재 제보 사안에 어떠한 영향을 미칠 수 있다고 생각하십니까?', '질문_키워드': '참전유공자, 공익제보자, 허위사실'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051293&fileType=PDF', 'row': 13}, page_content="{'답변자_이름': '김부겸 국무총리', '문맥': '제보자 조성은 씨는 과거 브랜드뉴파티 창당 과정에서 당원 수를 부풀렸다는 의혹과 참전유공자 등의 개인정보를 도용한 것으로 비난받으며 신뢰성에 흠집이 났습니다. 그의 전적이 현재 제보의 신뢰도에 영향을 미칠 가능성은 분명 피할 수 없는 문제로, 사건의 진위를 파악하는 과정에서 이러한 배경이 중요한 변수로 작용할 수 있습니다. 제보자가 공익제보자로서의 위치를 우회적으로 부인했다가 후에 인정하는 등 모순된 행동을 보였고, 특정 정치인에 반감을 표출한 과거 사례는 제보자의 동기와 진정성을 의심케 하는 요소로 작용합니다. 이는 향후 사건의 실체를 규명하는데 있어서 제보자의 과거 이력과 제보 내용의 신뢰성을 신중하게 따져볼 필요가 있음을 시사합니다.', '답변': '제보자의 과거 이력과 신뢰성 문제는 현재의 제보 사안에 영향을 미칠 수 있습니다. 이러한 문제들은 사건의 신뢰성과 정확성을 점검하는 데 중요한 고려 사항이며, 수사와 검토 과정에서 심사해야 합니다.', '답변_키워드': '판단'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051081&fileType=PDF', 'row': 14}, page_content="{'회의날짜': '2021년6월23일(수)', '국회_대': '21', '회의명': '국회본회의', '회수': '제388회', '차수': '제4차', '안건': '경제에 관한 질문', '법안': '경제에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051081&fileType=PDF', 'row': 14}, page_content="{'질문자_이름': '오기형 의원', '질문': '거래소에 대한 인식과 가이드라인을 발전시키기 위해 어떤 노력을 계획하고 있나요?', '질문_키워드': '업비트,  거래소,  고머니2,  북미 셀시우스네트워크,  가이드라인'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051081&fileType=PDF', 'row': 14}, page_content="{'답변자_이름': '은성수 금융위원회 위원장', '문맥': '현재 거래소 등록과 관련된 인식과 가이드라인을 발전시키기 위해 저희는 컨설팅을 제공하고 있습니다. 이를 통해 거래소 등록 사업자들에게 거래소의 도덕적 의무와 책임에 대한 이해를 높이고 있습니다. 또한, 거래소 등록 심사 과정에서 거래소가 해야 할 도덕적 의무에 대한 설명과 대화를 통해 사업자들이 이를 준수하도록 독려하고 있습니다. 앞으로도 거래소 등록과 관련된 인식과 가이드라인을 보다 발전시키기 위해 지속적으로 노력할 예정입니다.', '답변': '거래소에 대한 인식과 가이드라인을 발전시키기 위해 저희는 현재 컨설팅을 제공하고 있습니다. 이를 통해 거래소 등록 사업자들에게 거래소의 도덕적 의무와 책임에 대한 이해를 높이고 있습니다. 또한, 거래소 등록 심사 과정에서 거래소가 해야 할 도덕적 의무에 대한 설명과 대화를 통해 사업자들이 이를 준수하도록 독려하고 있습니다. 앞으로도 거래소 등록과 관련된 인식과 가이드라인을 보다 발전시키기 위해 지속적으로 노력할 예정입니다.', '답변_키워드': '특금법,  가이드라인,  한국거래소,  컨성팅'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048394&fileType=PDF', 'row': 15}, page_content="{'회의날짜': '2018년10월01일(월)', '국회_대': '20', '회의명': '국회본회의', '회수': '제364회', '차수': '제7차', '안건': '외교․통일․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048394&fileType=PDF', 'row': 15}, page_content="{'질문자_이름': '안상수 의원', '질문': '남북 군사 합의로 인한 비무장지대의 평화화가 안보에 대한 위협으로 여겨지는데, 현재 안보 유지와 평화화를 조율하는 방법에 대한 총리의 견해는 무엇인가요?', '질문_키워드': '지역구,  요전,  평양,  방문,  합의,  군사,  분야,  합의서'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048394&fileType=PDF', 'row': 15}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '총리의 견해에 따르면, 군사 합의로 인한 지역 안보 변화에 대한 논란의 여지가 있음에도 불구하고, 안보를 유지하면서도 평화적인 과정을 통해 협력 가능한 해결책을 모색해야 한다고 이야기하고 있습니다. 또한, 실제 위협으로 이어질 수 있는 사항은 신중하게 대응해야 한다고 언급하고 있습니다.', '답변': '군사 합의로 인한 지역 안보 변화는 논란의 여지가 있으나, 안보를 유지하면서도 평화적인 과정을 통해 협력 가능한 해결책을 모색해야 한다고 생각합니다. 실제 위협으로 이어질 수 있는 사항은 신중하게 대응해야 합니다.', '답변_키워드': '서해5도,  주민들,  보도,  희생,  대동강 하구,  상호주의,  NLL 남단,  사격훈련'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=045234&fileType=PDF', 'row': 16}, page_content="{'회의날짜': '2015년6월19일(금)', '국회_대': '19', '회의명': '국회본회의', '회수': '제334회', '차수': '제3차', '안건': '외교․통일․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=045234&fileType=PDF', 'row': 16}, page_content="{'질문자_이름': '심윤조 의원', '질문': '출국금지 조치에도 불구하고 20명 이상의 국민이 해외로 나간 이유는 무엇이며, 그에 따른 불안은 인지하고 계십니까?', '질문_키워드': '출국금지, 조치, 국민, 해외, 격리'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=045234&fileType=PDF', 'row': 16}, page_content="{'답변자_이름': '황교안 국무총리', '문맥': '문제의 근본적인 원인은 메르스 사태 초기에 격리 대상자에 대한 출국금지 조치의 정보가 제대로 시스템에 반영되지 못했기 때문입니다. 이로 인해 격리 대상자 중 20명이 넘는 한국 국민들이 해외로 출국할 수 있었던 것으로 보입니다. 당시에는 아직 최적화된 관리 시스템이 구축되어 있지 않았고, 이에 따라 격리 대상자의 신속한 출국금지 조치에 대한 정보 공유가 충분히 이루어지지 않았습니다. 이러한 상황은 국내외에서 많은 불안을 야기했고, 이에 대한 우려의 목소리도 클 것입니다. 현재로서는 관련 부처들이 긴밀히 협조하여 출국금지 조치에 대한 시스템을 강화하였으며, 이 같은 문제가 대부분 해소된 상태로 보건복지부, 법무부, 외교부 등 관련 기관들이 긴밀하게 협력하여 전체적인 출국금지 시스템을 제대로 작동시키고 있으며, 이로 인해 외국의 불안감을 완화하려는 노력을 기울이고 있다고 인지하고 있습니다.', '답변': '대부분은 초기에 시스템 문제로 인한 정보 부족으로 발생한 문제였으며, 현재는 대부분의 문제가 해결되었으며, 불안을 알고 있습니다.', '답변_키워드': '소리, 우리, 시스템, 상태, 출국금지, 인적사항, 통보'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049199&fileType=PDF', 'row': 17}, page_content="{'회의날짜': '2019년7월10일(수)', '국회_대': '20', '회의명': '국회본회의', '회수': '제369회', '차수': '제7차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049199&fileType=PDF', 'row': 17}, page_content="{'질문자_이름': '김병욱 의원', '질문': '뉴노멀로 향하는 한국의 경제적 변화와 수축사회에 대한 대응책은 무엇인지 총리님은 어떻게 생각하시나요?', '질문_키워드': '뉴노멀, 금융위기, 3저시대'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049199&fileType=PDF', 'row': 17}, page_content='{\'답변자_이름\': \'이낙연 국무총리\', \'문맥\': "총리님은 한일 경제 보복에 대한 현 상황에 대해 말하기 시작하시길 원하셨고, 민간의 참여가 중요하다고 언급하셨습니다. 또한, 부품, 소재, 장비를 직접 생산하는 업체의 참여가 필요하다고 이야기하셨습니다. 산업의 미래 전략을 짜기 위해서 정부와의 협의 창구로서, 미래 전략의 탱크 역할이 필요하다고 말씀하셨습니다. 또한, 이번 추경안에 대한 여야 합의가 중요하다고 강조하고 있으시죠. 총리님의 말씀을 정리하면, \'네이버와 다른 기업들이 함께하는 것은 바람직하다.\'고 이야기하신 것을 참고해, \'대기업 모임에 참여하지 못한 부품, 소재, 장비 업체들의 입장과 뜻이 중요하다\'라고 언급하시고, \'정부와의 협의 창구로서, 미래 전략의 탱크 역할이 필요하다.\'라고 답변하는 것이 적절할 것으로 생각됩니다.", \'답변\': \'뉴노멀로 변화하는 한국의 경제적 측면을 고려할 때, 우리는 수축사회에 대한 적응과 새로운 갈등에 유연하게 대처할 수 있는 정책과 사회적 변화가 필요하다고 생각합니다.\', \'답변_키워드\': \'수축사회, 팽창사회\'}'),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=
}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046819&fileType=PDF', 'row': 20}, page_content="{'질문자_이름': '이명수 의원', '질문': '권한대행으로서의 역할과 범위에 대한 법적 근거를 보완하고자 하는데, 권한대행이 적극적인 역할을 할 것이냐 소극적인 역할을 할 것이냐에 대한 의견은 어떠합니까?', '질문_키워드': '권한대행,  생각,  국민,  말씀,  대통령,  문제'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046819&fileType=PDF', 'row': 20}, page_content="{'답변자_이름': '황교안 국무총리', '문맥': '황교안 대통령 권한대행 겸 국무총리 님, 권한대행으로서의 역할과 범위에 대한 법적 근거를 보완하는 것에 대해 말씀드리고 싶습니다. 권한대행이 적극적인 역할을 할 것인지, 아니면 소극적인 역할을 할 것인지에 대한 논란이 있는 것을 잘 알고 있습니다. 권한대행으로서의 역할은 우리 국민의 안전과 민생 문제에 중점을 두어 적극적으로 수행되어야 한다고 생각합니다. 필요한 경우에는 법적 근거를 보완하여 국민이 안정을 느낄 수 있고, 보다 나은 복지를 제공하기 위해 최선을 다하겠습니다. 그렇기 때문에 권한을 적극적으로 행사하거나 인사권을 행사하는 등의 문제가 논란이 되어서는 안 됩니다. 대통령의 권한대행으로서, 국민 앞에 섰을 때는 헌법이 위임한 법적 지위에 따라 책임과 역할을 수행하는 것이 중요하다고 봅니다. 이는 단순히 저의 질문에 응답하는 시간을 넘어서, 국가적 상황을 안정적으로 관리하고 국민의 신뢰를 바탕으로 국정을 안정적으로 이끌어가는 것이 중요함을 강조하고 싶습니다.', '답변': '권한대행으로서의 역할은 국민 안전과 민생 문제에 중점을 두어 적극적으로 수행되어야 합니다. 필요한 경우 법적 근거를 보완하여 국민의 안심과 복지를 위해 최선의 노력을 다하겠습니다.', '답변_키워드': '의견,  대통령,  현상'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=035400&fileType=PDF', 'row': 21}, page_content="{'회의날짜': '2007년2월09일(금)', '국회_대': '17', '회의명': '국회본회의', '회수': '제265회', '차수': '제5차', '안건': '경제에 관한 질문(계속)', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=035400&fileType=PDF', 'row': 21}, page_content="{'질문자_이름': '강길부 의원', '질문': '공공주택 공급 확대로 발생하는 부작용에 대한 대책은 무엇인가요?', '질문_키워드': '주택공급,  공공,  비효율,  공공성,  강화,  비대화'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=035400&fileType=PDF', 'row': 21}, page_content="{'답변자_이름': '권오규 재정경제부 부총리겸장관', '문맥': '공공주택 공급 확대로 예상되는 부작용에 대한 대책으로 정부는 토지 공급 측면에 주목해 직주근접이 가능하도록 양질의 토지를 확보하는 방안을 모색하고 있습니다. 이를 위해 도심지역에 위치한 미이용 시설 부지나, 지방으로 이전하는 시설 부지, 그리고 도시 가까이에 위치한 그린벨트 지역 등에서 원활한 토지 공급을 용이하게 하려는 노력을 기울이고 있습니다. 더불어, 공공 부문의 재개발 및 재건축 사업에도 참여해 도심 안의 사용 가능한 토지를 적극 활용하며, 이와 같은 대책들을 통해 임대주택 공급 시, 직주 근접성과 같은 중요 요소를 반영하는 동시에 공공주택단지의 규모가 크고 도시 외곽에 위치하는 경향에 따른 미분양과 입주 공실률 문제 등을 최소화하여 비효율성과 경영상의 압박을 줄여나가고자 다양한 조치를 취하고 있습니다.', '답변': '공공주택 공급 확대 대책은 토지 공급에서 직주근접이 가능한 양질의 토지 확보와 도심 재개발, 재건축에 공공 참여를 포함하여 도심 내 미이용 시설 부지 및 그린벨트 등에서 토지 공급을 원활히 하기 위한 노력을 통해 부작용을 완화하려고 합니다.', '답변_키워드': '임대주택,  직주근접,  공급,  토지공급,  재개발,  재건축'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046414&fileType=PDF', 'row': 22}, page_content="{'회의날짜': '2016년9월22일(목)', '국회_대': '20', '회의명': '국회본회의', '회수': '제346회', '차수': '제7차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046414&fileType=PDF', 'row': 22}, page_content="{'질문자_이름': '함진규 의원', '질문': '기획재정부가 교통사업 결정권을 갖고 있고, 우리의 예산편성 방식이 다른 나라와 비교하여 독특하다는데, 이러한 사업 결정 방식이 각 부처의 독립성을 침해하는 것으로 생각하시나요?', '질문_키워드': '기획재정부,  사업 결정권,  개별사업,  일본,  미국,  부처,  사업계획,  수립'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046414&fileType=PDF', 'row': 22}, page_content="{'답변자_이름': '유일호 기획재정부 부총리겸장관', '문맥': '일부에서는 중앙 집중화된 권한이 각 부처의 독립성을 침해한다는 시각을 갖고 있지만, 다른 이들은 예산 주관 부서가 중앙 집중화된 권한을 갖고 있는 것이 일부 사업 결정을 효율적으로 할 수 있게 하는 것으로 이해하고 있습니다. 이러한 시스템은 나라마다 다를 수 있으며, 각 나라의 사회적, 정치적, 경제적 상황과 문화적 특성에 따라 다르게 적용됩니다. 하여튼, 사업 결정과 예산 배정의 중앙 집중화에 따른 문제점과 이점에 대해 더 깊이 조사하고 분석해야 할 필요가 있습니다.', '답변': '사업 결정권이 중앙부처에 집중되어 있는 현실은 예산 배정에 중앙 집중화된 권한이 있는 것으로, 동일한 사업 결정 방식이 다른 나라에서도 이뤄지고 있는 것을 고려할 때, 예산 주관 부서의 중앙 집중화에 대한 문제점을 고려할 필요가 있습니다.', '답변_키워드': '예산,   사업 결정권,  배정,  권한,  통합'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049008&fileType=PDF', 'row': 23}, page_content="{'회의날짜': '2019년3월19일(화)', '국회_대': '20', '회의명': '국회본회의', '회수': '제367회', '차수': '제5차', '안건': '정치에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049008&fileType=PDF', 'row': 23}, page_content="{'질문자_이름': '추혜선 의원', '질문': '현재의 수사에 대한 의혹과 증거인멸 우려에 대응하기 위해 수사단을 높인 결정에 대해 자세히 설명해 주십시오.', '질문_키워드': '증거인멸, 시간, 의혹, 명운, 수사'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049008&fileType=PDF', 'row': 23}, page_content="{'답변자_이름': '김부겸 행정안전부 장관', '문맥': '이 사건에 대한 의혹과 증거인멸에 대한 우려가 높아짐에 따라, 대응책으로 수사 체계가 강화되었습니다. 이를 위해 서울청 차장을 수사본부장으로 임명하고 152명의 강력한 수사단을 새롭게 편성하였습니다. 경찰 당국은 이번 조치로 초기 수사의 부적절한 개입을 방지하고, 더욱 철저하고 객관적인 수사가 이루어질 것으로 기대하고 있습니다. 사건의 심각성을 고려한 결정을 통해, 공정하고 투명한 수사 진행에 대한 국민의 신뢰를 회복하고자 합니다. 또한, 국민들의 의혹을 해소하고 적시에 정보를 제공하기 위해 일주일에 한 번 이상 수사진행 상황을 브리핑하는 방식으로, 수사의 투명성을 증진시킬 계획입니다. 이러한 노력은 범죄에 대한 무관심과 소홀함이 일으킨 사회적 불신을 극복하고, 정의가 실현될 수 있는 토대를 마련하기 위함입니다. 전반적으로 이러한 대책은 수사의 독립성을 강화하고, 경찰의 책임 있는 역할을 강조하는 것으로, 국민이 더 이상 경찰의 미흡한 대응에 실망하지 않도록 만드는 데 중점을 두고 있습니다.', '답변': '의혹과 증거인멸 우려를 고려하여 초기 수사에 개입이 없도록 서울청 차장을 수사본부장으로 임명하고, 152명으로 구성된 수사단을 편성하였습니다. 앞으로 일주일에 한 번 이상 국민에게 수사 진행 상황에 대한 브리핑을 통해 투명성을 확보하기로 결정했습니다.', '답변_키워드': '수사 단위, 수사단, 편성, 수사, 브리핑'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051074&fileType=PDF', 'row': 24}, page_content="{'회의날짜': '2021년6월22일(화)', '국회_대': '21', '회의명': '국회본회의', '회수': '제388회', '차수': '제3차', '안건': '정치·외교·통일·안보에 관한 질문', '법안': '정치·외교·통일·안보에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051074&fileType=PDF', 'row': 24}, page_content="{'질문자_이름': '정운천 의원', '질문': '정부가 2025년에 모든 자사고와 특목고를 일반고로 전환시키기로 결정한 것에 대해, 총리님도 같은 생각을 가지고 계신가요?', '질문_키워드': '정부 여당은 고교평준화, 2025년 자사고와 특목고를 전부 폐지,  생각'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051074&fileType=PDF', 'row': 24}, page_content="{'답변자_이름': '김부겸 국무총리', '문맥': '총리님은 자사고와 특목고 문제에 대한 일부 절차적인 문제를 인정하고 있지만, 이러한 문제를 그냥 둘 수 없는 상황이라고 말씀하셨습니다. 또한 자사고와 특목고가 현재 편법적인 운영을 하는 것으로 알고 있고, 이는 고교 교육의 정상화를 이루기까지의 여러 가지 장애물로 작용하고 있다고 인식하고 계십니다. 정부는 이 문제를 해결하기 위해 노력하고 있으며, 이에 대한 안타까움을 표하며, 교육부와 함께 이 문제를 해결하기 위한 노력을 계속할 것으로 예상됩니다.', '답변': '자사고와 특목고 문제에 대해 일부 절차적인 문제가 있음을 인정하고 있지만, 이러한 문제를 그냥 둘 수 없는 상황이라고 총리님은 말씀하셨습니다. 자사고와 특목고가 현재 편법적인 운영을 하고 있다는 문제식이 있으며, 이는 고교 교육의 정상화를 이루기까지의 여러 가지 장애물로 작용하고 있다고 인식하고 계십니다. 이에 대한 안타까움을 표하며, 정부는 이 문제를 해결하기 위해 노력하고 있습니다.', '답변_키워드': '고교 교육 정상화'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050952&fileType=PDF', 'row': 25}, page_content="{'회의날짜': '2021년4월20일(화)', '국회_대': '21', '회의명': '국회본회의', '회수': '제386회', '차수': '제2차', '안건': '경제에 관한 질문', '법안': '경제에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050952&fileType=PDF', 'row': 25}, page_content="{'질문자_이름': '어기구 의원', '질문': '부동산 문제의 근본적인 원인에 대해 어떻게 생각하시나요?', '질문_키워드': '국토균형발전, 부동산, 투기'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050952&fileType=PDF', 'row': 25}, page_content="{'답변자_이름': '홍남기 국무총리직무대행', '문맥': '저는 부동산 문제의 근본적인 원인은 주택 공급 부족과 투기 지역 소요로 볼 수 있습니다.', '답변': '부동산 문제의 근본적인 원인은 주택 공급 부족과 투기 지역 소요로 볼 수 있습니다.', '답변_키워드': '주택공급, 투기지역, 소요, 수요, 공급'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049025&fileType=PDF', 'row': 26}, page_content="{'회의날짜': '2019년3월22일(금)', '국회_대': '20', '회의명': '국회본회의', '회수': '제367회', '차수': '제8차', '안건': '교육․사회․문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049025&fileType=PDF', 'row': 26}, page_content="{'질문자_이름': '이채익 의원', '질문': '8.15 광복절에 대통령에게 대사면을 건의하고자 하는데, 전직 대통령 및 전 정부 인사들이 투옥된 상황에서 법적인 제약으로 인해 현재로서는 어려운 상태인가요?', '질문_키워드': '남북통일, 화해, 적폐청산, 대사면'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049025&fileType=PDF', 'row': 26}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '죄의 형이 확정된 후에만 사면이 가능하다는 법적 제약이 있기 때문에 현재 상황에서는 어려운 상태이며, 법률적인 요건이 갖추어지지 않는 이상 사면을 건의하기 어려운 상황으로 보입니다.', '답변': '네, 형이 확정돼야만 사면이 가능하며, 현재로서는 법적으로 어려움이 있습니다.', '답변_키워드': '법률적, 형, 확정, 사면, 가능'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048394&fileType=PDF', 'row': 27}, page_content="{'회의날짜': '2018년10월01일(월)', '국회_대': '20', '회의명': '국회본회의', '회수': '제364회', '차수': '제7차', '안건': '외교․통일․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048394&fileType=PDF', 'row': 27}, page_content="{'질문자_이름': '하태경 의원', '질문': '우리가 북한에 정보를 개방하는 것과 같은 방식으로 북한이 우리 정보를 받아들이도록 하는 전략은 가능한가요?', '질문_키워드': '북한,  우리,  정보,  북한,  우월한,  체제,  조선중앙TV,  자부'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048394&fileType=PDF', 'row': 27}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '북한의 정보 개방에 관해 양측이 상호 이해를 높이는 것은 매우 중요한 전략일 수 있습니다. 남북 간의 정보 교환이 양방향으로 이루어져야 하며, 이를 통해 양국 국민들이 서로에 대한 이해도를 높이고 오해를 줄일 수 있습니다. 그러나 현재 북한은 정보에 대해 매우 엄격한 통제를 하고 있으며 남한의 정보를 적극적으로 수용하지 않고 있습니다. 따라서 남북한이 정보를 공유하는 것은 양측간의 신뢰 구축과 적극적인 협력이 선행되어야 가능할 것으로 보입니다. 이는 남한이 정보를 더 개방적으로 접근할 준비가 되어 있음에도 불구하고, 북한이 같은 태도를 취할 준비가 되어 있지 않다는 현실적인 어려움을 반영합니다. 남북한 모두 정보 통제의 정도에 대해 서로 다른 기준과 접근 방식을 가지고 있기 때문에, 진정한 의미에서의 정보 개방과 교환을 달성하려면 많은 노력과 대화가 필요합니다.', '답변': '정보 개방의 양면성을 통해 남북간 상호이해를 높일 수 있습니다. 그러나 현재 북한의 정보 통제와 달리, 이러한 접근은 양측이 상호적인 신뢰를 가지고 적극 협력할 때 가능할 것으로 보입니다.', '답변_키워드': '남북관계,  진전,  논의,  가능,  대정부질문,  답변'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum
}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049199&fileType=PDF', 'row': 30}, page_content="{'회의날짜': '2019년7월10일(수)', '국회_대': '20', '회의명': '국회본회의', '회수': '제369회', '차수': '제7차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049199&fileType=PDF', 'row': 30}, page_content="{'질문자_이름': '신용현 의원', '질문': '부처 간 및 부처 내 장벽을 극복하기 위해 어떤 조치를 취할 계획이 있나요?', '질문_키워드': '부처,  장벽'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049199&fileType=PDF', 'row': 30}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '총리님, 부처 간 및 내부의 장벽을 해소하기 위해 사전 조정 및 사후 조정을 강화하고, 규제적인 요소를 긍정적으로 전환하여 부처 간 협력을 촉진하는 방안들을 검토하고 있습니다. 이에 따라 부처들의 협력을 더욱 원활히 하고자 다양한 정책적인 노력을 기울일 예정입니다. 기업 및 현장에서 불만을 제기하는 사안들에 대해서도 적극적으로 검토하여 실질적인 해결책을 모색하고자 합니다.', '답변': '부처 간 및 내부의 장벽을 해소하기 위해 사전 조정 및 사후 조정을 강화하고, 규제적인 요소를 긍정적으로 전환하여 부처 간 협력을 촉진하는 방안들을 검토하고 있습니다.', '답변_키워드': '부처, 장벽, 조정, 그것, 생각, 도처, 자체'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050196&fileType=PDF', 'row': 31}, page_content="{'회의날짜': '2020년9월16일(수)', '국회_대': '21', '회의명': '국회본회의', '회수': '제382회', '차수': '제6차', '안건': '경제에 관한 질문', '법안': '경제에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050196&fileType=PDF', 'row': 31}, page_content="{'질문자_이름': '장혜영 의원', '질문': '올해는 코로나19뿐만 아니라 태풍과 장마로 인한 피해가 크게 발생했습니다. 이에 대한 피해 복구를 위해 책정된 예산의 총액은 어느 정도이며, 어떻게 그 예산이 사용되고 있는지 알려주실 수 있나요?', '질문_키워드': '피해 복구,  예산의 총액'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050196&fileType=PDF', 'row': 31}, page_content="{'답변자_이름': '정세균 국무총리', '문맥': '코로나19뿐만 아니라 태풍과 장마로 인한 피해가 크게 발생한 올해에는 피해 복구를 위해 책정된 예산의 총액은 약 3조 4000억 원으로 알려져 있습니다. 이 예산은 재해 대비를 위해 확보한 예비비와 각 부처에서 일상적인 관리 예산과 함께 자연재해에 대비한 예산을 포함하고 있습니다. 태풍 및 기타 자연재해로 인한 피해에 대응하기 위해 일부 예비비가 사용되었으며, 이러한 예산이 어떻게 사용되고 있는지에 대한 구체적인 내용은 더 알아보아야 합니다.', '답변': '원래 재해 대비를 위해 예비비로 약 2조 원 정도를 확보하고 있었습니다. 각 부처에서는 일상적인 관리 예산과 함께 자연재해에 대비한 예산도 큰 부분을 차지하고 있습니다. 이번에 발생한 태풍 및 기타 자연재해로 인한 피해에 대응하기 위해 예비비 중 일부가 사용되었습니다.', '답변_키워드': '자연재해,   예비비,  자연재해 대비 예비비,  특별재난지역'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049008&fileType=PDF', 'row': 32}, page_content="{'회의날짜': '2019년3월19일(화)', '국회_대': '20', '회의명': '국회본회의', '회수': '제367회', '차수': '제5차', '안건': '정치에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049008&fileType=PDF', 'row': 32}, page_content="{'질문자_이름': '추혜선 의원', '질문': '검찰 과거사 진상조사단의 보고서에서 삭제 압력이 있었다는 사실에 대해 어떻게 인식하며 대응할 계획이 있나요?', '질문_키워드': '검찰, 삼성전기, 고문, 진상조사단, 과거사위원회, 조사단 보고서, 삭제, 압력'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049008&fileType=PDF', 'row': 32}, page_content="{'답변자_이름': '박상기 법무부 장관', '문맥': '삭제 압력과 관련된 사안에 대해서는 아주 중요한 문제로 인식하고 있습니다. 이러한 의혹이 국민의 불신을 증폭시킬 수 있기 때문에 사실관계를 분명히 하고, 과거사 진상조사 대상이 되는 사건에 대한 보고서가 투명하게 작성될 수 있도록 협의하고 지도하겠습니다. 앞으로 국민들께서 의혹을 품지 않도록 최선을 다해 투명하고 정확한 사실을 밝히는 데 헌신하겠습니다.', '답변': '삭제 압력에 대해서는 사건의 중요성을 감안하여 사실관계를 분명히 하기 위해 조사단과 협의하고 지도하겠습니다. 향후에는 국민의 의혹이 남지 않도록 투명하게 진상을 밝히기 위해 최선을 다하겠습니다.', '답변_키워드': '진상조사단, 보고서, 문건, 작성, 위원회, 장자연 리스트 사건, 김학의 전 차관 사건, 국민적 의혹, 사실관계'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046414&fileType=PDF', 'row': 33}, page_content="{'회의날짜': '2016년9월22일(목)', '국회_대': '20', '회의명': '국회본회의', '회수': '제346회', '차수': '제7차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046414&fileType=PDF', 'row': 33}, page_content="{'질문자_이름': '송영길 의원', '질문': '정부가 우리나라 조선사를 지원하여 머스크의 경쟁으로 국적사를 무너뜨리고 있다는 비판에 대해 어떻게 생각하십니까?', '질문_키워드': '정부,  은행,  금융,  지원,  조선사,  20척,  1만 8000TEU급,  머스트 운임단가'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046414&fileType=PDF', 'row': 33}, page_content="{'답변자_이름': '유일호 기획재정부 부총리겸기획재정부장관', '문맥': '해당 대화 내용에서 비판하는 주장은 정부가 우리나라 조선사에 금융적 지원을 해서 만든 선박을 머스크가 사용함으로써 운임단가 인하 경쟁을 거쳐 한국의 국적사인 한진해운을 비롯한 국내 해운사들을 경쟁에서 뒤처지게 했다는 것입니다. 이로 인해 국적사들이 경영난에 빠지며 결국 어려움을 겪게 되었다고 지적하고 있습니다. 비판자는 정부가 무능하고 경제에 대한 이해가 부족하며, 머스크와 같은 글로벌 선사에 의한 경쟁으로 국적사가 희생되고 있다며 우리나라 해운산업에 대한 국가적 지원의 중요성을 강조합니다. 그는 정부의 이러한 결정이 조선산업에 나쁜 영향을 끼쳤을 뿐만 아니라, 국가 안보상으로도 심각한 문제가 될 수 있다고 언급하며, 해운산업의 중요성을 재차 강조합니다. 결국 이 비판의 핵심은 정부의 잘못된 금융 지원 정책과 경제적 판단 미스가 국적사의 경영난을 초래하고, 이것이 조선산업뿐만 아니라 국가 안보에까지 영향을 미칠 수 있다는 점을 지적하고 있는 것입니다.', '답변': '정부는 해당 상황에 대해 이해 관계를 맺은 기업에 금융적 지원을 한 것으로, 국적사가 무너지는 것은 경쟁 상황과 머스크의 선택에 따른 결과로 판단됩니다.', '답변_키워드': '머스크,   배,  가격,  지불,  경쟁,  해운사,  세금,  한진해운'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049025&fileType=PDF', 'row': 34}, page_content="{'회의날짜': '2019년3월22일(금)', '국회_대': '20', '회의명': '국회본회의', '회수': '제367회', '차수': '제8차', '안건': '교육․사회․문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049025&fileType=PDF', 'row': 34}, page_content="{'질문자_이름': '이학재 의원', '질문': '국민들이 미세먼지로 인해 실망하고 있는데, 문재인 정부가 대선 당시에 제시한 미세먼지 해결 방안에 대한 국민들의 반응은 어떠한가요?', '질문_키워드': '대통령, 대선, 미세먼지, 정권'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049025&fileType=PDF', 'row': 34}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '국민들은 문재인 대통령이 대선 당시 약속한 미세먼지 문제 해결을 보지 못해 큰 실망을 하고 있습니다. 특히, 봄철에 자주 발생하는 고농도 미세먼지가 사람들에게 특별한 고통을 주고 있으며, 이로 인해 대통령에 대한 민심이 싸늘해지고 있다는 지적도 나옵니다. 정부의 현재까지의 대응조치나 제안된 정책들이 실질적인 미세먼지 감소 효과를 거두지 못하고 있는 실정입니다. 국민들 사이에서는 정부가 대선 때 제시한 미세먼지에 관한 공약들을 충분히 이행하지 않는다고 느끼는 목소리가 높아지고 있으며, 이에 정부에 대한 불신과 함께 미세먼지 해결에 대한 강한 조치를 촉구하는 목소리가 커지고 있습니다. 이는 정부가 미세먼지와 관련하여 당면한 문제를 신속하고 효과적으로 대처할 필요성을 보여줍니다.', '답변': '국민들은 대선 당시 문재인 대통령이 제시한 미세먼지 해결 방안을 실현하지 못해 실망하고 있으며, 특히 봄철 고농도 미세먼지로 인한 특별한 고통을 더 크게 느끼고 있습니다.', '답변_키워드': '대선, 심각, 연평균, 농도'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051074&fileType=PDF', 'row': 35}, page_content="{'회의날짜': '2021년6월22일(화)', '국회_대': '21', '회의명': '국회본회의', '회수': '제388회', '차수': '제3차', '안건': '정치·외교·통일·안보에 관한 질문', '법안': '정치·외교·통일·안보에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051074&fileType=PDF', 'row': 35}, page_content="{'질문자_이름': '최인호 의원', '질문': '가짜뉴스로 인해 백신에 대한 불신이 확산되고 있는 상황에서, 가짜뉴스에 대한 엄벌 조치가 필요한 것으로 생각하시나요?', '질문_키워드': '아스트라제네카 백신,  가짜뉴스'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051074&fileType=PDF', 'row': 35}, page_content="{'답변자_이름': '전해철 행정안전부 장관', '문맥': '현재 가짜뉴스로 인해 백신에 대한 불신이 점증되고 있는 상황에서 정부는 가짜뉴스에 대한 조사와 수사를 엄정하게 진행하고 있습니다. 백신 관련 가짜뉴스에 대해서는 18건 이상의 내사와 조사를 진행하고 일부 사례에 대해서는 송치도 이루어지고 있으며, 현재도 수사가 진행 중입니다. 또한, 정부는 경찰청뿐만 아니라 복지부, 질병관리청, 방송통신심의위원회 등 다양한 기관과 협력하여 가짜뉴스의 횡행을 단속하고, 더 이상의 가짜뉴스 창궐을 방지하기 위해 노력하고 있습니다.', '답변': '현재 가짜뉴스로 인해 백신에 대한 불신이 점증되고 있는 상황에서, 정부는 다음과 같은 노력을 하고 있습니다. 먼저, 가짜뉴스에 대한 조사와 수사를 엄정하게 진행하고 있습니다. 백신 관련 가짜뉴스에 대해서는 18건 이상의 내사와 조사를 진행하고 일부 사례에 대해서는 송치도 이루어지고 있으며, 현재도 수사가 진행 중입니다. 또한, 정부는 경찰청뿐만 아니라 복지부, 질병관리청, 방송통신심의위원회 등 다양한 기관과 협력하여 가짜뉴스의 횡행을 단속하고, 더 이상의 가짜뉴스 창궐을 방지하기 위해 노력하고 있습니다.', '답변_키워드': '가짜뉴스, 코로나, 코로나19 백신,  복지부,   질병관리청,  방송통신심의위원회'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051275&fileType=PDF', 'row': 36}, page_content="{'회의날짜': '2021년9월14일(화)', '국회_대': '21', '회의명': '국회본회의', '회수': '제391회', '차수': '제5차', '안건': '외교․통일․안보에 관한 질문', '법안': '외교․통일․안보에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051275&fileType=PDF', 'row': 36}, page_content="{'질문자_이름': '이재정 의원', '질문': '한반도 모델 및 평화뉴딜의 구체적 내용 및 실행 계획에 대해 설명해 주십시오.', '질문_키워드': '한반도의 미래상, 실현 과정과 방법, 정부에 대한 요구 ,  합의,  내용'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051275&fileType=PDF', 'row': 36}, page_content="{'답변자_이름': '이인영 통일부 장관', '문맥': '한반도 모델로서의 평화뉴딜은 경제적 발전과 평화를 동시에 추구하는 포괄적인 전략으로, 한반도의 지속 가능한 성장과 지역 안정을 목표로 합니다. 이 전략은 디지털화, 환경 친화적 성장, 사회적 포용성 강화를 아우르는 한국판 뉴딜 정책을 남북한 전반에 걸쳐 확장하는 구상을 포함하며, 특히 산업 및 자원 분야의 경제협력 뿐만 아니라 신재생 에너지, 탄소중립을 향한 노력 등을 남북이 협력하여 추진하는 것이 포함됩니다. 이 평화뉴딜은 남북 간의 적극적인 협력을 통해 한반도 전체의 경제 성장률을 끌어올리고 일자리 창출에 기여할 수 있는 잠재력을 가지고 있는데, 이는 궁극적으로 한국 경제에 새로운 성장동력을 제공하고, 국제사회에서의 코리아 디스카운트 해소 및 한반도의 평화적 이미지를 구축하는데 중요한 역할을 할 것으로 기대됩니다. 평화뉴딜을 통해 구체화될 한반도 모델은 국민들이 통일과 평화의 중요성에 대해 더 깊이 이해하고, 이를 위한 노력이 지속되어야 할 필요성을 절감하게 만들 가능성을 내포하고 있습니다.', '답변': '한반도 모델로서의 평화뉴딜은 한반도에서 경제적 발전과 평화를 동시에 추진하는 전략입니다. 평화뉴딜은 다양한 분야에서 실행되며, 디지털뉴딜, 그린뉴딜, 휴먼뉴딜을 통합적으로 확산하는 과정을 포함합니다. 이러한 전략을 통해 한반도는 새로운 성장 동력을 얻을 수 있으며, 통일과 평화에 대한 필요성을 국민들이 인식하게 될 것입니다.', '답변_키워드': '통일국민협약의 도출 과정, 사회적 대화의 방식, 사회정책 플랫폼, 협조'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum
}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050187&fileType=PDF', 'row': 320}, page_content="{'답변자_이름': '정경두 국방부 장관', '문맥': '위의 내용에서 국방부장관이 서 일병의 휴가에 대한 규정상 문제가 없다고 발표했으며, 해당 부분은 기록에 남아 있어서 정해진 절차에 따라 진행된 것으로 보고하고 있으며, 다른 사안들은 현재 검찰에서 수사 중이며 결과를 기다려야 한다는 맥락을 찾을 수 있습니다.', '답변': '네, 국방부에서 발표한 대로 그 관련 부분은 기록에 남아 있어서 정해진 절차에 따라 진행된 것으로 보고 있습니다. 그 외에 다른 사안들은 현재 검찰에서 수사 중이며 결과를 기다려야 합니다.', '답변_키워드': '국방부,  검찰,  수사'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=033256&fileType=PDF', 'row': 321}, page_content="{'회의날짜': '2005년6월08일(수)', '국회_대': '17', '회의명': '국회본회의', '회수': '제254회', '차수': '제3차', '안건': '통일․외교․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=033256&fileType=PDF', 'row': 321}, page_content="{'질문자_이름': '이원영 의원', '질문': '한미동맹은 비대칭적인 요소를 가지고 있을 수 있을까요?', '질문_키워드': '한미동맹,  기본적,  냉전주의적,  군사동맹,  비대칭적,  요소,  포함'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=033256&fileType=PDF', 'row': 321}, page_content="{'답변자_이름': '반기문 외교통상부 장관', '문맥': '제가 이전에 말씀드린 내용을 바탕으로 하면, 한미동맹은 냉전적인 요소를 가지고 있지 않습니다. 향후 50년을 내다보면 군사적인 측면 뿐 아니라 정치, 경제, 문화, 사회 등 다양한 분야를 아우르는 포괄적인 동맹으로 발전해야 합니다. 이러한 발전 과정에서 한미동맹은 양국 간의 협의와 협력을 통해 양자가 공동으로 이익을 창출할 수 있는 구조를 유지하고자 노력해야 합니다. 그리고 이러한 노력은 양국 간의 공동 번영과 안보를 위해서 중요한 요소가 될 것입니다.', '답변': '한미동맹은 냉전적인 요소를 가지고 있지 않으며, 향후 50년을 내다보면 군사적인 측면 뿐 아니라 정치, 경제, 문화, 사회 등 다양한 분야를 아우르는 포괄적인 동맹으로 발전해야 한다고 생각합니다.', '답변_키워드': '한미동맹,  분야,  냉전적,  요소,  포함,  한반도,  냉전,  첨예,  시대'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051986&fileType=PDF', 'row': 322}, page_content="{'회의날짜': '2022년7월25일(월)', '국회_대': '21', '회의명': '국회본회의', '회수': '제398회', '차수': '제5차', '안건': '정치․외교․통일․안보에 관한 질문', '법안': '정치․외교․통일․안보에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051986&fileType=PDF', 'row': 322}, page_content="{'질문자_이름': '윤상현 의원', '질문': '탈북 어민의 강제 북송 결정에 대해 통일부가 어떤 역할을 하나요?', '질문_키워드': '탈북어민, 강제북송, 결정'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051986&fileType=PDF', 'row': 322}, page_content="{'답변자_이름': '권영세 통일부 장관', '문맥': '제가 그 부분에 대해 명확히 말씀드릴 수 있는 것은 없습니다. 실제로 국정원 보고서의 내용을 확인하지 못했기 때문에, 탈북자의 귀순 의사가 그 보고서에 명시되었는지 결론을 내릴 수 없습니다. 국정원의 보고서가 포함할 수 있는 정보는 광범위하며, 만약 탈북자의 귀순 의사가 관련 보고서에 명확하게 기술되어 있다면, 그것은 이들 탈북자에 대한 정부의 처리 방침을 결정하는데 중요한 근거가 될 것입니다. 하지만 특정 보고서에 대해 구체적으로 어떤 정보가 담겨 있는지는 해당 문서를 직접 검토해본 후에야 비로소 분명해질 수 있으며, 제가 이 자리에서 그 내용에 대해 명확한 설명을 드리는 것은 적절하지 않습니다.', '답변': '통일부는 조사와 협의를 진행하는 역할을 수행합니다. 통일부는 탈북 어민의 의사를 확인하고, 북쪽으로 귀환할 것인지 아니면 대한민국에 남을 것인지를 결정하기 위해 탈북 어민과의 접촉과 협의를 진행합니다. 이를 통해 탈북 어민의 의사와 상황을 종합적으로 고려하여 결정을 내리게 됩니다.', '답변_키워드': '통일부, 북송, 탈북주민'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046180&fileType=PDF', 'row': 323}, page_content="{'회의날짜': '2016년7월04일(월)', '국회_대': '20', '회의명': '국회본회의', '회수': '제343회', '차수': '제6차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046180&fileType=PDF', 'row': 323}, page_content="{'질문자_이름': '이언주 의원', '질문': '국민들의 세금으로 지원받아온 기업들에 대한 지원체계와 감면제도에 대해 다시 검토할 필요성을 어떻게 평가하시나요?', '질문_키워드': '근본적,  필요,  국민들'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046180&fileType=PDF', 'row': 323}, page_content="{'답변자_이름': '유일호 기획재정부 부총리겸기획재정부장관', '문맥': '저희가 이전 대화에서 접한 내용은 국민들의 세금으로 지원받아온 기업들에 대한 지원체계와 감면제도에 대한 이야기였습니다. 상대적으로 높은 실효세율을 부과받는 중소기업과 대기업의 감면 혜택 차이, 그리고 R&D 투자세액공제의 효과, 법인세율의 혜택이 대부분 대기업에 쏠리는 문제 등에 대한 논의가 이어졌습니다.이러한 논의를 바탕으로 해당 감면제도와 지원방식의 공정성과 효율성을 평가할 필요성이 제기되었습니다. 특히 기업의 세금 감면체계와 지원방식이 국민들에게 공헌으로 이어지는지에 대한 검토가 필요하다는 의견도 나왔습니다.결론적으로, 지속적인 방안 강구를 통해 국민과 기업 간의 공정한 이익분배를 추구하고 해당 내용에 대한 국회 협의에 적극 참여하겠다는 의지를 표명한 것으로 판단됩니다.', '답변': '기업들의 세금 감면체계와 지원방식이 국민들에게 공헌으로 이어지지 않고 있어서, 이에 대한 검토가 필요하다고 생각합니다. 지속적인 방안 강구를 통해 국민과 기업 간의 공정한 이익분배를 추구할 것이며, 해당 내용에 대한 국회 협의에 적극 참여하겠습니다.', '답변_키워드': '국회,  지속적,  방안,  강구,  감면제도'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050202&fileType=PDF', 'row': 324}, page_content="{'회의날짜': '2020년9월17일(목)', '국회_대': '21', '회의명': '국회본회의', '회수': '제382회', '차수': '제7차', '안건': '교육·사회·문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050202&fileType=PDF', 'row': 324}, page_content="{'질문자_이름': '박영순 의원', '질문': '국민의 사회안전망 확충과 사회복지 정책에 대해 어떻게 생각하십니까?', '질문_키워드': '4대보험 가입률,  고용보험,  국민연금,  건강보험,  산재보험 가입자 수,  사각지대,  사회안전망 강화,  사회복지'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050202&fileType=PDF', 'row': 324}, page_content="{'답변자_이름': '정세균 국무총리', '문맥': '총리님은 국민의 사회안전망 확충과 사회복지 정책에 매우 긍정적으로 생각하십니다. 특히 문재인 정부 시기에 출산, 양육, 기초생활보장 및 자립지원, 의료비 부담 완화 등의 사회복지 정책이 대폭 확충되었으며, 국민들의 고통체감도 감소한 것을 느낄 수 있습니다. 정부의 강력한 역할과 사회안전망의 강화로 인해 국민들의 삶의 질이 향상되고, 취약계층에 대한 보호와 지원이 강화된 것으로 보이고 계십니다.', '답변': '국민의 사회안전망 확충과 사회복지 정책에 대해서는 매우 긍정적으로 생각합니다. 특히 문재인 정부 시기에 출산, 양육, 기초생활보장 및 자립지원, 의료비 부담 완화 등의 사회복지 정책이 대폭 확충되었으며, 국민들의 고통체감도 감소한 것을 느낄 수 있습니다. 정부의 강력한 역할과 사회안전망의 강화로 인해 국민들의 삶의 질이 향상되고, 취약계층에 대한 보호와 지원이 강화되었습니다.', '답변_키워드': '고용안전망,  사회안전망,  확충,  도산,  실업자'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=042819&fileType=PDF', 'row': 325}, page_content="{'회의날짜': '2013년6월11일(화)', '국회_대': '19', '회의명': '국회본회의', '회수': '제316회', '차수': '제5차', '안건': '외교․통일․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=042819&fileType=PDF', 'row': 325}, page_content="{'질문자_이름': '심윤조 의원', '질문': '미중 간에 북한의 비핵화에 대한 입장 차이가 있으며, 이번 회담 결과를 발표할 때 미묘한 표현의 차이가 있었습니다. 이에 대한 입장을 설명해주십시오.', '질문_키워드': '비핵화'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=042819&fileType=PDF', 'row': 325}, page_content="{'답변자_이름': '윤병세 외교부 장관', '문맥': '미국과 중국 간에는 북한 비핵화 문제에 대한 입장 차이가 있음에도 불구하고, 최근 정상 회담 결과 발표에서는 두 나라가 북한의 비핵화 원칙과 목표에 대해 동일한 입장을 가지고 있다는 점이 확인됐습니다. 이번 회담에서 중요한 발언에 따르면, 북한의 핵보유국 지위를 인정하지 않겠다는 공동의 뜻이 표명된 것입니다. 그럼에도 불구하고, 미국은 회담과 6자회담 복귀 자체로는 불충분하며, 북한이 진정성 있는 행동을 보여주지 않는 한 신뢰할 수 없다는 입장을 확고히 하고 있습니다. 한미 양국은 이 문제에 대해 긴밀하게 조율하고 있으며, 대화 재개를 위한 북한의 진정성 있는 태도를 요구하고 있습니다. 이는 단순한 대화 복귀가 아니라, 비핵화라는 구체적인 목표를 향한 진지한 논의가 중요하다는 것을 의미하며, 앞으로의 대화와 협상에서 이러한 접근 방식이 유지될 것으로 예상됩니다.', '답변': '미중 정상 간에는 이번 회담에서 북한의 비핵화 원칙과 목표에 대해 동일한 입장을 취했다고 이해됩니다. 미국은 북한의 핵보유국 지위를 인정하지 않으며, 단순히 6자회담으로 돌아가는 것은 부족하다고 판단하고 있습니다. 북한은 진정성 있는 행동을 보여야 믿을 수 있다는 입장을 강조하고 있으며, 미국과 한국은 이에 대한 조율을 진행하고 있습니다.', '답변_키워드': '비핵화,  북한'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046811&fileType=PDF', 'row': 326}, page_content="{'회의날짜': '2016년12월20일(화)', '국회_대': '20', '회의명': '국회본회의', '회수': '제347회', '차수': '제1차', '안건': '경제에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046811&fileType=PDF', 'row': 326}, page_content="{'질문자_이름': '정운천 의원', '질문': '10만 호를 큰 계획으로 세우기에는 어떤 이유로 그렇게 큰 투자를 고려하고 있으며, 1만 호에서의 실험 결과에 대한 어떤 도전과제를 고려하고 있나요?', '질문_키워드': '재생에너지, 계획'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=046811&fileType=PDF', 'row': 326}, page_content="{'답변자_이름': '주형환 산업통상자원부 장관', '문맥': '해당 내용은 에너지 분야에서 대규모 신·재생에너지 발전을 추진하기 위한 토론 내용으로 보입니다. 이는 1만 호 실험 결과를 바탕으로 10만 호의 큰 계획을 수립하기 위한 과정으로 이해될 수 있습니다. 이러한 큰 규모의 투자에 따른 도전과제를 고려하고 파일럿 실험의 중요성을 강조하는 것으로 보입니다.', '답변': '10만 호를 선택한 이유는 1만 호에서 얻은 성과를 기반으로 신·재생에너지 증가 효과를 최대화하려는 것입니다. 그러나 이는 동시에 큰 규모의 투자로 인한 도전과제에 대한 파일럿 실험의 중요성을 강조하는 것이기도 합니다.', '답변_키워드': '파일럿, 성과'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=047952&fileType=PDF', 'row': 327}, page_content="{'회의날짜': '2018년2월05일(월)', '국회_대': '20', '회의명': '국회본회의', '회수': '제356회', '차수': '제5차', '안건': '정치․외교․통일․안보에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=047952&fileType=PDF', 'row': 327}, page_content="{'질문자_이름': '안상수 위원', '질문': '한국 정부가 북한의 평창 올림픽 참가를 통해 핵무기를 완성하고 한미동맹에 균열을 만들려는 시도로 보이는데, 이에 대한 어떤 입장을 가지고 계십니까?', '질문_키워드': '평창, 올림픽, 핵무기, 완성, 시간, 한미동맹, 균열, 시도, 기만전술, 혈맹, 관계'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=047952&fileType=PDF', 'row': 327}, page_content="{'답변자_이름': '이낙연 국무총리', '문맥': '북한의 평창 올림픽 참가가 일부에서 우려를 불러일으키고 있음을 한국 정부는 인지하고 있으며, 이러한 참가를 통해 핵무기 완성과 한미동맹의 균열을 시도하는 것으로 볼 수 있습니다. 그럼에도 불구하고, 한국 정부는 북한과의 대화가 시작된 현재 상황이 긍정적인 변화라고 보고 있습니다. 이를 통해 북한의 추가적인 도발을 방지하고, 상황을 안정적으로 유지하며, 북한을 국제사회로 이끌어내는 등의 기회로 활용하고자 하는 입장입니다. 특히 한반도의 평화 증진과 긴장 완화를 목표로 하고 있으며, 이는 대화와 외교적 노력을 통해서만 해결할 수 있는 과제로 보고 노력을 기울이고 있습니다. 정부는 국제사회와의 협력을 중시하면서도 북한의 올림픽 참여를 계기로 한미동맹에 균열을 입히거나 북한의 기만적인 전술에 휘말릴 것이라는 우려에 대한 경계를 소홀히 하지 않고 있습니다.', '답변': '북한의 평창 올림픽 참가에 대한 우려는 이해하고 있습니다. 그러나 북한과의 대화 창이 열리는 것은 긍정적인 변화일 뿐만 아니라, 도발적인 시나리오로부터 우리를 보호하는 중요한 요소로도 간주되어 현재는 이 변화를 살려 나가기 위한 노력을 기울이고 있습니다.', '답변_키워드': '북한, 참가, 우려, 평창, 올림픽, 자체, 변화'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=
}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051995&fileType=PDF', 'row': 330}, page_content="{'회의날짜': '2022년7월27일(수)', '국회_대': '21', '회의명': '국회본회의', '회수': '제398회', '차수': '제7차', '안건': '교육․사회․문화에 관한 질문', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051995&fileType=PDF', 'row': 330}, page_content="{'질문자_이름': '김성주 의원', '질문': '윤석열 대통령의 연금개혁 목적은 무엇인가요?', '질문_키워드': '연금개혁'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=051995&fileType=PDF', 'row': 330}, page_content="{'답변자_이름': '한덕수 국무총리', '문맥': '윤석열 대통령의 연금개혁 목적은 2047년부터 연금이 지출이 들어오는 것보다 많아지기 시작하고, 2057년에는 축적된 재원이 소진될 것이며, 2070년에는 국가부채가 GDP의 200%를 넘어설 것으로 예상되는 상황을 방지하기 위함입니다. 이를 통해 국민연금의 재원 부족과 노후빈곤 문제에 대한 대비책을 마련하고, 지속 가능한 연금체계를 유지하고자 한다는 것이 윤석열 대통령의 목적입니다.', '답변': '윤석열 대통령은 더 내고 덜 받는 국민연금 개혁을 주장하였습니다. 그 목적은 2047년부터 연금이 지출이 들어오는 것보다 많아지기 시작하고, 2057년에는 축적된 재원이 소진될 것이며, 2070년에는 국가부채가 GDP의 200%를 넘어설 것으로 예상되는 상황을 방지하기 위함입니다.', '답변_키워드': '국민 세금, 국가부채, GDP'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050757&fileType=PDF', 'row': 331}, page_content="{'회의날짜': '2021년2월8일(월)', '국회_대': '21', '회의명': '국회본회의', '회수': '제384회', '차수': '제6차', '안건': '교육·사회·문화에 관한 질문(계속)', '법안': '교육·사회·문화에 관한 질문'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050757&fileType=PDF', 'row': 331}, page_content="{'질문자_이름': '박성중 의원', '질문': '서울시의 아파트 가격 상승은 서울시에서 공급이 부족한 것이 원인이라고 생각하시나요?', '질문_키워드': '아파트 가격, 임대차 3법'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050757&fileType=PDF', 'row': 331}, page_content="{'답변자_이름': '정세균 국무총리', '문맥': '대통령의 탈원전 결정과 북한 원전 지원 계획은 사실상 전례 없는 정책 방향의 전환을 나타냅니다. 이 결정들은 장기적인 에너지 정책의 변화를 통해 환경 문제에 대응하고, 국가의 지속 가능한 에너지 자원 관리를 목적으로 삼고 있습니다. 특히, 영화 한 편을 보고 영향을 받아 탈원전을 결정한 것이나, 월성 1호기의 조기 폐쇄, 그리고 북한 원전 지원을 검토한 것 등은 기존의 에너지 정책과 상이한 점이 많아 논란이 되고 있습니다. 산업부 공무원이 북한 원전 지원 문건을 삭제하는 등의 사태는 이러한 정책 전환 과정에서의 부주의함과 리스크를 드러내기도 하였습니다. 이러한 조치들은 에너지 안보와 경제 효율성, 환경 지속 가능성의 균형을 맞추는 복잡한 과제임에 틀림없으며, 그렇기 때문에 이에 대한 신중한 실증적 평가와 투명한 의사결정 절차는 물론, 광범위한 사회적 합의가 뒷받침되어야 할 것입니다.', '답변': '서울시의 아파트 가격 상승은 수요와 공급의 불균형에 기인한 것으로 보입니다. 서울시에서는 공급 부족으로 인해 수요와 공급의 균형이 깨져서 아파트 가격이 상승한 것으로 판단됩니다. 수요와 공급의 균형을 맞추기 위해 공급 확대가 필요한 시기입니다.', '답변_키워드': '공급확대 정책, 부동산 가격'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048404&fileType=PDF', 'row': 332}, page_content="{'회의날짜': '2018년10월04일(목)', '국회_대': '20', '회의명': '국회본회의', '회수': '제364회', '차수': '제9차', '안건': '교육․사회․문화에 관한 질문(계속)', '법안': '없음'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048404&fileType=PDF', 'row': 332}, page_content="{'질문자_이름': '정춘숙 의원', '질문': '증거물의 은닉 또는 폐기, 사후 재유포 시 구속수사를 강화하기 위해 수사 가이드라인을 재정비하거나 개선할 계획이 있나요?', '질문_키워드': '생각,  수,  압수수색,  가해자,  적극적,  처벌,  위법성,  증명,  증거,  신속'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=048404&fileType=PDF', 'row': 332}, page_content="{'답변자_이름': '김부겸 행정안전부 장관', '문맥': '불법촬영 범죄에 대한 정부 대책의 진행 상황과 관련하여 의원은 여성계의 지속적인 항의와 불안감을 언급하면서, 불법촬영과 관련된 콘텐츠의 유통 문제, 몰카 판매 규제의 부재, 웹하드 헤비업로드 처벌이 추진되지 못하고 있음을 지적했습니다. 기소율이 낮고 공중화장실 점검에 대한 미흡한 실적을 언급하며 혜화역 불법촬영 편파수사 항의집회에서 제기된 가해자에 대한 적극적인 처벌의 중요성을 강조했습니다. 의원은 신고 즉시 증거 확보의 중요성, 증거물의 은닉이나 폐기 가능성이 있는 경우 구속수사의 필요성, 온라인 계정을 압수수색 대상에 포함해야 한다고 주장했습니다. 이에 대해 행정안전부장관은 의원의 의견에 동의하고, 이미 개인 컴퓨터, 노트북, 웹하드 등 온라인 계정에 대해 압수수색을 시행하고 있으며, 구속수사와 관련하여 영장 기각률이 높다는 문제를 언급했습니다. 또한 법조계가 현실적인 문제에 좀 더 공감할 필요가 있다고 언급하며, 해외 서버를 이용한 불법촬영물 유통자의 자금 흐름 추적 및 강력 처벌, 국제공조를 통한 처벌의 중요성을 인정했으며, 수사인력 확충 계획도 밝혔습니다.', '답변': '현재의 수사 가이드라인을 재정비하여 증거물의 은닉, 폐기, 사후 재유포 시 구속수사를 효과적으로 강화하기 위한 계획이 있습니다. 또한, 불법촬영 영상물 관련 압수수색 대상으로서 이동저장장치뿐만 아니라 피의자의 온라인 계정을 적극적으로 포함시키고 있습니다.', '답변_키워드': '의원님,  경우,  저희들,  문제,  동의,  실질적,  경찰청,  확인,  불법촬영,  말씀'}"),
#  Document(metadata={'source': 'http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=050065&fileType=PDF', 'row': 333}, page_content="{'회의날짜': '2020년7월22일(수)', '국회_대': '21', '회의명': '국회본회의', '회수': '제380회', '차수': '제4차', '안건': '정치·외교·통일·안보에 관한 질문', '법안': '정치·외교·통일·안보에 관한 질문'}"),
#  ...]

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain_upstage import UpstageEmbeddings
from langchain_chroma import Chroma
from langchain.storage._lc_store import create_kv_docstore
from langchain.storage.file_system import LocalFileStore
# It should create documents smaller than the parent
child_splitter = CustomColumnSplitter()

# The vectorstore to use to index the child chunks
vectorstore = Chroma(
    collection_name="split_parents", embedding_function=UpstageEmbeddings(model="embedding-passage"),
    persist_directory='child_DB(Chroma, Upstage, Custom4)')

# The storage layer for the parent documents
fs = LocalFileStore('./parent_fs_chroma_Upstage_Custom4')
store = create_kv_docstore(fs)
big_chunk_retriever = ParentDocumentRetriever(
vectorstore=vectorstore,
docstore=store,
child_splitter=child_splitter)

# %%
from tqdm.notebook import tqdm
#
def embedding(a,b,MAX_BATCH_SIZE=100):
    #
    for i in tqdm(range(a,b,MAX_BATCH_SIZE)):
        print(f"start : {i}")
        i_end = min(len(docs),i+MAX_BATCH_SIZE)
        print(f"end: {i_end}")
        batch = docs[i:i_end]
        try:
            big_chunk_retriever.add_documents(batch, ids=None)
        except ValueError as e:
            print(e)
            #ct = i_end // 2
            temp = batch
            #print(ct)
            big_chunk_retriever.add_documents(temp[:50], ids=None)
            big_chunk_retriever.add_documents(temp[50:], ids=None)
            continue

        print(f"Number of keys stored in the doctstore :{len(list(store.yield_keys()))}")

# %% [markdown]
# ### embedding

# %%
embedding(0, 5100)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# start : 0
# end: 100
# Number of keys stored in the doctstore :100
# start : 100
# end: 200
# Number of keys stored in the doctstore :200
# start : 200
# end: 300
# Number of keys stored in the doctstore :300
# start : 300
# end: 400
# Number of keys stored in the doctstore :400
# start : 400
# end: 500
# Number of keys stored in the doctstore :500
# start : 500
# end: 600
# Number of keys stored in the doctstore :600
# start : 600
# end: 700
# Number of keys stored in the doctstore :700
# start : 700
# end: 800
# Number of keys stored in the doctstore :800
# start : 800
# end: 900
# Number of keys stored in the doctstore :900
# start : 900
# end: 1000
# Number of keys stored in the doctstore :1000
# start : 1000
# end: 1100
# Number of keys stored in the doctstore :1100
# start : 1100
# end: 1200
# Number of keys stored in the doctstore :1200
# start : 1200
# end: 1300
# Number of keys stored in the doctstore :1300
# start : 1300
# end: 1400
# Number of keys stored in the doctstore :1400
# start : 1400
# end: 1500
# Number of keys stored in the doctstore :1500
# start : 1500
# end: 1600
# Number of keys stored in the doctstore :1600
# start : 1600
# end: 1700
# Number of keys stored in the doctstore :1700
# start : 1700
# end: 1800
# Number of keys stored in the doctstore :1800
# start : 1800
# end: 1900
# Number of keys stored in the doctstore :1900
# start : 1900
# end: 2000
# Number of keys stored in the doctstore :2000
# start : 2000
# end: 2100
# Number of keys stored in the doctstore :2100
# start : 2100
# end: 2200
# Number of keys stored in the doctstore :2200
# start : 2200
# end: 2300
# Number of keys stored in the doctstore :2300
# start : 2300
# end: 2400
# Number of keys stored in the doctstore :2400
# start : 2400
# end: 2500
# Number of keys stored in the doctstore :2500
# start : 2500
# end: 2600
# Number of keys stored in the doctstore :2600
# start : 2600
# end: 2700
# Number of keys stored in the doctstore :2700
# start : 2700
# end: 2800
# Number of keys stored in the doctstore :2800
# start : 2800
# end: 2900
# Number of keys stored in the doctstore :2900
# start : 2900
# end: 3000
# Number of keys stored in the doctstore :3000
# start : 3000
# end: 3100
# Number of keys stored in the doctstore :3100
# start : 3100
# end: 3200
# Number of keys stored in the doctstore :3200
# start : 3200
# end: 3300
# Number of keys stored in the doctstore :3300
# start : 3300
# end: 3400
# Number of keys stored in the doctstore :3400
# start : 3400
# end: 3500
# Number of keys stored in the doctstore :3500
# start : 3500
# end: 3600
# Number of keys stored in the doctstore :3600
# start : 3600
# end: 3700
# Number of keys stored in the doctstore :3700
# start : 3700
# end: 3800
# Number of keys stored in the doctstore :3800
# start : 3800
# end: 3900
# Number of keys stored in the doctstore :3900
# start : 3900
# end: 4000
# Number of keys stored in the doctstore :4000
# start : 4000
# end: 4100
# Number of keys stored in the doctstore :4100
# start : 4100
# end: 4200
# Number of keys stored in the doctstore :4200
# start : 4200
# end: 4300
# Number of keys stored in the doctstore :4300
# start : 4300
# end: 4400
# Number of keys stored in the doctstore :4400
# start : 4400
# end: 4500
# Number of keys stored in the doctstore :4500
# start : 4500
# end: 4600
# Number of keys stored in the doctstore :4600
# start : 4600
# end: 4700
# Number of keys stored in the doctstore :4700
# start : 4700
# end: 4800
# Number of keys stored in the doctstore :4800
# start : 4800
# end: 4900
# Number of keys stored in the doctstore :4900
# start : 4900
# end: 5000
# Number of keys stored in the doctstore :5000
# start : 5000
# end: 5100
# Number of keys stored in the doctstore :5100

# %%
embedding(5100, 2*5100)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# start : 5100
# end: 5200
# Number of keys stored in the doctstore :5200
# start : 5200
# end: 5300
# Number of keys stored in the doctstore :5300
# start : 5300
# end: 5400
# Number of keys stored in the doctstore :5400
# start : 5400
# end: 5500
# Number of keys stored in the doctstore :5500
# start : 5500
# end: 5600
# Number of keys stored in the doctstore :5600
# start : 5600
# end: 5700
# Number of keys stored in the doctstore :5700
# start : 5700
# end: 5800
# Number of keys stored in the doctstore :5800
# start : 5800
# end: 5900
# Number of keys stored in the doctstore :5900
# start : 5900
# end: 6000
# Number of keys stored in the doctstore :6000
# start : 6000
# end: 6100
# Number of keys stored in the doctstore :6100
# start : 6100
# end: 6200
# Number of keys stored in the doctstore :6200
# start : 6200
# end: 6300
# Number of keys stored in the doctstore :6300
# start : 6300
# end: 6400
# Number of keys stored in the doctstore :6400
# start : 6400
# end: 6500
# Number of keys stored in the doctstore :6500
# start : 6500
# end: 6600
# Number of keys stored in the doctstore :6600
# start : 6600
# end: 6700
# Number of keys stored in the doctstore :6700
# start : 6700
# end: 6800
# Number of keys stored in the doctstore :6800
# start : 6800
# end: 6900
# Number of keys stored in the doctstore :6900
# start : 6900
# end: 7000
# Number of keys stored in the doctstore :7000
# start : 7000
# end: 7100
# Number of keys stored in the doctstore :7100
# start : 7100
# end: 7200
# Number of keys stored in the doctstore :7200
# start : 7200
# end: 7300
# Number of keys stored in the doctstore :7300
# start : 7300
# end: 7400
# Number of keys stored in the doctstore :7400
# start : 7400
# end: 7500
# Number of keys stored in the doctstore :7500
# start : 7500
# end: 7600
# Number of keys stored in the doctstore :7600
# start : 7600
# end: 7700
# Number of keys stored in the doctstore :7700
# start : 7700
# end: 7800
# Number of keys stored in the doctstore :7800
# start : 7800
# end: 7900
# Number of keys stored in the doctstore :7900
# start : 7900
# end: 8000
# Number of keys stored in the doctstore :8000
# start : 8000
# end: 8100
# Number of keys stored in the doctstore :8100
# start : 8100
# end: 8200
# Number of keys stored in the doctstore :8200
# start : 8200
# end: 8300
# Number of keys stored in the doctstore :8300
# start : 8300
# end: 8400
# Number of keys stored in the doctstore :8400
# start : 8400
# end: 8500
# Number of keys stored in the doctstore :8500
# start : 8500
# end: 8600
# Number of keys stored in the doctstore :8600
# start : 8600
# end: 8700
# Number of keys stored in the doctstore :8700
# start : 8700
# end: 8800
# Number of keys stored in the doctstore :8800
# start : 8800
# end: 8900
# Number of keys stored in the doctstore :8900
# start : 8900
# end: 9000
# Number of keys stored in the doctstore :9000
# start : 9000
# end: 9100
# Number of keys stored in the doctstore :9100
# start : 9100
# end: 9200
# Number of keys stored in the doctstore :9200
# start : 9200
# end: 9300
# Number of keys stored in the doctstore :9300
# start : 9300
# end: 9400
# Number of keys stored in the doctstore :9400
# start : 9400
# end: 9500
# Number of keys stored in the doctstore :9500
# start : 9500
# end: 9600
# Number of keys stored in the doctstore :9600
# start : 9600
# end: 9700
# Number of keys stored in the doctstore :9700
# start : 9700
# end: 9800
# Number of keys stored in the doctstore :9800
# start : 9800
# end: 9900
# Number of keys stored in the doctstore :9900
# start : 9900
# end: 10000
# Number of keys stored in the doctstore :10000
# start : 10000
# end: 10100
# Number of keys stored in the doctstore :10100
# start : 10100
# end: 10200
# Number of keys stored in the doctstore :10200

# %%
embedding(2*5100, 3*5100)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# start : 10200
# end: 10300
# Number of keys stored in the doctstore :10300
# start : 10300
# end: 10400
# Number of keys stored in the doctstore :10400
# start : 10400
# end: 10500
# Number of keys stored in the doctstore :10500
# start : 10500
# end: 10600
# Number of keys stored in the doctstore :10600
# start : 10600
# end: 10700
# Number of keys stored in the doctstore :10700
# start : 10700
# end: 10800
# Number of keys stored in the doctstore :10800
# start : 10800
# end: 10900
# Number of keys stored in the doctstore :10900
# start : 10900
# end: 11000
# Number of keys stored in the doctstore :11000
# start : 11000
# end: 11100
# Number of keys stored in the doctstore :11100
# start : 11100
# end: 11200
# Number of keys stored in the doctstore :11200
# start : 11200
# end: 11300
# Number of keys stored in the doctstore :11300
# start : 11300
# end: 11400
# Number of keys stored in the doctstore :11400
# start : 11400
# end: 11500
# Number of keys stored in the doctstore :11500
# start : 11500
# end: 11600
# Number of keys stored in the doctstore :11600
# start : 11600
# end: 11700
# Number of keys stored in the doctstore :11700
# start : 11700
# end: 11800
# Number of keys stored in the doctstore :11800
# start : 11800
# end: 11900
# Number of keys stored in the doctstore :11900
# start : 11900
# end: 12000
# Number of keys stored in the doctstore :12000
# start : 12000
# end: 12100
# Number of keys stored in the doctstore :12100
# start : 12100
# end: 12200
# Number of keys stored in the doctstore :12200
# start : 12200
# end: 12300
# Number of keys stored in the doctstore :12300
# start : 12300
# end: 12400
# Number of keys stored in the doctstore :12400
# start : 12400
# end: 12500
# Number of keys stored in the doctstore :12500
# start : 12500
# end: 12600
# Number of keys stored in the doctstore :12600
# start : 12600
# end: 12700
# Number of keys stored in the doctstore :12700
# start : 12700
# end: 12800
# Number of keys stored in the doctstore :12800
# start : 12800
# end: 12900
# Number of keys stored in the doctstore :12900
# start : 12900
# end: 13000
# Number of keys stored in the doctstore :13000
# start : 13000
# end: 13100
# Number of keys stored in the doctstore :13100
# start : 13100
# end: 13200
# Number of keys stored in the doctstore :13200
# start : 13200
# end: 13300
# Number of keys stored in the doctstore :13300
# start : 13300
# end: 13400
# Number of keys stored in the doctstore :13400
# start : 13400
# end: 13500
# Number of keys stored in the doctstore :13500
# start : 13500
# end: 13600
# Number of keys stored in the doctstore :13600
# start : 13600
# end: 13700
# Number of keys stored in the doctstore :13700
# start : 13700
# end: 13800
# Number of keys stored in the doctstore :13800
# start : 13800
# end: 13900
# Number of keys stored in the doctstore :13900
# start : 13900
# end: 14000
# Number of keys stored in the doctstore :14000
# start : 14000
# end: 14100
# Number of keys stored in the doctstore :14100
# start : 14100
# end: 14200
# Number of keys stored in the doctstore :14200
# start : 14200
# end: 14300
# Number of keys stored in the doctstore :14300
# start : 14300
# end: 14400
# Number of keys stored in the doctstore :14400
# start : 14400
# end: 14500
# Number of keys stored in the doctstore :14500
# start : 14500
# end: 14600
# Number of keys stored in the doctstore :14600
# start : 14600
# end: 14700
# Number of keys stored in the doctstore :14700
# start : 14700
# end: 14800
# Number of keys stored in the doctstore :14800
# start : 14800
# end: 14900
# Number of keys stored in the doctstore :14900
# start : 14900
# end: 15000
# Number of keys stored in the doctstore :15000
# start : 15000
# end: 15100
# Number of keys stored in the doctstore :15100
# start : 15100
# end: 15200
# Number of keys stored in the doctstore :15200
# start : 15200
# end: 15300
# Number of keys stored in the doctstore :15300

# %% [markdown]
# **여기서부터 다시!!!**

# %%
embedding(3*5100, 4*5100)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# start : 15300
# end: 15400
# Number of keys stored in the doctstore :15400
# start : 15400
# end: 15500
# Number of keys stored in the doctstore :15500
# start : 15500
# end: 15600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 embedding(3*5100, 4*5100)
#
# Cell In[108], line 11, in embedding(a, b, MAX_BATCH_SIZE)
#       9 batch = docs[i:i_end]
#      10 try:
# ---> 11     big_chunk_retriever.add_documents(batch, ids=None)
#      12 except ValueError as e:
#      13     print(e)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain/retrievers/parent_document_retriever.py:133, in ParentDocumentRetriever.add_documents(self, documents, ids, add_to_docstore, **kwargs)
#     118 """Adds documents to the docstore and vectorstores.
#     119
#     120 Args:
#    (...)
#     130         and you don't want to re-add them.
#     131 """
#     132 docs, full_docs = self._split_docs_for_adding(documents, ids, add_to_docstore)
# --> 133 self.vectorstore.add_documents(docs, **kwargs)
#     134 if add_to_docstore:
#     135     self.docstore.mset(full_docs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_core/vectorstores/base.py:287, in VectorStore.add_documents(self, documents, **kwargs)
#     285     texts = [doc.page_content for doc in documents]
#     286     metadatas = [doc.metadata for doc in documents]
# --> 287     return self.add_texts(texts, metadatas, **kwargs)
#     288 msg = (
#     289     f"`add_documents` and `add_texts` has not been implemented "
#     290     f"for {self.__class__.__name__} "
#     291 )
#     292 raise NotImplementedError(msg)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_chroma/vectorstores.py:508, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     506 texts = list(texts)
#     507 if self._embedding_function is not None:
# --> 508     embeddings = self._embedding_function.embed_documents(texts)
#     509 if metadatas:
#     510     # fill metadatas with empty dicts if somebody
#     511     # did not specify metadata for all texts
#     512     length_diff = len(texts) - len(metadatas)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_upstage/embeddings.py:215, in UpstageEmbeddings.embed_documents(self, texts)
#     213 for i in range(0, len(texts), batch_size):
#     214     batch = texts[i : i + batch_size]
# --> 215     data = self.client.create(input=batch, **params).data
#     216     embeddings.extend([r.embedding for r in data])
#     218 return embeddings
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     118         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     119             base64.b64decode(data), dtype="float32"
#     120         ).tolist()
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1268, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1254 def post(
#    1255     self,
#    1256     path: str,
#    (...)
#    1263     stream_cls: type[_StreamT] | None = None,
#    1264 ) -> ResponseT | _StreamT:
#    1265     opts = FinalRequestOptions.construct(
#    1266         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1267     )
# -> 1268     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:945, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     942 else:
#     943     retries_taken = 0
# --> 945 return self._request(
#     946     cast_to=cast_to,
#     947     options=options,
#     948     stream=stream,
#     949     stream_cls=stream_cls,
#     950     retries_taken=retries_taken,
#     951 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:981, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     978 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     980 try:
# --> 981     response = self._client.send(
#     982         request,
#     983         stream=stream or self._should_stream_response_body(request=request),
#     984         **kwargs,
#     985     )
#     986 except httpx.TimeoutException as err:
#     987     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
embedding(15500, 4*5100)
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
# start : 15500
# end: 15600
# Number of keys stored in the doctstore :15600
# start : 15600
# end: 15700
# Number of keys stored in the doctstore :15700
# start : 15700
# end: 15800
# Number of keys stored in the doctstore :15800
# start : 15800
# end: 15900
# Number of keys stored in the doctstore :15900
# start : 15900
# end: 16000
# Number of keys stored in the doctstore :16000
# start : 16000
# end: 16100
# Number of keys stored in the doctstore :16100
# start : 16100
# end: 16200
# Number of keys stored in the doctstore :16200
# start : 16200
# end: 16300
# Number of keys stored in the doctstore :16300
# start : 16300
# end: 16400
# Number of keys stored in the doctstore :16400
# start : 16400
# end: 16500
# Number of keys stored in the doctstore :16500
# start : 16500
# end: 16600
# Number of keys stored in the doctstore :16600
# start : 16600
# end: 16700
# Number of keys stored in the doctstore :16700
# start : 16700
# end: 16800
# Number of keys stored in the doctstore :16800
# start : 16800
# end: 16900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 embedding(15500, 4*5100)
#
# Cell In[108], line 11, in embedding(a, b, MAX_BATCH_SIZE)
#       9 batch = docs[i:i_end]
#      10 try:
# ---> 11     big_chunk_retriever.add_documents(batch, ids=None)
#      12 except ValueError as e:
#      13     print(e)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain/retrievers/parent_document_retriever.py:133, in ParentDocumentRetriever.add_documents(self, documents, ids, add_to_docstore, **kwargs)
#     118 """Adds documents to the docstore and vectorstores.
#     119
#     120 Args:
#    (...)
#     130         and you don't want to re-add them.
#     131 """
#     132 docs, full_docs = self._split_docs_for_adding(documents, ids, add_to_docstore)
# --> 133 self.vectorstore.add_documents(docs, **kwargs)
#     134 if add_to_docstore:
#     135     self.docstore.mset(full_docs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_core/vectorstores/base.py:287, in VectorStore.add_documents(self, documents, **kwargs)
#     285     texts = [doc.page_content for doc in documents]
#     286     metadatas = [doc.metadata for doc in documents]
# --> 287     return self.add_texts(texts, metadatas, **kwargs)
#     288 msg = (
#     289     f"`add_documents` and `add_texts` has not been implemented "
#     290     f"for {self.__class__.__name__} "
#     291 )
#     292 raise NotImplementedError(msg)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_chroma/vectorstores.py:508, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     506 texts = list(texts)
#     507 if self._embedding_function is not None:
# --> 508     embeddings = self._embedding_function.embed_documents(texts)
#     509 if metadatas:
#     510     # fill metadatas with empty dicts if somebody
#     511     # did not specify metadata for all texts
#     512     length_diff = len(texts) - len(metadatas)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_upstage/embeddings.py:215, in UpstageEmbeddings.embed_documents(self, texts)
#     213 for i in range(0, len(texts), batch_size):
#     214     batch = texts[i : i + batch_size]
# --> 215     data = self.client.create(input=batch, **params).data
#     216     embeddings.extend([r.embedding for r in data])
#     218 return embeddings
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     118         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     119             base64.b64decode(data), dtype="float32"
#     120         ).tolist()
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1268, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1254 def post(
#    1255     self,
#    1256     path: str,
#    (...)
#    1263     stream_cls: type[_StreamT] | None = None,
#    1264 ) -> ResponseT | _StreamT:
#    1265     opts = FinalRequestOptions.construct(
#    1266         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1267     )
# -> 1268     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:945, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     942 else:
#     943     retries_taken = 0
# --> 945 return self._request(
#     946     cast_to=cast_to,
#     947     options=options,
#     948     stream=stream,
#     949     stream_cls=stream_cls,
#     950     retries_taken=retries_taken,
#     951 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:981, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     978 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     980 try:
# --> 981     response = self._client.send(
#     982         request,
#     983         stream=stream or self._should_stream_response_body(request=request),
#     984         **kwargs,
#     985     )
#     986 except httpx.TimeoutException as err:
#     987     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
embedding(4*5100, 5*5100)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# start : 20400
# end: 20500
# Number of keys stored in the doctstore :20500
# start : 20500
# end: 20600
# Number of keys stored in the doctstore :20600
# start : 20600
# end: 20700
# Number of keys stored in the doctstore :20700
# start : 20700
# end: 20800
# Number of keys stored in the doctstore :20800
# start : 20800
# end: 20900
# Number of keys stored in the doctstore :20900
# start : 20900
# end: 21000
# Number of keys stored in the doctstore :21000
# start : 21000
# end: 21100
# Number of keys stored in the doctstore :21100
# start : 21100
# end: 21200
# Number of keys stored in the doctstore :21200
# start : 21200
# end: 21300
# Number of keys stored in the doctstore :21300
# start : 21300
# end: 21400
# Number of keys stored in the doctstore :21400
# start : 21400
# end: 21500
# Number of keys stored in the doctstore :21500
# start : 21500
# end: 21600
# Number of keys stored in the doctstore :21600
# start : 21600
# end: 21700
# Number of keys stored in the doctstore :21700
# start : 21700
# end: 21800
# Number of keys stored in the doctstore :21800
# start : 21800
# end: 21900
# Number of keys stored in the doctstore :21900
# start : 21900
# end: 22000
# Number of keys stored in the doctstore :22000
# start : 22000
# end: 22100
# Number of keys stored in the doctstore :22100
# start : 22100
# end: 22200
# Number of keys stored in the doctstore :22200
# start : 22200
# end: 22300
# Number of keys stored in the doctstore :22300
# start : 22300
# end: 22400
# Number of keys stored in the doctstore :22400
# start : 22400
# end: 22500
# Number of keys stored in the doctstore :22500
# start : 22500
# end: 22600
# Number of keys stored in the doctstore :22600
# start : 22600
# end: 22700
# Number of keys stored in the doctstore :22700
# start : 22700
# end: 22800
# Number of keys stored in the doctstore :22800
# start : 22800
# end: 22900
# Number of keys stored in the doctstore :22900
# start : 22900
# end: 23000
# Number of keys stored in the doctstore :23000
# start : 23000
# end: 23100
# Number of keys stored in the doctstore :23100
# start : 23100
# end: 23200
# Number of keys stored in the doctstore :23200
# start : 23200
# end: 23300
# Number of keys stored in the doctstore :23300
# start : 23300
# end: 23400
# Number of keys stored in the doctstore :23400
# start : 23400
# end: 23500
# Number of keys stored in the doctstore :23500
# start : 23500
# end: 23600
# Number of keys stored in the doctstore :23600
# start : 23600
# end: 23700
# Number of keys stored in the doctstore :23700
# start : 23700
# end: 23800
# Number of keys stored in the doctstore :23800
# start : 23800
# end: 23900
# Number of keys stored in the doctstore :23900
# start : 23900
# end: 24000
# Number of keys stored in the doctstore :24000
# start : 24000
# end: 24100
# Number of keys stored in the doctstore :24100
# start : 24100
# end: 24200
# Number of keys stored in the doctstore :24200
# start : 24200
# end: 24300
# Number of keys stored in the doctstore :24300
# start : 24300
# end: 24400
# Number of keys stored in the doctstore :24400
# start : 24400
# end: 24500
# Number of keys stored in the doctstore :24500
# start : 24500
# end: 24600
# Number of keys stored in the doctstore :24600
# start : 24600
# end: 24700
# Number of keys stored in the doctstore :24700
# start : 24700
# end: 24800
# Number of keys stored in the doctstore :24800
# start : 24800
# end: 24900
# Number of keys stored in the doctstore :24900
# start : 24900
# end: 25000
# Number of keys stored in the doctstore :25000
# start : 25000
# end: 25100
# Number of keys stored in the doctstore :25100
# start : 25100
# end: 25200
# Number of keys stored in the doctstore :25200
# start : 25200
# end: 25300
# Number of keys stored in the doctstore :25300
# start : 25300
# end: 25400
# Number of keys stored in the doctstore :25400
# start : 25400
# end: 25500
# Number of keys stored in the doctstore :25500

# %%
embedding(5*5100, 6*5100)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# start : 25500
# end: 25600
# Number of keys stored in the doctstore :25600
# start : 25600
# end: 25700
# Number of keys stored in the doctstore :25700
# start : 25700
# end: 25800
# Number of keys stored in the doctstore :25800
# start : 25800
# end: 25900
# Number of keys stored in the doctstore :25900
# start : 25900
# end: 26000
# Number of keys stored in the doctstore :26000
# start : 26000
# end: 26100
# Number of keys stored in the doctstore :26100
# start : 26100
# end: 26200
# Number of keys stored in the doctstore :26200
# start : 26200
# end: 26300
# Number of keys stored in the doctstore :26300
# start : 26300
# end: 26400
# Number of keys stored in the doctstore :26400
# start : 26400
# end: 26500
# Number of keys stored in the doctstore :26500
# start : 26500
# end: 26600
# Number of keys stored in the doctstore :26600
# start : 26600
# end: 26700
# Number of keys stored in the doctstore :26700
# start : 26700
# end: 26800
# Number of keys stored in the doctstore :26800
# start : 26800
# end: 26900
# Number of keys stored in the doctstore :26900
# start : 26900
# end: 27000
# Number of keys stored in the doctstore :27000
# start : 27000
# end: 27100
# Number of keys stored in the doctstore :27100
# start : 27100
# end: 27200
# Number of keys stored in the doctstore :27200
# start : 27200
# end: 27300
# Number of keys stored in the doctstore :27300
# start : 27300
# end: 27400
# Number of keys stored in the doctstore :27400
# start : 27400
# end: 27500
# Number of keys stored in the doctstore :27500
# start : 27500
# end: 27600
# Number of keys stored in the doctstore :27600
# start : 27600
# end: 27700
# Number of keys stored in the doctstore :27700
# start : 27700
# end: 27800
# Number of keys stored in the doctstore :27800
# start : 27800
# end: 27900
# Number of keys stored in the doctstore :27900
# start : 27900
# end: 28000
# Number of keys stored in the doctstore :28000
# start : 28000
# end: 28100
# Number of keys stored in the doctstore :28100
# start : 28100
# end: 28200
# Number of keys stored in the doctstore :28200
# start : 28200
# end: 28300
# Number of keys stored in the doctstore :28300
# start : 28300
# end: 28400
# Number of keys stored in the doctstore :28400
# start : 28400
# end: 28500
# Number of keys stored in the doctstore :28500
# start : 28500
# end: 28600
# Number of keys stored in the doctstore :28600
# start : 28600
# end: 28700
# Number of keys stored in the doctstore :28700
# start : 28700
# end: 28800
# Number of keys stored in the doctstore :28800
# start : 28800
# end: 28900
# Number of keys stored in the doctstore :28900
# start : 28900
# end: 29000
# Number of keys stored in the doctstore :29000
# start : 29000
# end: 29100
# Number of keys stored in the doctstore :29100
# start : 29100
# end: 29200
# Number of keys stored in the doctstore :29200
# start : 29200
# end: 29300
# Number of keys stored in the doctstore :29300
# start : 29300
# end: 29400
# Number of keys stored in the doctstore :29400
# start : 29400
# end: 29500
# Number of keys stored in the doctstore :29500
# start : 29500
# end: 29600
# Number of keys stored in the doctstore :29600
# start : 29600
# end: 29700
# Number of keys stored in the doctstore :29700
# start : 29700
# end: 29800
# Number of keys stored in the doctstore :29800
# start : 29800
# end: 29900
# Number of keys stored in the doctstore :29900
# start : 29900
# end: 30000
# Number of keys stored in the doctstore :30000
# start : 30000
# end: 30100
# Number of keys stored in the doctstore :30100
# start : 30100
# end: 30200
# Number of keys stored in the doctstore :30200
# start : 30200
# end: 30300
# Number of keys stored in the doctstore :30300
# start : 30300
# end: 30400
# Number of keys stored in the doctstore :30400
# start : 30400
# end: 30500
# Number of keys stored in the doctstore :30500
# start : 30500
# end: 30600
# Number of keys stored in the doctstore :30600

# %%
embedding(6*5100, 35231)
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]
# start : 30600
# end: 30700
# Number of keys stored in the doctstore :30700
# start : 30700
# end: 30800
# Number of keys stored in the doctstore :30800
# start : 30800
# end: 30900
# Number of keys stored in the doctstore :30900
# start : 30900
# end: 31000
# Number of keys stored in the doctstore :31000
# start : 31000
# end: 31100
# Number of keys stored in the doctstore :31100
# start : 31100
# end: 31200
# Number of keys stored in the doctstore :31200
# start : 31200
# end: 31300
# Number of keys stored in the doctstore :31300
# start : 31300
# end: 31400
# Number of keys stored in the doctstore :31400
# start : 31400
# end: 31500
# Number of keys stored in the doctstore :31500
# start : 31500
# end: 31600
# Number of keys stored in the doctstore :31600
# start : 31600
# end: 31700
# Number of keys stored in the doctstore :31700
# start : 31700
# end: 31800
# Number of keys stored in the doctstore :31800
# start : 31800
# end: 31900
# Number of keys stored in the doctstore :31900
# start : 31900
# end: 32000
# Number of keys stored in the doctstore :32000
# start : 32000
# end: 32100
# Number of keys stored in the doctstore :32100
# start : 32100
# end: 32200
# Number of keys stored in the doctstore :32200
# start : 32200
# end: 32300
# Number of keys stored in the doctstore :32300
# start : 32300
# end: 32400
# Number of keys stored in the doctstore :32400
# start : 32400
# end: 32500
# Number of keys stored in the doctstore :32500
# start : 32500
# end: 32600
# Number of keys stored in the doctstore :32600
# start : 32600
# end: 32700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 embedding(6*5100, 35231)
#
# Cell In[73], line 11, in embedding(a, b, MAX_BATCH_SIZE)
#       9 batch = docs[i:i_end]
#      10 try:
# ---> 11     big_chunk_retriever.add_documents(batch, ids=None)
#      12 except ValueError as e:
#      13     print(e)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain/retrievers/parent_document_retriever.py:133, in ParentDocumentRetriever.add_documents(self, documents, ids, add_to_docstore, **kwargs)
#     118 """Adds documents to the docstore and vectorstores.
#     119
#     120 Args:
#    (...)
#     130         and you don't want to re-add them.
#     131 """
#     132 docs, full_docs = self._split_docs_for_adding(documents, ids, add_to_docstore)
# --> 133 self.vectorstore.add_documents(docs, **kwargs)
#     134 if add_to_docstore:
#     135     self.docstore.mset(full_docs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_core/vectorstores/base.py:287, in VectorStore.add_documents(self, documents, **kwargs)
#     285     texts = [doc.page_content for doc in documents]
#     286     metadatas = [doc.metadata for doc in documents]
# --> 287     return self.add_texts(texts, metadatas, **kwargs)
#     288 msg = (
#     289     f"`add_documents` and `add_texts` has not been implemented "
#     290     f"for {self.__class__.__name__} "
#     291 )
#     292 raise NotImplementedError(msg)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_chroma/vectorstores.py:508, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     506 texts = list(texts)
#     507 if self._embedding_function is not None:
# --> 508     embeddings = self._embedding_function.embed_documents(texts)
#     509 if metadatas:
#     510     # fill metadatas with empty dicts if somebody
#     511     # did not specify metadata for all texts
#     512     length_diff = len(texts) - len(metadatas)
#
# File /opt/anaconda3/lib/python3.11/site-packages/langchain_upstage/embeddings.py:215, in UpstageEmbeddings.embed_documents(self, texts)
#     213 for i in range(0, len(texts), batch_size):
#     214     batch = texts[i : i + batch_size]
# --> 215     data = self.client.create(input=batch, **params).data
#     216     embeddings.extend([r.embedding for r in data])
#     218 return embeddings
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     118         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     119             base64.b64decode(data), dtype="float32"
#     120         ).tolist()
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1268, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1254 def post(
#    1255     self,
#    1256     path: str,
#    (...)
#    1263     stream_cls: type[_StreamT] | None = None,
#    1264 ) -> ResponseT | _StreamT:
#    1265     opts = FinalRequestOptions.construct(
#    1266         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1267     )
# -> 1268     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:945, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     942 else:
#     943     retries_taken = 0
# --> 945 return self._request(
#     946     cast_to=cast_to,
#     947     options=options,
#     948     stream=stream,
#     949     stream_cls=stream_cls,
#     950     retries_taken=retries_taken,
#     951 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:981, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     978 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     980 try:
# --> 981     response = self._client.send(
#     982         request,
#     983         stream=stream or self._should_stream_response_body(request=request),
#     984         **kwargs,
#     985     )
#     986 except httpx.TimeoutException as err:
#     987     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
len(list(store.yield_keys()))
# Out:
# 32600

# %%
embedding(32600, 35231)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# start : 32600
# end: 32700
# Number of keys stored in the doctstore :32700
# start : 32700
# end: 32800
# Number of keys stored in the doctstore :32800
# start : 32800
# end: 32900
# Number of keys stored in the doctstore :32900
# start : 32900
# end: 33000
# Number of keys stored in the doctstore :33000
# start : 33000
# end: 33100
# Number of keys stored in the doctstore :33100
# start : 33100
# end: 33200
# Number of keys stored in the doctstore :33200
# start : 33200
# end: 33300
# Number of keys stored in the doctstore :33300
# start : 33300
# end: 33400
# Number of keys stored in the doctstore :33400
# start : 33400
# end: 33500
# Number of keys stored in the doctstore :33500
# start : 33500
# end: 33600
# Number of keys stored in the doctstore :33600
# start : 33600
# end: 33700
# Number of keys stored in the doctstore :33700
# start : 33700
# end: 33800
# Number of keys stored in the doctstore :33800
# start : 33800
# end: 33900
# Number of keys stored in the doctstore :33900
# start : 33900
# end: 34000
# Number of keys stored in the doctstore :34000
# start : 34000
# end: 34100
# Number of keys stored in the doctstore :34100
# start : 34100
# end: 34200
# Number of keys stored in the doctstore :34200
# start : 34200
# end: 34300
# Number of keys stored in the doctstore :34300
# start : 34300
# end: 34400
# Number of keys stored in the doctstore :34400
# start : 34400
# end: 34500
# Number of keys stored in the doctstore :34500
# start : 34500
# end: 34600
# Number of keys stored in the doctstore :34600
# start : 34600
# end: 34700
# Number of keys stored in the doctstore :34700
# start : 34700
# end: 34800
# Number of keys stored in the doctstore :34800
# start : 34800
# end: 34900
# Number of keys stored in the doctstore :34900
# start : 34900
# end: 35000
# Number of keys stored in the doctstore :35000
# start : 35000
# end: 35100
# Number of keys stored in the doctstore :35100
# start : 35100
# end: 35200
# Number of keys stored in the doctstore :35200
# start : 35200
# end: 35231
# Number of keys stored in the doctstore :35231

# %% [markdown]
# ### RAG 진행

# %%
def RAG_experiment(query):
    sub_docs = vectorstore.similarity_search(query)

    print("Sub Document")
    print("글 길이: {}\n\n".format(len(sub_docs[0].page_content)))
    print(sub_docs[0].page_content)

    retrieved_docs = big_chunk_retriever.invoke(query)
    print("Retrieved Document")
    print("글 길이: {}\n\n".format(len(retrieved_docs[0].page_content)))
    print(retrieved_docs[0].page_content)

# %%
RAG_experiment("한덕수 총리가 무역적자에 관해 언급한 내용은 무엇인가요?")
# Out:
# Sub Document
# 글 길이: 389
#
#
# {'답변자_이름': '한덕수 국무총리', '문맥': "'무역적자가 28년 만에 발생한 이유는 중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.'", '답변': '중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.', '답변_키워드': '중국, 원칙'}
# Retrieved Document
# 글 길이: 528
#
#
# 회의날짜: 2022년7월26일(화)
# 국회_대: 21
# 회의명: 국회본회의
# 회수: 제398회
# 차수: 제6차
# 안건: 경제에 관한 질문
# 법안: 경제에 관한 질문
# 질문자_이름: 김경협  의원
# 질문: 무역적자가 28년 만에 발생한 이유는 무엇이라고 생각하십니까?
# 질문_키워드: 국제사회, 무역적자
# 문맥: '무역적자가 28년 만에 발생한 이유는 중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.'
# 답변자_이름: 한덕수 국무총리
# 답변: 중국의 경제 성장이 둔화하고 중국의 산업 정책이 변화함에 따라 우리의 중국 수출 퍼텐셜이 줄어들었기 때문이라고 생각합니다. 여기에 중국의 글로벌 서플라이 체인 변화도 영향을 미치고 있습니다. 이로 인해 우리는 미래 수출을 다원화하고 다변화해야 할 필요가 있다고 생각합니다.
# 답변_키워드: 중국, 원칙

# %%
RAG_experiment("공공의료대학에 대한 정부의 입장은 무엇인가요?")
# Out:
# Sub Document
# 글 길이: 906
#
#
# {'답변자_이름': '정세균 국무총리', '문맥': '정부와 국회 양쪽에서 공공의료대학 설립 법안의 통과에 대한 노력의 중요성은 공감대가 형성되어 있으나 실제로 법안이 통과되지 못하는 현 상황에 대해 유감의 목소리가 커지고 있습니다. 이를 통해 필수 의료분야, 특히 감염병과 같은 공중보건 위기에 대비하는 의료 전문가를 양성하는 기관의 중요성 또한 강조되고 있습니다. 사회적인 필요성과 과거의 경험 (메르스 사태 등)으로 볼 때, 이런 전문의를 양성하는 공공의료대학이 필요한 시점임에도 불구하고, 정치적 의사 결정 과정의 지연으로 인해 여러 문제가 발생하고 있습니다. 국회는 법안을 입법화해야 할 책임이 있는 기관으로, 과거에는 다수결의 원칙이 어느 정도 작동하여 중요 법안들이 통과될 수 있었지만, 현재는 몇몇 의원들의 반대로 입법 과정이 지연되거나 불발되는 상황이 발생하고 있습니다. 이는 의료 시스템 내의 구조적 문제를 해결하고 질병 대응 역량을 강화하려는 노력에 걸림돌이 되고 있으며, 이에 대해 큰 우려를 나타내고 있는 것입니다. 따라서, 공공의료대학 설립을 통한 의료 시스템의 강화는 국회에서 긴급히 검토하고 통과시켜야 할 사안으로 보이며, 이대로 정책이 지체될 경우 공중보건 위기 상황에서의 대응력이 약화될 수 있음을 의미합니다. 정부는 법안을 적극적으로 옹호하고 필요한 조치를 취해야 할 책임이 있으며, 국회 또한 공공의 이익을 위해 신속하고 효과적으로 기능해야 한다는 점이 강조되고 있습니다.', '답변': '공공의료대학 설립 법안이 국회에서 통과되지 못하는 상황을 유감스럽게 생각하며, 과거의 다수결 원리가 작동하지 않아 입법이 불발하는 문제를 지적하고 있습니다. 공공의료대학 설립은 근본적인 대책으로, 5월 국회에서 반드시 통과시켜야 한다고 주장하고 있습니다.', '답변_키워드': '공공의료대학'}
# Retrieved Document
# 글 길이: 1111
#
#
# 회의날짜: 2020년3월11일(수)
# 국회_대: 20
# 회의명: 예산결산특별위원회
# 회수: 제376회
# 차수: 제1차
# 안건: 2020년도 고용보험기금운용계획변경안
# 법안: 없음
# 질문자_이름: 이용호 위원
# 질문: 공공의료대학 설립에 대한 법안이 국회에서 통과되지 못하고 있는데, 이에 대한 정부의 노력과 국회의 역할에 대한 의견을 어떻게 보십니까?
# 질문_키워드: 코로나, 감염 확산, 공공의료대학, 감염내과 전문의
# 문맥: 정부와 국회 양쪽에서 공공의료대학 설립 법안의 통과에 대한 노력의 중요성은 공감대가 형성되어 있으나 실제로 법안이 통과되지 못하는 현 상황에 대해 유감의 목소리가 커지고 있습니다. 이를 통해 필수 의료분야, 특히 감염병과 같은 공중보건 위기에 대비하는 의료 전문가를 양성하는 기관의 중요성 또한 강조되고 있습니다. 사회적인 필요성과 과거의 경험 (메르스 사태 등)으로 볼 때, 이런 전문의를 양성하는 공공의료대학이 필요한 시점임에도 불구하고, 정치적 의사 결정 과정의 지연으로 인해 여러 문제가 발생하고 있습니다. 국회는 법안을 입법화해야 할 책임이 있는 기관으로, 과거에는 다수결의 원칙이 어느 정도 작동하여 중요 법안들이 통과될 수 있었지만, 현재는 몇몇 의원들의 반대로 입법 과정이 지연되거나 불발되는 상황이 발생하고 있습니다. 이는 의료 시스템 내의 구조적 문제를 해결하고 질병 대응 역량을 강화하려는 노력에 걸림돌이 되고 있으며, 이에 대해 큰 우려를 나타내고 있는 것입니다. 따라서, 공공의료대학 설립을 통한 의료 시스템의 강화는 국회에서 긴급히 검토하고 통과시켜야 할 사안으로 보이며, 이대로 정책이 지체될 경우 공중보건 위기 상황에서의 대응력이 약화될 수 있음을 의미합니다. 정부는 법안을 적극적으로 옹호하고 필요한 조치를 취해야 할 책임이 있으며, 국회 또한 공공의 이익을 위해 신속하고 효과적으로 기능해야 한다는 점이 강조되고 있습니다.
# 답변자_이름: 정세균 국무총리
# 답변: 공공의료대학 설립 법안이 국회에서 통과되지 못하는 상황을 유감스럽게 생각하며, 과거의 다수결 원리가 작동하지 않아 입법이 불발하는 문제를 지적하고 있습니다. 공공의료대학 설립은 근본적인 대책으로, 5월 국회에서 반드시 통과시켜야 한다고 주장하고 있습니다.
# 답변_키워드: 공공의료대학

# %%
RAG_experiment("대학 미충원 인원에 관한 발언들로 무엇이 있나요?")
# Out:
# Sub Document
# 글 길이: 140
#
#
# {'질문자_이름': '서동용 의원', '질문': '올해 대학 및 전문대의 신입생 미충원 문제가 심각한데, 이에 대한 정부의 대응책이 있을까요?', '질문_키워드': '지방사립대,  지방 거점 국립대,  전문대학,  추가모집,  미충원 인원,  올해'}
# Retrieved Document
# 글 길이: 717
#
#
# 회의날짜: 2021년4월21일(수)
# 국회_대: 21
# 회의명: 국회본회의
# 회수: 제386회
# 차수: 제3차
# 안건: 교육․사회․문화에 관한 질문
# 법안: 교육․사회․문화에 관한 질문
# 질문자_이름: 서동용 의원
# 질문: 올해 대학 및 전문대의 신입생 미충원 문제가 심각한데, 이에 대한 정부의 대응책이 있을까요?
# 질문_키워드: 지방사립대,  지방 거점 국립대,  전문대학,  추가모집,  미충원 인원,  올해
# 문맥: 올해 대학 및 전문대의 신입생 미충원 문제에 대한 정부의 대응책은 매우 중요한 문제로 여겨지고 있습니다. 이에 정부는 지방대에 대한 중장기 기본계획을 수립하여 지역과 대학이 협력하여 학생들이 지역의 대학에 입학하고 취업할 수 있는 여건을 만들기 위한 사업을 진행 중입니다. 또한, 국회 상임위에서도 여야 위원들이 협의를 통해 대안을 마련하고 있으며, 5월 초경에는 이에 대한 대안을 발표할 예정입니다.
# 답변자_이름: 유은혜 교육부 부총리겸장관
# 답변: 이 문제를 심각하게 받아들이고 지난 3월에 여러 관계부처와 협력하여 지방대에 대한 중장기 기본계획을 수립했습니다. 또한, 국회 상임위에서 여야 위원들이 협의를 통해 대안을 마련하고 있으며, 지역과 대학이 협력하여 학생들이 지역의 대학에 입학하고 취업할 수 있는 여건을 만들기 위한 사업을 진행 중입니다. 5월 초경에는 대안을 발표할 예정입니다.
# 답변_키워드: 비수도권,  지방대,  중장기 기본계획,  국회 상임위,  고등교육
